# %%
import json
import pandas as pd
from thefuzz import fuzz
from thefuzz import process
from pyalex import Works, Authors, Sources, Institutions, Topics, Publishers, Funders
import numpy as np

# %%
def get_self_citing_paperIDs_from_OpenAlex(path_openalex,list_of_names, source_type ):
    """ 
    Extracting paper IDs that are citing a proceeding document and originate from the same proceeding  
    
    Args:
        path_openalex (str): Path to the Json File including the citing documents
        source_type (str): Allows to select between Journal and Conference sources
        list_of_names (list): Contains the journal/conference names that are related to the observed proceedings

    Returns:
        df_OA: Dataframe including the document ID and the corresponding journals 

    """
    # Readin the json file with the citing documents
    with open(path_openalex, 'r', encoding="utf-8") as file:
        OpenAlexCitations = json.load(file)

    journals_open_alex = []
    for i in OpenAlexCitations:
        list_journals = []
        for j in OpenAlexCitations[i]:
            if j.get("primary_location") and j["primary_location"].get("source") and j["primary_location"]["source"].get("type") == source_type:
                try:
                    if j["primary_location"]["source"]["display_name"] in list_of_names:                
                        list_journals.append([j["id"], j["title"]])
                except:
                    continue
        journals_open_alex.append([i, list_journals])

    # Creating the dataframe including the ID and the corresponding journals
    df_OA = pd.DataFrame(journals_open_alex, columns=["ID", f"{source_type}s"])
    
    return df_OA

# %%
# Creating the dataframes with the citing journals for all three proceedings
list_of_names=["CLEF (Working Notes)", "CLEF (Online Working Notes/Labs/Workshop)"]

df_ceur_journals = get_journals_from_OpenAlex("../../../data/OpenAlex_CEUR_citing_doc.json", list_of_names, source_type="journal")
df_lncs_journals = get_journals_from_OpenAlex("../../../data/OpenAlex_LNCS_citing_doc.json", ["Cross-Language Evaluation Forum"], source_type="conference")
df_trec_journals = get_journals_from_OpenAlex("../../../data/OpenAlex_TREC_citing_doc.json", ["Text REtrieval Conference"], source_type="conference")

# %% [markdown]
# ## Analying self-citation by Overview Papers (CEUR)

# %%
ceur_citing_docs = []
for i in df_ceur_journals["journals"]:
    for j in i:
        ceur_citing_docs.append(j)

# %%
ceur_citing_docs
# Out:
# [['https://openalex.org/W2750981090',
#   'Image-based Plant Species Identification with Deep Convolutional Neural Networks.'],
#  ['https://openalex.org/W2403531298',
#   'Applying LDA in contextual image retrieval ReDCAD participation at ImageCLEF Flickr Photo Retrieval 2012'],
#  ['https://openalex.org/W2294894353',
#   'The participation of IntermidiaLab at the ImageCLEF 2012 Photo Annotation Task'],
#  ['https://openalex.org/W2401982302',
#   'A Hybrid Tweet Contextualization System using IR and Summarization.'],
#  ['https://openalex.org/W2406927329',
#   'An Automatic System for Modality and Negation Detection.'],
#  ['https://openalex.org/W2399497040',
#   'Tweet Contextualization (Answering Tweet Question) - the Role of Multi-document Summarization.'],
#  ['https://openalex.org/W2185044903', 'FBM-Yahoo! at RepLab 2012'],
#  ['https://openalex.org/W2397760338',
#   'Learning to Analyze Relevancy and Polarity of Tweets.'],
#  ['https://openalex.org/W2182297626',
#   'UTACLIR @ CLEF 2002: Towards a unified translation process model'],
#  ['https://openalex.org/W2916411982',
#   'COLE experiments at CLEF 2002 Spanish monolingual track'],
#  ['https://openalex.org/W120173694',
#   'COLE at CLEF 2004: Rapid prototyping of a QA system for Spanish'],
#  ['https://openalex.org/W3196618497',
#   'Overview of the CLEF-2021 CheckThat! Lab: Task 3 on Fake News Detection.'],
#  ['https://openalex.org/W2125398487',
#   'Combining Text and Image Queries at ImageCLEF2005'],
#  ['https://openalex.org/W2188747564',
#   'NCTU_DBLAB@ImageCLEF 2005: Automatic annotation task'],
#  ['https://openalex.org/W2182223068',
#   'CYU_IM@ImageCLEF 2007: Medical image annotation task'],
#  ['https://openalex.org/W2147822033',
#   'CoLesIR at CLEF 2006: Rapid Prototyping of an N-gram-Based CLIR System'],
#  ['https://openalex.org/W2403513632',
#   'Benefits of deep NLP-based Lemmatization for Information Retrieval.'],
#  ['https://openalex.org/W2408619611',
#   'A Shallow Approach for Answer Selection based on Dependency Trees and Term Density.'],
#  ['https://openalex.org/W3198121869',
#   'Multi-label Style Change Detection by Solving a Binary Classification Problem.'],
#  ['https://openalex.org/W2966743415',
#   'Automated Lifelog Moment Retrieval based on Image Segmentation and Similarity Scores.'],
#  ['https://openalex.org/W2889120544',
#   'Visual Concept Selection with Textual Knowledge for Understanding Activities of Daily Living and Life Moment Retrieval.'],
#  ['https://openalex.org/W2889159752',
#   'Regim Lab Team at ImageCLEF Lifelog Moment Retrieval Task 2018.'],
#  ['https://openalex.org/W2889405858',
#   'Lifelog Moment Retrieval with Visual Concept Fusion and Text-based Query Expansion.'],
#  ['https://openalex.org/W2889492456',
#   'Multimedia Lab @ ImageCLEF 2018 Lifelog Moment Retrieval Task.'],
#  ['https://openalex.org/W2966249446',
#   'Multimedia Lab @ ImageCLEF 2019 Lifelog Moment Retrieval Task.'],
#  ['https://openalex.org/W2888932510',
#   'An Interactive Lifelog Retrieval System for Activities of Daily Living Understanding.'],
#  ['https://openalex.org/W2889335545',
#   'Leveraging Content and Context in Understanding Activities of Daily Living.'],
#  ['https://openalex.org/W2889465643',
#   'ImageSem at ImageCLEF 2018 Caption Task: Image Retrieval and Transfer Learning.'],
#  ['https://openalex.org/W2965490408',
#   'ImageSem at ImageCLEFmed Caption 2019 Task: a Two-stage Medical Concept Detection Strategy.'],
#  ['https://openalex.org/W2966063709',
#   'Overview of the ImageCLEFmed 2019 concept detection task'],
#  ['https://openalex.org/W2889077803',
#   'Generating Text from Images in a Smooth Representation Space.'],
#  ['https://openalex.org/W2965795432',
#   'AUEB NLP Group at ImageCLEFmed Caption 2019.'],
#  ['https://openalex.org/W3095365742', 'Essex at ImageCLEFcaption 2020 Task.'],
#  ['https://openalex.org/W3097366680',
#   'ImageCLEF 2020: An approach for Visual Question Answering using VGG-LSTM for Different Datasets.'],
#  ['https://openalex.org/W3196749764',
#   'AUEB NLP Group at ImageCLEFmed Caption Tasks 2021.'],
#  ['https://openalex.org/W2295716592',
#   'ECNU at 2015 eHealth Task 2: User-centred Health Information Retrieval'],
#  ['https://openalex.org/W2752259871',
#   'KISTI at CLEF eHealth 2017 Patient-Centered Information Retrieval Task-1: Improving Medical Document Retrieval with Query Expansion.'],
#  ['https://openalex.org/W2406679719',
#   'Hybrid Learning Framework for Large-Scale Web Image Annotation and Localization.'],
#  ['https://openalex.org/W2577225106',
#   'Deep Learning and SVM Classification for Plant Recognition in Content-Based Large Scale Image Retrieval.'],
#  ['https://openalex.org/W2888789950',
#   'Overview of the Author Obfuscation Task at PAN 2018: A New Approach to Measuring Safety.'],
#  ['https://openalex.org/W2394742672',
#   'AUTH-Atypon at BioASQ 3: Large-Scale Semantic Indexing in Biomedicine.'],
#  ['https://openalex.org/W2404001631',
#   'A Comparative Study of Similarity Measures for Content-Based Medical Image Retrieval.'],
#  ['https://openalex.org/W2402263930',
#   "ITI's Participation in the ImageCLEF 2012 Medical Retrieval and Classification Tasks."],
#  ['https://openalex.org/W2916088666',
#   'The medGIFT Group in ImageCLEFmed 2012'],
#  ['https://openalex.org/W2189209245',
#   'FCSE at Medical Tasks of ImageCLEF 2013'],
#  ['https://openalex.org/W2407664795', 'NovaSearch on Medical ImageCLEF 2013.'],
#  ['https://openalex.org/W2187223183',
#   'Overview of the ImageCLEF 2012 Flickr Photo Annotation and Retrieval Task'],
#  ['https://openalex.org/W1988287859',
#   'Sabanci-Okan system at imageclef 2013 plant identification competition'],
#  ['https://openalex.org/W2242365488',
#   'Sabanci-Okan system in LifeCLEF 2015 plant identification competition'],
#  ['https://openalex.org/W2394732248', 'A Methodology for Social Book Search.'],
#  ['https://openalex.org/W2915108564',
#   'Overview of QA4MRE at CLEF 2012: Question Answering for Machine Reading Evaluation'],
#  ['https://openalex.org/W2295001245',
#   'An Approach to the Main Task of QA4MRE-2013'],
#  ['https://openalex.org/W2186320763',
#   'Building Optimal Question Answering System Automatically using Configuration Space Exploration (CSE) for QA4MRE 2013 Tasks.'],
#  ['https://openalex.org/W2186320763',
#   'Building Optimal Question Answering System Automatically using Configuration Space Exploration (CSE) for QA4MRE 2013 Tasks.'],
#  ['https://openalex.org/W2186320763',
#   'Building Optimal Question Answering System Automatically using Configuration Space Exploration (CSE) for QA4MRE 2013 Tasks.'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2405094145',
#   "Guess Again and See if They Line up: Surrey's Runs at Plagiarism Detection Notebook for PAN at CLEF 2013."],
#  ['https://openalex.org/W3096938098',
#   'Overview of the VQA-Med Task at ImageCLEF 2020: Visual Question Answering and Generation in the Medical Domain.'],
#  ['https://openalex.org/W3198253599',
#   'Lijie at ImageCLEFmed VQA-Med 2021: Attention Model-based Efficient Interaction between Multimodality.'],
#  ['https://openalex.org/W2576343211',
#   'The Effectiveness of Query Expansion when searching for Health related Content: InfoLab at CLEF eHealth 2016.'],
#  ['https://openalex.org/W2296287566',
#   'FHDO Biomedical Computer Science Group at Medical Classification Task of ImageCLEF 2015.'],
#  ['https://openalex.org/W2406030325',
#   'AAUITEC at ImageCLEF 2015: Compound Figure Separation.'],
#  ['https://openalex.org/W2294483503',
#   'IIS at ImageCLEF 2015: Multi-label Classification Task.'],
#  ['https://openalex.org/W2296315338',
#   'X-ray image body part clustering using deep convolutional neural network: SNUMedinfo at ImageCLEF 2015 medical clustering task'],
#  ['https://openalex.org/W2404910391',
#   'Convolutional Neural Networks for Medical Clustering'],
#  ['https://openalex.org/W2407398178',
#   'CIS UDEL Working Notes on ImageCLEF 2015: Compound Figure Detection Task.'],
#  ['https://openalex.org/W2403164357',
#   'Automatic Classification of Body Parts X-ray Images.'],
#  ['https://openalex.org/W2402232595',
#   'Clustering of Medical X-ray Images by Merging Outputs of Different Classification Techniques.'],
#  ['https://openalex.org/W2295083309',
#   'IBM Research at Image CLEF 2015: Medical Clustering Task.'],
#  ['https://openalex.org/W2400252330',
#   'Historical Clicks for Product Search: GESIS at CLEF LL4IR 2015.'],
#  ['https://openalex.org/W2407334860',
#   'Probabilistic field mapping for product search'],
#  ['https://openalex.org/W2577407958',
#   "Ideas for a Standard LL4IR Extension - Living Labs from a System Operator's Perspective."],
#  ['https://openalex.org/W2966743415',
#   'Automated Lifelog Moment Retrieval based on Image Segmentation and Similarity Scores.'],
#  ['https://openalex.org/W2889120544',
#   'Visual Concept Selection with Textual Knowledge for Understanding Activities of Daily Living and Life Moment Retrieval.'],
#  ['https://openalex.org/W120173694',
#   'COLE at CLEF 2004: Rapid prototyping of a QA system for Spanish'],
#  ['https://openalex.org/W2404045381',
#   'Evaluating Fusion Techniques at Different Domains in ImageCLEF Subtasks.'],
#  ['https://openalex.org/W2404292891',
#   'Passage Retrieval vs. Document Retrieval in the Monolingual Task with the IR-n System.'],
#  ['https://openalex.org/W2147918336',
#   'European Ad Hoc Retrieval Experiments with Hummingbird SearchServerTM at CLEF 2005.'],
#  ['https://openalex.org/W2127339406',
#   'EQUAL : Encyclopaedic QUestion Answering for Lists'],
#  ['https://openalex.org/W2399896266',
#   'GIRSA-WP at GikiCLEF: Integration of Structured Information and Decomposition of Questions.'],
#  ['https://openalex.org/W2395681725',
#   'DMS-SZTAKI @ ImageCLEF 2012 Photo Annotation.'],
#  ['https://openalex.org/W2916797803', 'SZTAKI @ ImageCLEF 2009'],
#  ['https://openalex.org/W2159529225',
#   'Chemnitz at VideoCLEF 2009: Experiments and Observations on Treating Classification as an IR Task.'],
#  ['https://openalex.org/W2115443061',
#   'REINA at WebCLEF 2007. Selecting usefull snippets'],
#  ['https://openalex.org/W2259059895', 'Hunting Answers with RAPOSA (FOX)'],
#  ['https://openalex.org/W2396044720', 'QA@L2F@QA@CLEF.'],
#  ['https://openalex.org/W1988287859',
#   'Sabanci-Okan system at imageclef 2013 plant identification competition'],
#  ['https://openalex.org/W2242365488',
#   'Sabanci-Okan system in LifeCLEF 2015 plant identification competition'],
#  ['https://openalex.org/W2188960351',
#   'Question Answering System for QA4MRE@CLEF 2012'],
#  ['https://openalex.org/W2401982302',
#   'A Hybrid Tweet Contextualization System using IR and Summarization.'],
#  ['https://openalex.org/W2406956366',
#   'Enhancing a Question Answering System with Textual Entailment for Machine Reading Evaluation.'],
#  ['https://openalex.org/W2406927329',
#   'An Automatic System for Modality and Negation Detection.'],
#  ['https://openalex.org/W2399497040',
#   'Tweet Contextualization (Answering Tweet Question) - the Role of Multi-document Summarization.'],
#  ['https://openalex.org/W2295760158',
#   'Two Approaches for QA4MRE: Information Retrieval and Graph-based knowledge representation'],
#  ['https://openalex.org/W3096015202',
#   'EvolutionTeam at CLEF2020 - CheckThat! lab : Integration of Linguistic and Sentimental Features in a Fake News Detection Approach.'],
#  ['https://openalex.org/W2965490408',
#   'ImageSem at ImageCLEFmed Caption 2019 Task: a Two-stage Medical Concept Detection Strategy.'],
#  ['https://openalex.org/W2966063709',
#   'Overview of the ImageCLEFmed 2019 concept detection task'],
#  ['https://openalex.org/W3095854630',
#   'AUEB NLP Group at ImageCLEFmed Caption 2020.'],
#  ['https://openalex.org/W2296626982',
#   'Using Textual and Visual Processing in Scalable Concept Image Annotation Challenge'],
#  ['https://openalex.org/W2574174279',
#   'Using Machine Learning Techniques, Textual and Visual Processing in Scalable Concept Image Annotation Challenge.'],
#  ['https://openalex.org/W2296287566',
#   'FHDO Biomedical Computer Science Group at Medical Classification Task of ImageCLEF 2015.'],
#  ['https://openalex.org/W2189209245',
#   'FCSE at Medical Tasks of ImageCLEF 2013'],
#  ['https://openalex.org/W2576770651',
#   'UDEL CIS Working Notes in ImageCLEF 2016.'],
#  ['https://openalex.org/W2407664795', 'NovaSearch on Medical ImageCLEF 2013.'],
#  ['https://openalex.org/W2404143171',
#   'Cultural Heritage in CLEF (CHiC) 2013 - Multilingual Task Overview.'],
#  ['https://openalex.org/W2397707338',
#   'USTB at INEX2014: Social Book Search Track'],
#  ['https://openalex.org/W2578368441',
#   'USTB at Social Book Search 2016 Suggestion Task: Active Books Set and Re-ranking.'],
#  ['https://openalex.org/W2295241886',
#   'USTB at Social Book Search 2015 Suggestion Task: Metadata Expansion and Reranking.'],
#  ['https://openalex.org/W2402770933',
#   'Solving Open-Domain Multiple Choice Questions with Textual Entailment and Text Similarity Measures.'],
#  ['https://openalex.org/W2402770933',
#   'Solving Open-Domain Multiple Choice Questions with Textual Entailment and Text Similarity Measures.'],
#  ['https://openalex.org/W2295218167',
#   'French run of Synapse Développement at Entrance Exams 2014'],
#  ['https://openalex.org/W2402770933',
#   'Solving Open-Domain Multiple Choice Questions with Textual Entailment and Text Similarity Measures.'],
#  ['https://openalex.org/W2408148480',
#   'English run of Synapse Développement at Entrance Exams 2014'],
#  ['https://openalex.org/W2400796284',
#   'Source Retrieval for Plagiarism Detection from Large Web Corpora: Recent Approaches.'],
#  ['https://openalex.org/W2401309779',
#   'Supervised Ranking for Plagiarism Source Retrieval.'],
#  ['https://openalex.org/W2404012917',
#   'Source Retrieval and Text Alignment Corpus Construction for Plagiarism Detection.'],
#  ['https://openalex.org/W2575628804',
#   'Derivative Approach for Plagiarism Source Retrieval.'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2400652919',
#   'A Hybrid Architecture for Plagiarism Detection.'],
#  ['https://openalex.org/W2407028518',
#   'Using Noun Phrases and Tf-idf for Plagiarized Document Retrieval.'],
#  ['https://openalex.org/W2915998928',
#   'Overview of the Author Identification Task at PAN 2013'],
#  ['https://openalex.org/W2394650926',
#   'Homotopy Based Classification for Author Verification Task: Notebook for PAN at CLEF 2015.'],
#  ['https://openalex.org/W2915998928',
#   'Overview of the Author Identification Task at PAN 2013'],
#  ['https://openalex.org/W2189616766', 'QA@L2F, Second Steps at QA@CLEF.'],
#  ['https://openalex.org/W2916114784',
#   'Cross Lingual Question Answering using QRISTAL for CLEF 2008'],
#  ['https://openalex.org/W2183534784',
#   'University of Hagen at CLEF 2005: Towards a Better Baseline for NLP Methods in Domain-Specific Information Retrieval'],
#  ['https://openalex.org/W2158492748',
#   'University of Hagen at CLEF2006: Reranking Documents for the Domain-specific Task.'],
#  ['https://openalex.org/W2889361079',
#   'Overview of the CLEF 2018 Consumer Health Search Task'],
#  ['https://openalex.org/W2405637460',
#   'Query Expansion using External Resources for Improving Information Retrieval in the Biomedical Domain.'],
#  ['https://openalex.org/W2401386366',
#   'Miracl at Clef 2014 : eHealth Information Retrieval Task.'],
#  ['https://openalex.org/W2397350210',
#   'Team IRLabDAIICT at ShARe/CLEF eHealth 2014 Task 3: User-centered Information Retrieval System for Clinical Documents.'],
#  ['https://openalex.org/W2399378184',
#   'CSKU GPRF-QE for Medical Topic Web Retrieval.'],
#  ['https://openalex.org/W2184865242',
#   'CUNI at the ShARe/CLEF eHealth Evaluation Lab 2014'],
#  ['https://openalex.org/W2186702334',
#   'The University of Iowa at CLEF 2014: eHealth Task 3'],
#  ['https://openalex.org/W2408354624',
#   'TeamHCMUS: A Concept-based Information Retrieval Approach for Web Medical Documents.'],
#  ['https://openalex.org/W2397526260',
#   'Task 2a: Team KU-CS: Query Coherence Analysis for PRF and Genomics Expansion.'],
#  ['https://openalex.org/W2408354624',
#   'TeamHCMUS: A Concept-based Information Retrieval Approach for Web Medical Documents.'],
#  ['https://openalex.org/W2408354624',
#   'TeamHCMUS: A Concept-based Information Retrieval Approach for Web Medical Documents.'],
#  ['https://openalex.org/W2296138661',
#   'MIL at ImageCLEF 2013: Scalable System for Image Annotation'],
#  ['https://openalex.org/W2185932291',
#   'KDEVIR at ImageCLEF 2014 Scalable Concept Image Annotation Task: Ontology-based Automatic Image Annotation'],
#  ['https://openalex.org/W2294170641',
#   'Renmin University of China at ImageCLEF 2014 Scalable Concept Image Annotation'],
#  ['https://openalex.org/W2295169469',
#   'DISA at ImageCLEF 2014: The search-based solution for scalable image annotation'],
#  ['https://openalex.org/W2296626982',
#   'Using Textual and Visual Processing in Scalable Concept Image Annotation Challenge'],
#  ['https://openalex.org/W2404134963',
#   'MindLab at ImageCLEF 2014: Scalable Concept Image Annotation.'],
#  ['https://openalex.org/W2295382288',
#   'IPL at ImageCLEF 2014: Scalable Concept Image Annotation.'],
#  ['https://openalex.org/W2404341878',
#   'Regimvid at ImageCLEF 2015 Scalable Concept Image Annotation Task: Ontology based Hierarchical Image Annotation'],
#  ['https://openalex.org/W2964642049', 'Overview of ImageCLEFcoral 2019 task'],
#  ['https://openalex.org/W2888792935',
#   'Overview of the ImageCLEF 2014 Robot Vision Task.'],
#  ['https://openalex.org/W2294403783',
#   'RUC-Tencent at ImageCLEF 2015: Concept Detection, Localization and Sentence Generation'],
#  ['https://openalex.org/W2296626982',
#   'Using Textual and Visual Processing in Scalable Concept Image Annotation Challenge'],
#  ['https://openalex.org/W2296698078',
#   'KDEVIR at ImageCLEF 2015 Scalable Image Annotation, Localization, and Sentence Generation task: Ontology based Multi-label Image Annotation.'],
#  ['https://openalex.org/W2404341878',
#   'Regimvid at ImageCLEF 2015 Scalable Concept Image Annotation Task: Ontology based Hierarchical Image Annotation'],
#  ['https://openalex.org/W2293828522',
#   'Overview of the ImageCLEF 2015 liver CT annotation task'],
#  ['https://openalex.org/W2296096075',
#   'Automatic Annotation of Liver CT Image: ImageCLEFmed 2015'],
#  ['https://openalex.org/W2293828522',
#   'Overview of the ImageCLEF 2015 liver CT annotation task'],
#  ['https://openalex.org/W2296096075',
#   'Automatic Annotation of Liver CT Image: ImageCLEFmed 2015'],
#  ['https://openalex.org/W2293828522',
#   'Overview of the ImageCLEF 2015 liver CT annotation task'],
#  ['https://openalex.org/W2296096075',
#   'Automatic Annotation of Liver CT Image: ImageCLEFmed 2015'],
#  ['https://openalex.org/W2291762912',
#   'This is it! Selection and Preferences for Books'],
#  ['https://openalex.org/W2886432658',
#   'The Value of Multistage Search Systems for Book Search'],
#  ['https://openalex.org/W2398462394',
#   'Book Recommendation Using Information Retrieval Methods and Graph Analysis.'],
#  ['https://openalex.org/W2399214803', 'LaHC at CLEF 2015 SBS Lab'],
#  ['https://openalex.org/W2293532098',
#   'A generic retrieval system for biomedical literatures: USTB at BioASQ2015 Question Answering Task'],
#  ['https://openalex.org/W2295241886',
#   'USTB at Social Book Search 2015 Suggestion Task: Metadata Expansion and Reranking.'],
#  ['https://openalex.org/W2404400986',
#   'Fine-tuning Deep Convolutional Networks for Plant Recognition.'],
#  ['https://openalex.org/W2296514540',
#   'Plant identification with deep convolutional neural network: SNUMedinfo at LifeCLEF plant identification task 2015'],
#  ['https://openalex.org/W2578619353',
#   'Development of a News Recommender System based on Apache Flink.'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2397716882',
#   'On the Empirical Evaluation of Hybrid Author Identification Method.'],
#  ['https://openalex.org/W2401347463',
#   'Author Profiling of Twitter Users: Notebook for PAN at CLEF 2015.'],
#  ['https://openalex.org/W2397862192',
#   'ISOFT at QALD-5: Hybrid Question Answering System over Linked Data and Text Data.'],
#  ['https://openalex.org/W2403393286',
#   'The Fudan Participation in the 2015 BioASQ Challenge: Large-scale Biomedical Semantic Indexing and Question Answering'],
#  ['https://openalex.org/W2293532098',
#   'A generic retrieval system for biomedical literatures: USTB at BioASQ2015 Question Answering Task'],
#  ['https://openalex.org/W2403393286',
#   'The Fudan Participation in the 2015 BioASQ Challenge: Large-scale Biomedical Semantic Indexing and Question Answering'],
#  ['https://openalex.org/W2394742672',
#   'AUTH-Atypon at BioASQ 3: Large-Scale Semantic Indexing in Biomedicine.'],
#  ['https://openalex.org/W2296408433',
#   'HPI question answering system in the BioASQ 2015 challenge'],
#  ['https://openalex.org/W2406476085',
#   'Learning to Answer Biomedical Factoid & List Questions: OAQA at BioASQ 3B.'],
#  ['https://openalex.org/W2394742672',
#   'AUTH-Atypon at BioASQ 3: Large-Scale Semantic Indexing in Biomedicine.'],
#  ['https://openalex.org/W2296305699',
#   'Reading comprehension at Entrance Exams 2015'],
#  ['https://openalex.org/W3197800295',
#   'Dowsing for Answers to Math Questions: Ongoing Viability of Traditional MathIR.'],
#  ['https://openalex.org/W3198245124',
#   'End-to-end Biomedical Question Answering via Bio-AnswerFinder and Discriminative Language Representation Models.'],
#  ['https://openalex.org/W3198562165',
#   'Overview of BioASQ Tasks 9a, 9b and Synergy in CLEF2021.'],
#  ['https://openalex.org/W3198710199',
#   'MDS_UNCC Question Answering System for Biomedical Data with Preliminary Error Analysis.'],
#  ['https://openalex.org/W3196837057',
#   'PIDNA at BioASQ MESINESP: Hybrid Semantic Indexing for Biomedical Articles in Spanish.'],
#  ['https://openalex.org/W3197758567',
#   'TOBB ETU at CheckThat! 2021: Data Engineering for Detecting Check-Worthy Claims.'],
#  ['https://openalex.org/W3197758567',
#   'TOBB ETU at CheckThat! 2021: Data Engineering for Detecting Check-Worthy Claims.'],
#  ['https://openalex.org/W3095986797',
#   'Check_square at CheckThat! 2020: Claim Detection in Social Media via Fusion of Transformer and Syntactic Features'],
#  ['https://openalex.org/W3197758567',
#   'TOBB ETU at CheckThat! 2021: Data Engineering for Detecting Check-Worthy Claims.'],
#  ['https://openalex.org/W3197758567',
#   'TOBB ETU at CheckThat! 2021: Data Engineering for Detecting Check-Worthy Claims.'],
#  ['https://openalex.org/W3198657625',
#   'Aschern at CLEF CheckThat! 2021: Lambda-Calculus of Fact-Checked Claims.'],
#  ['https://openalex.org/W3095558364',
#   'FLE at CLEF eHealth 2020: Text Mining and Semantic Knowledge for Automated Clinical Encoding.'],
#  ['https://openalex.org/W3097323310',
#   'Transformers in Semantic Indexing of Clinical Codes.'],
#  ['https://openalex.org/W3097916427',
#   'As Simple as Possible: Using the R Tidyverse for Multilingual Information Extraction. IMS UniPD ad CLEF eHealth 2020 Task 1.'],
#  ['https://openalex.org/W3095525213',
#   'Overview of Automatic Clinical Coding: Annotations, Guidelines, and Solutions for non-English Clinical Cases at CodiEsp Track of CLEF eHealth 2020.'],
#  ['https://openalex.org/W3095525213',
#   'Overview of Automatic Clinical Coding: Annotations, Guidelines, and Solutions for non-English Clinical Cases at CodiEsp Track of CLEF eHealth 2020.'],
#  ['https://openalex.org/W3197811249',
#   'VADER meets BERT: sentiment analysis for early detection of signs of self-harm through social mining.'],
#  ['https://openalex.org/W3198303683',
#   'Early Risk Detection of Pathological Gambling, Self-Harm and Depression Using BERT.'],
#  ['https://openalex.org/W3197420423',
#   'A RoBERTa-based model on measuring the severity of the signs of depression.'],
#  ['https://openalex.org/W3197754921',
#   'UPV-Symanto at eRisk 2021: Mental Health Author Profiling for Early Risk Prediction on the Internet.'],
#  ['https://openalex.org/W3198303683',
#   'Early Risk Detection of Pathological Gambling, Self-Harm and Depression Using BERT.'],
#  ['https://openalex.org/W3197420423',
#   'A RoBERTa-based model on measuring the severity of the signs of depression.'],
#  ['https://openalex.org/W3197754921',
#   'UPV-Symanto at eRisk 2021: Mental Health Author Profiling for Early Risk Prediction on the Internet.'],
#  ['https://openalex.org/W3198450613',
#   'NLP-UNED at eRisk 2021: self-harm early risk detection with TF-IDF and linguistic features.'],
#  ['https://openalex.org/W3197811249',
#   'VADER meets BERT: sentiment analysis for early detection of signs of self-harm through social mining.'],
#  ['https://openalex.org/W3094996448',
#   'Transfer Learning for Named Entity Recognition in Historical Corpora.'],
#  ['https://openalex.org/W3096875034',
#   'Hybrid Statistical and Attentive Deep Neural Approach for Named Entity Recognition in Historical Newspapers.'],
#  ['https://openalex.org/W3095348722',
#   'Triple E - Effective Ensembling of Embeddings and Language Models for NER of Historical German.'],
#  ['https://openalex.org/W3095348722',
#   'Triple E - Effective Ensembling of Embeddings and Language Models for NER of Historical German.'],
#  ['https://openalex.org/W3095461034',
#   'AIML at VQA-Med 2020: Knowledge inference via a skeleton-based sentence mapping approach for medical domain visual question answering'],
#  ['https://openalex.org/W3094735822',
#   'The Inception Team at VQA-Med 2020: Pretrained VGG with Data Augmentation for Medical VQA and VQG.'],
#  ['https://openalex.org/W3096105091',
#   'NLM at VQA-Med 2020: Visual Question Answering and Generation in the Medical Domain.'],
#  ['https://openalex.org/W3097410128',
#   'Techniques for Medical Concept Detection from Multi-Modal Images.'],
#  ['https://openalex.org/W3095365742', 'Essex at ImageCLEFcaption 2020 Task.'],
#  ['https://openalex.org/W3096938098',
#   'Overview of the VQA-Med Task at ImageCLEF 2020: Visual Question Answering and Generation in the Medical Domain.'],
#  ['https://openalex.org/W3095875466',
#   'Overview of ImageCLEFtuberculosis 2020 Automatic CT-based Report Generation.'],
#  ['https://openalex.org/W3097665901',
#   'Overview of the ImageCLEFmed 2020 Concept Prediction Task: Medical Image Understanding.'],
#  ['https://openalex.org/W3095875466',
#   'Overview of ImageCLEFtuberculosis 2020 Automatic CT-based Report Generation.'],
#  ['https://openalex.org/W3095875466',
#   'Overview of ImageCLEFtuberculosis 2020 Automatic CT-based Report Generation.'],
#  ['https://openalex.org/W3198371010',
#   'UAIC-AI at SnakeCLEF 2021: Impact of convolutions in snake species recognition.'],
#  ['https://openalex.org/W3097096175',
#   'Bird Species Recognition via Neural Architecture Search.'],
#  ['https://openalex.org/W3097342294',
#   'Using Triplet Loss for Bird Species Recognition on BirdCLEF 2020.'],
#  ['https://openalex.org/W3097850733',
#   'Xception Based Method for Bird Sound Recognition of BirdCLEF 2020.'],
#  ['https://openalex.org/W3196668293',
#   'EfficientNets and Vision Transformers for Snake Species Identification Using Image and Location Information.'],
#  ['https://openalex.org/W3198371010',
#   'UAIC-AI at SnakeCLEF 2021: Impact of convolutions in snake species recognition.'],
#  ['https://openalex.org/W3197567090',
#   'Siamese Bert for Authorship Verification.'],
#  ['https://openalex.org/W3196935460',
#   'O2D2: Out-Of-Distribution Detector to Capture Undecidable Trials in Authorship Verification.'],
#  ['https://openalex.org/W3094889889',
#   'Overview of the 8th Author Profiling Task at PAN 2020: Profiling Fake News Spreaders on Twitter.'],
#  ['https://openalex.org/W3198070797',
#   'Unified and Multilingual Author Profiling for Detecting Haters.'],
#  ['https://openalex.org/W3097704516',
#   'Exploring Argument Retrieval with Transformers.'],
#  ['https://openalex.org/W3094996272',
#   'Argument Retrieval Using Deep Neural Ranking Models.'],
#  ['https://openalex.org/W3196573980',
#   'Exploring BERT Synonyms and Quality Prediction for Argument Retrieval.'],
#  ['https://openalex.org/W3196819784',
#   'Learning to Rank Arguments with Feature Selection.'],
#  ['https://openalex.org/W3197013090',
#   'Development of an IR System for Argument Search.'],
#  ['https://openalex.org/W3197446804',
#   'Quality-aware Argument Retrieval with Topical Clustering.'],
#  ['https://openalex.org/W3197540334',
#   'Exploring Document Expansion for Argument Retrieval.'],
#  ['https://openalex.org/W2401019170',
#   'Supervised Named Entity Recognition for Clinical Data.'],
#  ['https://openalex.org/W2296679031',
#   'WI-ENRE in CLEF eHealth Evaluation Lab 2015: Clinical Named Entity Recognition Based on CRF'],
#  ['https://openalex.org/W2401383351', 'LIMSI @ CLEF eHealth 2015 - task 1b'],
#  ['https://openalex.org/W2295716592',
#   'ECNU at 2015 eHealth Task 2: User-centred Health Information Retrieval'],
#  ['https://openalex.org/W2294442178',
#   'Employing query expansion models to help patients diagnose themselves'],
#  ['https://openalex.org/W2294680412', 'KISTI at CLEF eHealth 2015 Task 2'],
#  ['https://openalex.org/W2399984920',
#   'UBML participation to CLEF eHealth IR challenge 2015: Task 2'],
#  ['https://openalex.org/W2293627165',
#   "Bridging Layperson's Queries with Medical Concepts- GRIUM@CLEF2015 eHealth Task 2"],
#  ['https://openalex.org/W2397526260',
#   'Task 2a: Team KU-CS: Query Coherence Analysis for PRF and Genomics Expansion.'],
#  ['https://openalex.org/W2408354624',
#   'TeamHCMUS: A Concept-based Information Retrieval Approach for Web Medical Documents.'],
#  ['https://openalex.org/W2577637233',
#   'Team GU-IRLAB at CLEF eHealth 2016: Task 3.'],
#  ['https://openalex.org/W2295924316',
#   'Miracl at Clef 2015 : User-Centred Health Information Retrieval Task'],
#  ['https://openalex.org/W2401610526',
#   'Unsupervised Language Model Adaptation using Utterance-based Web Search for Clinical Speech Recognition'],
#  ['https://openalex.org/W2293037998',
#   'Automatic Clinical Speech Recognition for CLEF 2015 eHealth Challenge.'],
#  ['https://openalex.org/W2753720671',
#   'Fusion Methods for ICD10 Code Classification of Death Certificates in Multilingual Corpora.'],
#  ['https://openalex.org/W2573336013',
#   'Wrappers for Feature Subset Selection in CRF-based Clinical Information Extraction.'],
#  ['https://openalex.org/W2917788533',
#   'ECNU at 2018 eHealth Task 2: Technologically Assisted Reviews in Empirical Medicine.'],
#  ['https://openalex.org/W2751725489',
#   'ECNU at 2017 eHealth Task 2: Technologically Assisted Reviews in Empirical Medicine.'],
#  ['https://openalex.org/W2572906393',
#   'ECNU at 2016 eHealth Task 3: Patient-centred Information Retrieval.'],
#  ['https://openalex.org/W2407398178',
#   'CIS UDEL Working Notes on ImageCLEF 2015: Compound Figure Detection Task.'],
#  ['https://openalex.org/W2294403783',
#   'RUC-Tencent at ImageCLEF 2015: Concept Detection, Localization and Sentence Generation'],
#  ['https://openalex.org/W2294821704',
#   'INAOE-UNAL at ImageCLEF 2015: Scalable Concept Image Annotation'],
#  ['https://openalex.org/W2296626982',
#   'Using Textual and Visual Processing in Scalable Concept Image Annotation Challenge'],
#  ['https://openalex.org/W2296698078',
#   'KDEVIR at ImageCLEF 2015 Scalable Image Annotation, Localization, and Sentence Generation task: Ontology based Multi-label Image Annotation.'],
#  ['https://openalex.org/W2396288019',
#   "CEA LIST's participation to the Scalable Concept Image Annotation task of ImageCLEF 2015."],
#  ['https://openalex.org/W2396625194',
#   'BUAA-iCC at ImageCLEF 2015 Scalable Concept Image Annotation Challenge'],
#  ['https://openalex.org/W2404341878',
#   'Regimvid at ImageCLEF 2015 Scalable Concept Image Annotation Task: Ontology based Hierarchical Image Annotation'],
#  ['https://openalex.org/W2406679719',
#   'Hybrid Learning Framework for Large-Scale Web Image Annotation and Localization.'],
#  ['https://openalex.org/W2296096075',
#   'Automatic Annotation of Liver CT Image: ImageCLEFmed 2015'],
#  ['https://openalex.org/W2296153215',
#   'Overview of the ImageCLEF 2015 medical clustering task'],
#  ['https://openalex.org/W2578309615',
#   'Subfigure and Multi-Label Classification using a Fine-Tuned Convolutional Neural Network.'],
#  ['https://openalex.org/W2293828522',
#   'Overview of the ImageCLEF 2015 liver CT annotation task'],
#  ['https://openalex.org/W2577833659',
#   "INAOE's participation at ImageCLEF 2016: Text Illustration Task."],
#  ['https://openalex.org/W2573177916',
#   'CNRS TELECOM ParisTech at ImageCLEF 2016 Scalable Concept Image Annotation Task: Overcoming the Scarcity of Training Data.'],
#  ['https://openalex.org/W2296153215',
#   'Overview of the ImageCLEF 2015 medical clustering task'],
#  ['https://openalex.org/W2296153215',
#   'Overview of the ImageCLEF 2015 medical clustering task'],
#  ['https://openalex.org/W2517817292',
#   'Convolutional Neural Networks for Large-Scale Bird Song Classification in Noisy Environment'],
#  ['https://openalex.org/W2577807852',
#   'Optimizing a Scalable News Recommender System.'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2296582998',
#   'Efficient Paragraph based Chunking and Download Filtering for Plagiarism Source Retrieval'],
#  ['https://openalex.org/W2402211003',
#   'Improving Synoptic Quering for Source Retrieval: Notebook for PAN at CLEF 2015.'],
#  ['https://openalex.org/W2404012917',
#   'Source Retrieval and Text Alignment Corpus Construction for Plagiarism Detection.'],
#  ['https://openalex.org/W2405210618',
#   'Developing Bilingual Plagiarism Detection Corpus Using Sentence Aligned Parallel Corpus Notebook for PAN at CLEF 2015'],
#  ['https://openalex.org/W2404012917',
#   'Source Retrieval and Text Alignment Corpus Construction for Plagiarism Detection.'],
#  ['https://openalex.org/W2396176393',
#   'The Short Stories Corpus: Notebook for PAN at CLEF 2015.'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2889329048',
#   "Author Masking Directed by Author's Style: Notebook for PAN at CLEF 2018."],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2400796284',
#   'Source Retrieval for Plagiarism Detection from Large Web Corpora: Recent Approaches.'],
#  ['https://openalex.org/W2403393286',
#   'The Fudan Participation in the 2015 BioASQ Challenge: Large-scale Biomedical Semantic Indexing and Question Answering'],
#  ['https://openalex.org/W2293532098',
#   'A generic retrieval system for biomedical literatures: USTB at BioASQ2015 Question Answering Task'],
#  ['https://openalex.org/W2394742672',
#   'AUTH-Atypon at BioASQ 3: Large-Scale Semantic Indexing in Biomedicine.'],
#  ['https://openalex.org/W2889010644',
#   'CIC-GIL Approach to Cross-domain Authorship Attribution: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W2889189821',
#   'Detecting a Change of Style using Text Statistics: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W2889394874',
#   'Multi-Language Neural Network Model with Advance Preprocessor for Gender Classification over Social Media: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W2966046452',
#   'Cross-domain Authorship Attribution: Author Identification using a Multi-Aspect Ensemble Approach.'],
#  ['https://openalex.org/W2888924060',
#   'UniNE at CLEF 2018: Author Masking: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W3096813180',
#   'Overview of the Style Change Detection Task at PAN 2020.'],
#  ['https://openalex.org/W2889340004',
#   'EACH-USP Ensemble Cross-domain Authorship Attribution: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W2889379006',
#   'Bidirectional Echo State Network-based Reservoir Computing for Cross-domain Authorship Attribution: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W2888920605',
#   'A Parallel Hierarchical Attention Network for Style Change Detection: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W2889010644',
#   'CIC-GIL Approach to Cross-domain Authorship Attribution: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W2889125366',
#   'Dynamic Parameter Search for Cross-Domain Authorship Attribution: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W2889148569',
#   'Cross-Domain Authorship Attribution Based on Compression: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W2889189821',
#   'Detecting a Change of Style using Text Statistics: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W2889230975',
#   'Cross-domain Authorship Attribution: Author Identification using Char Sequences, Word Uni-grams, and POS-tags Features: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W3198121869',
#   'Multi-label Style Change Detection by Solving a Binary Classification Problem.'],
#  ['https://openalex.org/W2888907526',
#   'Character-based Convolutional Neural Network for Style Change Detection: Notebook for PAN at CLEF 2018.'],
#  ['https://openalex.org/W3095923643',
#   'Ensemble Model for Profiling Fake News Spreaders on Twitter.'],
#  ['https://openalex.org/W2964386916',
#   'Classifying German Animal Experiment Summaries with Multi-lingual BERT at CLEF eHealth 2019 Task 1.'],
#  ['https://openalex.org/W3095637798',
#   'A study of Machine Learning models for Clinical Coding of Medical Reports at CodiEsp 2020.'],
#  ['https://openalex.org/W3096252815',
#   'A Study on Reciprocal Ranking Fusion in Consumer Health Search. IMS UniPD ad CLEF eHealth 2020 Task 2.'],
#  ['https://openalex.org/W2965220465',
#   'A Distributed Effort Approach for Systematic Reviews. IMS Unipd At CLEF 2019 eHealth Task 2.'],
#  ['https://openalex.org/W2964548917',
#   'MLT-DFKI at CLEF eHealth 2019: Multi-label Classification of ICD-10 Codes with BERT.'],
#  ['https://openalex.org/W2964386916',
#   'Classifying German Animal Experiment Summaries with Multi-lingual BERT at CLEF eHealth 2019 Task 1.'],
#  ['https://openalex.org/W2889458578',
#   'ImageCLEF 2018: Lesion-based TB-descriptor for CT Image Analysis.'],
#  ['https://openalex.org/W2964674803',
#   'Feature and Deep Learning Based Approaches for Automatic Report Generation and Severity Scoring of Lung Tuberculosis from CT Images.'],
#  ['https://openalex.org/W2966350651',
#   'ImageCLEF 2019: Deep Learning for Tuberculosis CT Image Analysis.'],
#  ['https://openalex.org/W2966837926',
#   'ImageCLEFmed Tuberculosis 2019: Predicting CT Scans Severity Scores using Stage-Wise Boosting in Low-Resource Environments.'],
#  ['https://openalex.org/W2889504173',
#   'Feature-Based Approach for Severity Scoring of Lung Tuberculosis from CT Images.'],
#  ['https://openalex.org/W3096938098',
#   'Overview of the VQA-Med Task at ImageCLEF 2020: Visual Question Answering and Generation in the Medical Domain.'],
#  ['https://openalex.org/W3095461034',
#   'AIML at VQA-Med 2020: Knowledge inference via a skeleton-based sentence mapping approach for medical domain visual question answering'],
#  ['https://openalex.org/W3094735822',
#   'The Inception Team at VQA-Med 2020: Pretrained VGG with Data Augmentation for Medical VQA and VQG.'],
#  ['https://openalex.org/W3096105091',
#   'NLM at VQA-Med 2020: Visual Question Answering and Generation in the Medical Domain.'],
#  ['https://openalex.org/W2889015686',
#   'Overview of ImageCLEF 2018 Medical Domain Visual Question Answering Task.'],
#  ['https://openalex.org/W2965314216',
#   'An Encoder-Decoder Model for Visual Question Answering in the Medical Domain.'],
#  ['https://openalex.org/W3095461034',
#   'AIML at VQA-Med 2020: Knowledge inference via a skeleton-based sentence mapping approach for medical domain visual question answering'],
#  ['https://openalex.org/W3095461034',
#   'AIML at VQA-Med 2020: Knowledge inference via a skeleton-based sentence mapping approach for medical domain visual question answering'],
#  ['https://openalex.org/W3096105091',
#   'NLM at VQA-Med 2020: Visual Question Answering and Generation in the Medical Domain.'],
#  ['https://openalex.org/W2966743415',
#   'Automated Lifelog Moment Retrieval based on Image Segmentation and Similarity Scores.'],
#  ['https://openalex.org/W2889200385',
#   'Overview of ImageCLEFtuberculosis 2018 - Detecting Multi-Drug Resistance, Classifying Tuberculosis Types and Assessing Severity Scores.'],
#  ['https://openalex.org/W2964674803',
#   'Feature and Deep Learning Based Approaches for Automatic Report Generation and Severity Scoring of Lung Tuberculosis from CT Images.'],
#  ['https://openalex.org/W2889200385',
#   'Overview of ImageCLEFtuberculosis 2018 - Detecting Multi-Drug Resistance, Classifying Tuberculosis Types and Assessing Severity Scores.'],
#  ['https://openalex.org/W3095293733',
#   'UAIC2020: Lung Analysis for Tuberculosis Detection.'],
#  ['https://openalex.org/W2966743415',
#   'Automated Lifelog Moment Retrieval based on Image Segmentation and Similarity Scores.'],
#  ['https://openalex.org/W2964911883',
#   'A Multimedia Modular Approach to Lifelog Moment Retrieval.'],
#  ['https://openalex.org/W2889200385',
#   'Overview of ImageCLEFtuberculosis 2018 - Detecting Multi-Drug Resistance, Classifying Tuberculosis Types and Assessing Severity Scores.'],
#  ['https://openalex.org/W2966664333',
#   'ImageCLEF2019: Tuberculosis - Severity Scoring and CT Report with Neural Networks, Transfer Learning and Ensembling.'],
#  ['https://openalex.org/W3095293733',
#   'UAIC2020: Lung Analysis for Tuberculosis Detection.'],
#  ['https://openalex.org/W2965314216',
#   'An Encoder-Decoder Model for Visual Question Answering in the Medical Domain.'],
#  ['https://openalex.org/W2966593387',
#   'ZJUTCVR Team at ImageCLEFlifelog2019 Lifelog Moment Retrieval Task.'],
#  ['https://openalex.org/W2889200385',
#   'Overview of ImageCLEFtuberculosis 2018 - Detecting Multi-Drug Resistance, Classifying Tuberculosis Types and Assessing Severity Scores.'],
#  ['https://openalex.org/W2965490408',
#   'ImageSem at ImageCLEFmed Caption 2019 Task: a Two-stage Medical Concept Detection Strategy.'],
#  ['https://openalex.org/W3095854630',
#   'AUEB NLP Group at ImageCLEFmed Caption 2020.'],
#  ['https://openalex.org/W2965795432',
#   'AUEB NLP Group at ImageCLEFmed Caption 2019.'],
#  ['https://openalex.org/W3097441936',
#   'ImageCLEF 2020: Image Caption Prediction using Multilabel Convolutional Neural Network.'],
#  ['https://openalex.org/W3095365742', 'Essex at ImageCLEFcaption 2020 Task.'],
#  ['https://openalex.org/W3096010625',
#   'Organiser Team at ImageCLEFlifelog 2020: A Baseline Approach for Moment Retrieval and Athlete Performance Prediction using Lifelog Data.'],
#  ['https://openalex.org/W2889243425',
#   'Overview of the CLEF 2018 Personalised Information Retrieval Lab (PIR-CLEF 2018).'],
#  ['https://openalex.org/W3096283493',
#   'Early Mental Health Risk Assessment through Writing Styles, Topics and Neural Models.'],
#  ['https://openalex.org/W2965168687',
#   'Early Risk Prediction by means of DeepLearning.'],
#  ['https://openalex.org/W2965168687',
#   'Early Risk Prediction by means of DeepLearning.'],
#  ['https://openalex.org/W3197754921',
#   'UPV-Symanto at eRisk 2021: Mental Health Author Profiling for Early Risk Prediction on the Internet.'],
#  ['https://openalex.org/W3197754921',
#   'UPV-Symanto at eRisk 2021: Mental Health Author Profiling for Early Risk Prediction on the Internet.'],
#  ['https://openalex.org/W2965168687',
#   'Early Risk Prediction by means of DeepLearning.'],
#  ['https://openalex.org/W2965681520',
#   'Neural Weakly Supervised Fact Check-Worthiness Detection with Contrastive Sampling-Based Ranking Loss.'],
#  ['https://openalex.org/W3197758567',
#   'TOBB ETU at CheckThat! 2021: Data Engineering for Detecting Check-Worthy Claims.'],
#  ['https://openalex.org/W2965681520',
#   'Neural Weakly Supervised Fact Check-Worthiness Detection with Contrastive Sampling-Based Ranking Loss.'],
#  ['https://openalex.org/W2966728082',
#   'TOBB-ETU at CLEF 2019: Prioritizing Claims Based on Check-Worthiness.'],
#  ['https://openalex.org/W3197758567',
#   'TOBB ETU at CheckThat! 2021: Data Engineering for Detecting Check-Worthy Claims.'],
#  ['https://openalex.org/W2186783922',
#   'University of Hagen at GeoCLEF 2007: Exploring Location Indicators for Geographic Information Retrieval'],
#  ['https://openalex.org/W2100808887',
#   'TALP at GeoCLEF 2007: Using Terrier with Geographical Knowledge Filtering.'],
#  ['https://openalex.org/W2109849772',
#   'GIR experiements with Forostar at GeoCLEF 2007'],
#  ['https://openalex.org/W2124926405',
#   'Exploring Image, Text and Geographic Evidences in ImageCLEF 2007'],
#  ['https://openalex.org/W2182519998', 'SINAI at ImageCLEF 2007'],
#  ['https://openalex.org/W2915812099', 'SINAI at ImageCLEF 2006.'],
#  ['https://openalex.org/W2187266683',
#   'Query and Document Translation by Automatic Text Categorization: A Simple Approach to Establish a Strong Textual Baseline for ImageCLEFmed 2006'],
#  ['https://openalex.org/W2149879563',
#   "XRCE's Participation to ImageCLEFphoto 2007"],
#  ['https://openalex.org/W2131142985',
#   "TIA-INAOE's Participation at ImageCLEF 2007"],
#  ['https://openalex.org/W2406716792',
#   'Experiment for Using Web Information to do Query and Document Expansion.'],
#  ['https://openalex.org/W1480097573',
#   'TIA-INAOE Participation at ImageCLEF 2008.'],
#  ['https://openalex.org/W2149879563',
#   "XRCE's Participation to ImageCLEFphoto 2007"],
#  ['https://openalex.org/W2097891119',
#   'MMIS at ImageCLEF 2008: Experiments combining Different Evidence Sources.'],
#  ['https://openalex.org/W2131142985',
#   "TIA-INAOE's Participation at ImageCLEF 2007"],
#  ['https://openalex.org/W1480097573',
#   'TIA-INAOE Participation at ImageCLEF 2008.'],
#  ['https://openalex.org/W2401296811',
#   'Taking Benefit of Query and Document Expansion using MeSH Descriptors in Medical ImageCLEF 2009.'],
#  ['https://openalex.org/W2189165525',
#   'Text-only Cross-language Image Search at Medical ImageCLEF 2008.'],
#  ['https://openalex.org/W2398153903',
#   'First Participation of University and Hospitals of Geneva to Domain-Specific Track in CLEF 2008.'],
#  ['https://openalex.org/W2131142985',
#   "TIA-INAOE's Participation at ImageCLEF 2007"],
#  ['https://openalex.org/W2117408723', 'FIRE in ImageCLEF 2007.'],
#  ['https://openalex.org/W2402984650',
#   'Mining the Behaviour of Users in a Multilingual Information Access Task.'],
#  ['https://openalex.org/W2402984650',
#   'Mining the Behaviour of Users in a Multilingual Information Access Task.'],
#  ['https://openalex.org/W2401618487',
#   'The Importance of being Grid: Chemnitz University of Technology at Grid@CLEF.'],
#  ['https://openalex.org/W2398031737',
#   'Domain-Specific Cross Language Retrieval: Comparing and Merging Structured and Unstructured Indices.'],
#  ['https://openalex.org/W2152458240',
#   'REINA at CLEF 2009 Robust-WSD Task: Partial Use of WSD Information for Retrieval'],
#  ['https://openalex.org/W2915150011',
#   'CACAO PROJECT AT THE TEL@CLEF 2008 TASK'],
#  ['https://openalex.org/W2182893956',
#   'CELI participation at ImageCLEF 2006: Comparison with the Ad-hoc track'],
#  ['https://openalex.org/W1809553506',
#   'Bengali and Hindi to English Cross-language Text Retrieval under Limited Resources'],
#  ['https://openalex.org/W2104692102',
#   'IIIT Hyderabad at CLEF 2007 - Adhoc Indian Language CLIR task'],
#  ['https://openalex.org/W2915152463',
#   'The University of Lisbon at GeoCLEF 2007'],
#  ['https://openalex.org/W2402050558',
# ...
#   'UPF’s participation at the CLEF eRisk 2018: early risk prediction on the Internet'],
#  ['https://openalex.org/W2187630128',
#   'BossaNova at ImageCLEF 2012 Flickr Photo Annotation Task'],
#  ['https://openalex.org/W2296138661',
#   'MIL at ImageCLEF 2013: Scalable System for Image Annotation'],
#  ['https://openalex.org/W2184093099',
#   'KIDS-NUTN at ImageCLEF 2012 Photo Annotation and Retrieval Task'],
#  ['https://openalex.org/W2294894353',
#   'The participation of IntermidiaLab at the ImageCLEF 2012 Photo Annotation Task'],
#  ['https://openalex.org/W2295162216',
#   'Visual Concept Features and Textual Expansion in a Multimodal System for Concept Annotation and Retrieval with Flickr Photos at ImageCLEF2012'],
#  ['https://openalex.org/W2396922316',
#   'UAIC participation at ImageCLEF 2012 Photo Annotation Task'],
#  ['https://openalex.org/W2403531298',
#   'Applying LDA in contextual image retrieval ReDCAD participation at ImageCLEF Flickr Photo Retrieval 2012'],
#  ['https://openalex.org/W1988287859',
#   'Sabanci-Okan system at imageclef 2013 plant identification competition'],
#  ['https://openalex.org/W2242365488',
#   'Sabanci-Okan system in LifeCLEF 2015 plant identification competition'],
#  ['https://openalex.org/W2296185138',
#   'Maestra at LifeCLEF 2014 Plant Task: Plant Identification using Visual Data.'],
#  ['https://openalex.org/W2294640400',
#   'IFSC/USP at ImageCLEF 2011: Plant identication task'],
#  ['https://openalex.org/W2187223183',
#   'Overview of the ImageCLEF 2012 Flickr Photo Annotation and Retrieval Task'],
#  ['https://openalex.org/W2187223183',
#   'Overview of the ImageCLEF 2012 Flickr Photo Annotation and Retrieval Task'],
#  ['https://openalex.org/W2187223183',
#   'Overview of the ImageCLEF 2012 Flickr Photo Annotation and Retrieval Task'],
#  ['https://openalex.org/W2187223183',
#   'Overview of the ImageCLEF 2012 Flickr Photo Annotation and Retrieval Task'],
#  ['https://openalex.org/W2401714993',
#   'REGIMRobvid: Objects and Scenes Detection for Robot Vision 2013.'],
#  ['https://openalex.org/W2404341878',
#   'Regimvid at ImageCLEF 2015 Scalable Concept Image Annotation Task: Ontology based Hierarchical Image Annotation'],
#  ['https://openalex.org/W2187223183',
#   'Overview of the ImageCLEF 2012 Flickr Photo Annotation and Retrieval Task'],
#  ['https://openalex.org/W2294540220',
#   'URJC&UNED at ImageCLEF 2013 Photo Annotation Task.'],
#  ['https://openalex.org/W2187223183',
#   'Overview of the ImageCLEF 2012 Flickr Photo Annotation and Retrieval Task'],
#  ['https://openalex.org/W2187223183',
#   'Overview of the ImageCLEF 2012 Flickr Photo Annotation and Retrieval Task'],
#  ['https://openalex.org/W2187223183',
#   'Overview of the ImageCLEF 2012 Flickr Photo Annotation and Retrieval Task'],
#  ['https://openalex.org/W2294540220',
#   'URJC&UNED at ImageCLEF 2013 Photo Annotation Task.'],
#  ['https://openalex.org/W2403819561',
#   'BTU DBIS at ImageCLEF2013 Plant Identification Task.'],
#  ['https://openalex.org/W2403351442',
#   "BTU DBIS' Personal Photo Retrieval Runs at ImageCLEF 2013."],
#  ['https://openalex.org/W2295831062',
#   'Efficient instance-based fish species visual identification by global representation'],
#  ['https://openalex.org/W2189209245',
#   'FCSE at Medical Tasks of ImageCLEF 2013'],
#  ['https://openalex.org/W2293226064',
#   "ITI's Participation in the 2013 Medical Track of ImageCLEF"],
#  ['https://openalex.org/W2405447308',
#   'Using the Divergence Framework for Randomness: CHiC 2013 Lab Report.'],
#  ['https://openalex.org/W2293138554', 'UniNE at CLEF - CHiC 2013.'],
#  ['https://openalex.org/W2404143171',
#   'Cultural Heritage in CLEF (CHiC) 2013 - Multilingual Task Overview.'],
#  ['https://openalex.org/W2404280607',
#   'Identifying the most suitable stemmer for the CHiC multilingual ad-hoc task'],
#  ['https://openalex.org/W2402769614',
#   'REINA at RepLab2013 Topic Detection Task: Community Detection.'],
#  ['https://openalex.org/W2185044903', 'FBM-Yahoo! at RepLab 2012'],
#  ['https://openalex.org/W2291397378', 'UNED at RepLab 2012: Monitoring Task.'],
#  ['https://openalex.org/W2397707338',
#   'USTB at INEX2014: Social Book Search Track'],
#  ['https://openalex.org/W2188264586',
#   'Social Feature Re-ranking in INEX 2013 Social Book Search Track'],
#  ['https://openalex.org/W2578368441',
#   'USTB at Social Book Search 2016 Suggestion Task: Active Books Set and Re-ranking.'],
#  ['https://openalex.org/W2295241886',
#   'USTB at Social Book Search 2015 Suggestion Task: Metadata Expansion and Reranking.'],
#  ['https://openalex.org/W2296053451',
#   "SOCIAL BOOK SEARCH TRACK: ISM@INEX'14 SUGGESTION TASK"],
#  ['https://openalex.org/W2394732248', 'A Methodology for Social Book Search.'],
#  ['https://openalex.org/W2395124225',
#   'Integrating Social Features and Query Type Recognition in the Suggestion Track of CLEF 2015 Social Book Search Lab.'],
#  ['https://openalex.org/W2407111306',
#   'A Pipeline Tweet Contextualization System at INEX 2013.'],
#  ['https://openalex.org/W2295492055',
#   'INEX2014: Tweet Contextualization Using Association Rules between Terms'],
#  ['https://openalex.org/W2407111306',
#   'A Pipeline Tweet Contextualization System at INEX 2013.'],
#  ['https://openalex.org/W2407111306',
#   'A Pipeline Tweet Contextualization System at INEX 2013.'],
#  ['https://openalex.org/W2398102415',
#   'Tweet Contextualization: a Strategy Based on Document Retrieval Using Query Enrichment and Automatic Summarization.'],
#  ['https://openalex.org/W2915108564',
#   'Overview of QA4MRE at CLEF 2012: Question Answering for Machine Reading Evaluation'],
#  ['https://openalex.org/W2915108564',
#   'Overview of QA4MRE at CLEF 2012: Question Answering for Machine Reading Evaluation'],
#  ['https://openalex.org/W2396044781',
#   'Question Answering System for Entrance Exams in QA4MRE.'],
#  ['https://openalex.org/W2406927329',
#   'An Automatic System for Modality and Negation Detection.'],
#  ['https://openalex.org/W2399497040',
#   'Tweet Contextualization (Answering Tweet Question) - the Role of Multi-document Summarization.'],
#  ['https://openalex.org/W2295760158',
#   'Two Approaches for QA4MRE: Information Retrieval and Graph-based knowledge representation'],
#  ['https://openalex.org/W2915108564',
#   'Overview of QA4MRE at CLEF 2012: Question Answering for Machine Reading Evaluation'],
#  ['https://openalex.org/W2396044781',
#   'Question Answering System for Entrance Exams in QA4MRE.'],
#  ['https://openalex.org/W2397508834',
#   'Using Anaphora resolution in a Question Answering system for Machine Reading Evaluation'],
#  ['https://openalex.org/W2965175830', 'CheckThat! 2019 UAICS.'],
#  ['https://openalex.org/W2915108564',
#   'Overview of QA4MRE at CLEF 2012: Question Answering for Machine Reading Evaluation'],
#  ['https://openalex.org/W2915108564',
#   'Overview of QA4MRE at CLEF 2012: Question Answering for Machine Reading Evaluation'],
#  ['https://openalex.org/W2915108564',
#   'Overview of QA4MRE at CLEF 2012: Question Answering for Machine Reading Evaluation'],
#  ['https://openalex.org/W2915108564',
#   'Overview of QA4MRE at CLEF 2012: Question Answering for Machine Reading Evaluation'],
#  ['https://openalex.org/W2186320763',
#   'Building Optimal Question Answering System Automatically using Configuration Space Exploration (CSE) for QA4MRE 2013 Tasks.'],
#  ['https://openalex.org/W2296753911',
#   'Report on the CLEF-IP 2013 Experiments: Multilayer Collection Selection on Topically Organized Patents'],
#  ['https://openalex.org/W2406451213',
#   'An Overview of the Traditional Authorship Attribution Subtask.'],
#  ['https://openalex.org/W2407476599',
#   'Authorship Verification with Compression Features.'],
#  ['https://openalex.org/W2136050570',
#   'Overview of the International Sexual Predator Identification Competition at PAN-2012.'],
#  ['https://openalex.org/W2396323302',
#   'Grammar Checker Features for Author Identification and Author Profiling Notebook for PAN at CLEF 2013'],
#  ['https://openalex.org/W2294180820',
#   'Know-Center at PAN 2015 author identification Notebook for PAN at CLEF 2015'],
#  ['https://openalex.org/W2136050570',
#   'Overview of the International Sexual Predator Identification Competition at PAN-2012.'],
#  ['https://openalex.org/W2136050570',
#   'Overview of the International Sexual Predator Identification Competition at PAN-2012.'],
#  ['https://openalex.org/W2753766265',
#   'CLEF 2017 eRisk Overview: Early Risk Prediction on the Internet: Experimental Foundations.'],
#  ['https://openalex.org/W2136050570',
#   'Overview of the International Sexual Predator Identification Competition at PAN-2012.'],
#  ['https://openalex.org/W2401918981',
#   'A Basic Character N-gram Approach to Authorship Verification Notebook for PAN at CLEF 2013.'],
#  ['https://openalex.org/W2136050570',
#   'Overview of the International Sexual Predator Identification Competition at PAN-2012.'],
#  ['https://openalex.org/W2398763698',
#   "A Textual Modus Operandi: Surrey's Simple System for Author Identification Notebook for PAN at CLEF 2013."],
#  ['https://openalex.org/W2407092985',
#   "A Trinity of Trials: Surrey's 2014 Attempts at Author Verification."],
#  ['https://openalex.org/W2399268477',
#   'Readability for Author Profiling? Notebook for PAN at CLEF 2013.'],
#  ['https://openalex.org/W2398068589',
#   'Adapting for Subject-Specific Term Length using Topic Cost in Author Verification - Notebook for PAN at CLEF 2015'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2400478366',
#   'Heterogeneous Queries for Synoptic and Phrasal Search'],
#  ['https://openalex.org/W2395614926',
#   'Diverse queries and feature type selection for plagiarism discovery: Notebook for PAN at CLEF 2013'],
#  ['https://openalex.org/W2396655261',
#   'Using a Variety of n-Grams for the Detection of Different Kinds of Plagiarism Notebook for PAN at CLEF 2013.'],
#  ['https://openalex.org/W2402211003',
#   'Improving Synoptic Quering for Source Retrieval: Notebook for PAN at CLEF 2015.'],
#  ['https://openalex.org/W2293853475',
#   'Overview of the 1st International Competition on Quality Flaw Prediction in Wikipedia'],
#  ['https://openalex.org/W132616547', 'Report on CLEF-2001 Experiments.'],
#  ['https://openalex.org/W2889004469',
#   'Miracl at CLEF 2018 : Consumer Health Search Task.'],
#  ['https://openalex.org/W2295924316',
#   'Miracl at Clef 2015 : User-Centred Health Information Retrieval Task'],
#  ['https://openalex.org/W2296510182',
#   'Automatic Annotation of Liver CT Images: the Submission of the BMET Group to ImageCLEFmed 2014'],
#  ['https://openalex.org/W2401501349',
#   'Liver CT Annotation via Generalized Coupled Tensor Factorization.'],
#  ['https://openalex.org/W2296096075',
#   'Automatic Annotation of Liver CT Image: ImageCLEFmed 2015'],
#  ['https://openalex.org/W2395282059',
#   'Assembling Heterogeneous Domain Adaptation Methods for Image Classification.'],
#  ['https://openalex.org/W2296626982',
#   'Using Textual and Visual Processing in Scalable Concept Image Annotation Challenge'],
#  ['https://openalex.org/W2753544948',
#   'News Recommender System based on Association Rules @ CLEF NewsREEL 2017.'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2396176393',
#   'The Short Stories Corpus: Notebook for PAN at CLEF 2015.'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2293679225',
#   'Towards Data Submissions for Shared Tasks: First Experiences for the Task of Text Alignment ?'],
#  ['https://openalex.org/W2402211003',
#   'Improving Synoptic Quering for Source Retrieval: Notebook for PAN at CLEF 2015.'],
#  ['https://openalex.org/W2394650926',
#   'Homotopy Based Classification for Author Verification Task: Notebook for PAN at CLEF 2015.'],
#  ['https://openalex.org/W2394650926',
#   'Homotopy Based Classification for Author Verification Task: Notebook for PAN at CLEF 2015.'],
#  ['https://openalex.org/W3097592856',
#   'A Deep Learning Model to Predict Gender, Age and Occupation of the Celebrities based on Tweets Followers.'],
#  ['https://openalex.org/W2401347463',
#   'Author Profiling of Twitter Users: Notebook for PAN at CLEF 2015.'],
#  ['https://openalex.org/W2401347463',
#   'Author Profiling of Twitter Users: Notebook for PAN at CLEF 2015.'],
#  ['https://openalex.org/W2403729121',
#   'QAnswer - Enhanced Entity Matching for Question Answering over Linked Data.'],
#  ['https://openalex.org/W2403393286',
#   'The Fudan Participation in the 2015 BioASQ Challenge: Large-scale Biomedical Semantic Indexing and Question Answering'],
#  ['https://openalex.org/W2394742672',
#   'AUTH-Atypon at BioASQ 3: Large-Scale Semantic Indexing in Biomedicine.'],
#  ['https://openalex.org/W3097055670',
#   'Overview of BioASQ 8a and 8b: Results of the Eighth Edition of the BioASQ Tasks a and b.'],
#  ['https://openalex.org/W2296305699',
#   'Reading comprehension at Entrance Exams 2015'],
#  ['https://openalex.org/W3095005514',
#   'Named Entity Recognition in Chemical Patents using Ensemble of Contextual Language Models.'],
#  ['https://openalex.org/W3095525213',
#   'Overview of Automatic Clinical Coding: Annotations, Guidelines, and Solutions for non-English Clinical Cases at CodiEsp Track of CLEF eHealth 2020.'],
#  ['https://openalex.org/W3197811249',
#   'VADER meets BERT: sentiment analysis for early detection of signs of self-harm through social mining.'],
#  ['https://openalex.org/W3096599108',
#   'SZTAKI @ ImageCLEFmed 2020 Tuberculosis Task.'],
#  ['https://openalex.org/W3198320563',
#   'Contrastive Representation Learning for Natural World Imagery: Habitat prediction for 30, 000 species.'],
#  ['https://openalex.org/W3198371010',
#   'UAIC-AI at SnakeCLEF 2021: Impact of convolutions in snake species recognition.'],
#  ['https://openalex.org/W3197294601',
#   'TUC Media Computing at BIRDCLEF 2021: Noise augmentation strategies in bird sound classification in combination with DenseNets and ResNets.'],
#  ['https://openalex.org/W3198122208',
#   'Profiling Hate Speech Spreaders on Twitter Task at PAN 2021.'],
#  ['https://openalex.org/W3095197266',
#   'An Ensemble Model Using N-grams and Statistical Features to Identify Fake News Spreaders on Twitter.'],
#  ['https://openalex.org/W3095923643',
#   'Ensemble Model for Profiling Fake News Spreaders on Twitter.'],
#  ['https://openalex.org/W3096688232',
#   'Detecting Fake News Spreaders on Twitter Using Universal Sentence Encoder.'],
#  ['https://openalex.org/W3095621011',
#   'UniNE at PAN-CLEF 2020: Profiling Fake News Spreaders on Twitter.'],
#  ['https://openalex.org/W3096848822',
#   'A BERT based Two-stage Fake News Spreader Profiling System.'],
#  ['https://openalex.org/W3196715916',
#   'Profiling Hate Speech Spreaders on Twitter.'],
#  ['https://openalex.org/W3196851571',
#   'Hate speech spreader detection using contextualized word embeddings.'],
#  ['https://openalex.org/W3197781543',
#   'Profiling Hate Speech Spreaders on Twitter.'],
#  ['https://openalex.org/W3197952119',
#   'Profiling Spreaders of Hate Speech with N-grams and RoBERTa.'],
#  ['https://openalex.org/W3198044570',
#   'Profiling Hate Speech Spreaders on Twitter.'],
#  ['https://openalex.org/W3198868317',
#   'Profiling Hate Speech Spreaders using Characters andWords N-grams.'],
#  ['https://openalex.org/W2578890806',
#   'CAPS: A Cross-genre Author Profiling System.'],
#  ['https://openalex.org/W3196334678',
#   'COLE and LYS at BioASQ MESINESP Task: large scale multilabel text categorization with sparse and dense indices.'],
#  ['https://openalex.org/W3095583815',
#   'CoLe and LYS at BioASQ MESINESP8 Task: Similarity based Descriptor Assigment in Spanish.'],
#  ['https://openalex.org/W2578779760',
#   'Individual Differences and Task Behaviour'],
#  ['https://openalex.org/W2889340760',
#   'A Big Data approach to gender classification in Twitter: Notebook for PAN at CLEF 2018.'],
#  ...]

# %%
# Read the manually curated list of Overview paper title

file_name = "../../../data/CEUR_Overview_titles.txt"

overview_paper_ceur = []

with open(file_name, 'r', encoding='utf-8') as file:
    overview_paper_ceur = [line.strip() for line in file]

# %%
with open("../../../data/OpenAlex_CEUR.json", 'r', encoding="utf-8") as file:
    OpenAlexCitations_CEUR = json.load(file)

# %%
threshold = 70

comparison_list = []
for key,value in OpenAlexCitations_CEUR.items():
    for i in overview_paper_ceur:
        if fuzz.ratio(value["title"], i) >= threshold:
            if [value["id"], value["title"]] not in comparison_list:
                comparison_list.append([value["id"], value["title"]])

# %%
len(comparison_list)
# Out:
# 400

# %%
# Threshold for fuzzy-matching
threshold = 90
count_matches = 0

for id1, title1 in ceur_citing_docs:
    for id2, title2 in comparison_list:
        if id1 == id2 or fuzz.ratio(title1, title2) >= threshold:
            count_matches += 1
            break

print(f"Amount of Overlap: {count_matches}")
# Out:
# Amount of Overlap: 277

# %%
# Threshold for fuzzy-matching
threshold = 90
count_matches = 0

for id1, title1 in ceur_citing_docs:
    for id2, title2 in comparison_list:
        if id1 == id2:
            count_matches += 1
            break

print(f"Amount of Overlap: {count_matches}")
# Out:
# Amount of Overlap: 271

# %%
count_matches
# Out:
# 271

# %% [markdown]
# ## Analying self-citation by Overview Papers (LNCS)

# %%
lncs_citing_docs = []
for i in df_lncs_journals["conferences"]:
    for j in i:
        lncs_citing_docs.append(j)

# %%
# Read the manually curated list of Overview paper title

file_name = "../../../data/LNCS_Overview_titles.txt"

overview_paper_lncs = []

with open(file_name, 'r', encoding='utf-8') as file:
    overview_paper_lncs = [line.strip() for line in file]

# %%
with open("../../../data/OpenAlex_LNCS.json", 'r', encoding="utf-8") as file:
    OpenAlexCitations_LNCS = json.load(file)

# %%
threshold = 70

comparison_list = []
for key,value in OpenAlexCitations_LNCS.items():
    for i in overview_paper_lncs:
        if fuzz.ratio(value["title"], i) >= threshold:
            if [value["id"], value["title"]] not in comparison_list:
                comparison_list.append([value["id"], value["title"]])

# %%
# Threshold for fuzzy-matching
threshold = 70
count_matches = 0

for id1, title1 in lncs_citing_docs:
    for id2, title2 in comparison_list:
        if id1 == id2 or fuzz.ratio(title1, title2) >= threshold:
            count_matches += 1
            break

print(f"Amount of Overlap: {count_matches}")
# Out:
# Amount of Overlap: 2

# %%
# Threshold for fuzzy-matching
threshold = 70
count_matches = 0

for id1, title1 in lncs_citing_docs:
    for id2, title2 in comparison_list:
        if id1 == id2:
            count_matches += 1
            break

print(f"Amount of Overlap: {count_matches}")
# Out:
# Amount of Overlap: 0

# %% [markdown]
# ## Analying self-citation by Overview Papers (TREC)

# %%
trec_citing_docs = []
for i in df_trec_journals["conferences"]:
    for j in i:
        trec_citing_docs.append(j)

# %%
# Read the manually curated list of Overview paper title

file_name = "../../../data/TREC_Overview_titles.txt"

overview_paper_trec = []

with open(file_name, 'r', encoding='utf-8') as file:
    overview_paper_trec = [line.strip() for line in file]

# %%
with open("../../../data/OpenAlex_TREC.json", 'r', encoding="utf-8") as file:
    OpenAlexCitations_TREC = json.load(file)

# %%
threshold = 70

comparison_list = []
for key,value in OpenAlexCitations_TREC.items():
    for i in overview_paper_trec:
        if fuzz.ratio(value["title"], i) >= threshold:
            if [value["id"], value["title"]] not in comparison_list:
                comparison_list.append([value["id"], value["title"]])

# %%
# Threshold for fuzzy-matching
threshold = 70
count_matches = 0

for id1, title1 in trec_citing_docs:
    for id2, title2 in comparison_list:
        if id1 == id2 or fuzz.ratio(title1, title2) >= threshold:
            count_matches += 1
            break

print(f"Amount of Overlap: {count_matches}")
# Out:
# Amount of Overlap: 447

# %%
# Threshold for fuzzy-matching
threshold = 70
count_matches = 0

for id1, title1 in trec_citing_docs:
    for id2, title2 in comparison_list:
        if id1 == id2:
            count_matches += 1
            break

print(f"Amount of Overlap: {count_matches}")
# Out:
# Amount of Overlap: 268
