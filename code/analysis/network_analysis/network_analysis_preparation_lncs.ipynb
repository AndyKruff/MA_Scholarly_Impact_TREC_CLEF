# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
df_lncs = pd.read_parquet("../../../data/metadata_LNCS.parquet")
df_lncs.loc[df_lncs['ID'] == "lncs_649", 'Section'] = "CLEF at SemEval 2007"

# %%
# Read iso file to resolve country name abbrevations

with open("../../../data/iso3166-1.json", 'r', encoding="utf-8") as file:
    Country_codes = json.load(file)


country_codes_new = {}
for i in Country_codes["3166-1"]:
    country_codes_new[i["alpha_2"]] = i["name"]

# %%
# Extract metadata informations from OpenAlex regarding author names, institution names and location of the institution

def calculate_most_active_countries_institutions(country_codes_dict,df,path):
    with open(path, 'r', encoding="utf-8") as file:
        OpenAlexJson = json.load(file)

    countries_list = []
    for i in OpenAlexJson:
        country_codes = []
        institutions = []
        for j in OpenAlexJson[i]["authorships"]:
            for k in j["institutions"]:
                if k["country_code"] is not None and k["display_name"] is not None:
                    if [country_codes_new[k["country_code"]], k["display_name"], j["author"]["display_name"]] not in country_codes:
                        country_codes.append([country_codes_new[k["country_code"]], k["display_name"], j["author"]["display_name"]])
        countries_list.append([i, country_codes])

    df_countries = pd.DataFrame(countries_list, columns=["ID", "Countries"])
    df = pd.merge(df, df_countries, how ="inner", right_on="ID",left_on="ID")
    return df

# %%
df_lncs = calculate_most_active_countries_institutions(country_codes_new, df_lncs, path="../../../data/OpenAlex_LNCS.json" )

# %%
# Create paths to the location of the XML-transformed LNCS PDFs from GROBID

paths = []
for i, j in df_lncs_test.iterrows():
    path = "./resources/XML_LNCS/" + j["Book Subtitle"] + "/" + j["Section"]
    if j["Subsection"] == "Uncategorized":
        path = path + "/" + j["Filename"].replace(".pdf", ".tei.xml")
    else:
        path = path + "/" + j["Section"] + "/" + j["Subsection"] + "/" + j["Filename"].replace(".pdf", ".tei.xml")

    paths.append(path)

# %%
df_lncs["paths"] = paths

# %%
df_lncs
# Out:
#      PubYear                                      Book Subtitle  \
# 0       2005  6th Workshop of the Cross-Language Evaluation ...
# 1       2005  6th Workshop of the Cross-Language Evaluation ...
# 2       2005  6th Workshop of the Cross-Language Evaluation ...
# 3       2005  6th Workshop of the Cross-Language Evaluation ...
# 4       2005  6th Workshop of the Cross-Language Evaluation ...
# ...      ...                                                ...
# 1220    2013  4th International Conference of the CLEF Initi...
# 1221    2013  4th International Conference of the CLEF Initi...
# 1222    2013  4th International Conference of the CLEF Initi...
# 1223    2013  4th International Conference of the CLEF Initi...
# 1224    2013  4th International Conference of the CLEF Initi...
#
#                                              Book Title  \
# 0       Accessing Multilingual Information Repositories
# 1       Accessing Multilingual Information Repositories
# 2       Accessing Multilingual Information Repositories
# 3       Accessing Multilingual Information Repositories
# 4       Accessing Multilingual Information Repositories
# ...                                                 ...
# 1220  Information Access Evaluation. Multilinguality...
# 1221  Information Access Evaluation. Multilinguality...
# 1222  Information Access Evaluation. Multilinguality...
# 1223  Information Access Evaluation. Multilinguality...
# 1224  Information Access Evaluation. Multilinguality...
#
#                       Filename  \
# 0               11878773_2.pdf
# 1               11878773_3.pdf
# 2               11878773_4.pdf
# 3               11878773_5.pdf
# 4               11878773_6.pdf
# ...                        ...
# 1220  978-3-642-40802-1_28.pdf
# 1221  978-3-642-40802-1_29.pdf
# 1222  978-3-642-40802-1_30.pdf
# 1223  978-3-642-40802-1_31.pdf
# 1224  978-3-642-40802-1_32.pdf
#
#                                                   Title  \
# 0                      CLEF 2005: Ad Hoc Track Overview
# 1     Ad-Hoc Mono- and Bilingual Retrieval Experimen...
# 2     MIRACLE at Ad-Hoc CLEF 2005: Merging and Combi...
# 3           The XLDB Group at the CLEF 2005 Ad-Hoc Task
# 4     Thomson Legal and Regulatory Experiments at CL...
# ...                                                 ...
# 1220  Recent Trends in Digital Text Forensics and It...
# 1221  QA4MRE 2011-2013: Overview of Question Answeri...
# 1222  Multilingual Question Answering over Linked Da...
# 1223  Overview of RepLab 2013: Evaluating Online Rep...
# 1224  Entity Recognition in Parallel Multi-lingual B...
#
#                                                 Section     Subsection  \
# 0     Part I. Multilingual Textual Document Retrival...  Uncategorized
# 1                               Cross-Language and More  Uncategorized
# 2                               Cross-Language and More  Uncategorized
# 3                               Cross-Language and More  Uncategorized
# 4                               Cross-Language and More  Uncategorized
# ...                                                 ...            ...
# 1220                                      Lab Overviews  Uncategorized
# 1221                                      Lab Overviews  Uncategorized
# 1222                                      Lab Overviews  Uncategorized
# 1223                                      Lab Overviews  Uncategorized
# 1224                                      Lab Overviews  Uncategorized
#
#                                                DOI Citation count  \
# 0               https://doi.org/10.1007/11878773_2             17
# 1               https://doi.org/10.1007/11878773_3      Not found
# 2               https://doi.org/10.1007/11878773_4              4
# 3               https://doi.org/10.1007/11878773_5              3
# 4               https://doi.org/10.1007/11878773_6              1
# ...                                            ...            ...
# 1220  https://doi.org/10.1007/978-3-642-40802-1_28             15
# 1221  https://doi.org/10.1007/978-3-642-40802-1_29             13
# 1222  https://doi.org/10.1007/978-3-642-40802-1_30             36
# 1223  https://doi.org/10.1007/978-3-642-40802-1_31             49
# 1224  https://doi.org/10.1007/978-3-642-40802-1_32              9
#
#                                  Authors & Affiliations         ID  \
# 0     [['Department of Information Engineering, Univ...     lncs_2
# 1     [['Information Science, University of Hildeshe...     lncs_3
# 2     [['Universidad Politécnica de Madrid, \xa0', [...     lncs_4
# 3     [['Departamento de Informática, Grupo XLDB, Fa...     lncs_5
# 4     [['Thomson Legal and Regulatory, 610 Opperman ...     lncs_6
# ...                                                 ...        ...
# 1220  [['Web Technology and Information Systems, Bau...  lncs_1339
# 1221  [['NLP&IR Group, UNED, Spain', ['Anselmo Peñas...  lncs_1340
# 1222  [['CITEC, Universität Bielefeld, Germany', ['P...  lncs_1341
# 1223  [['UNED NLP and IR Group, Juan del Rosal, 16, ...  lncs_1342
# 1224  [['Department of Computational Linguistics, Un...  lncs_1343
#
#                                               Countries  \
# 0     [[Italy, University of Padua, Giorgio Maria Di...
# 1     [[Germany, University of Hildesheim, René Hack...
# 2     [[Spain, Universidad Politécnica de Madrid, Jo...
# 3     [[Portugal, University of Lisbon, Nuno Cardoso...
# 4     [[United States, Thomson Reuters (United State...
# ...                                                 ...
# 1220  [[Germany, Bauhaus-Universität Weimar, Tim Gol...
# 1221  [[Spain, National University of Distance Educa...
# 1222  [[Germany, Bielefeld University, Philipp Cimia...
# 1223  [[Spain, National University of Distance Educa...
# 1224  [[Switzerland, University of Zurich, Dietrich ...
#
#                                                   paths
# 0     ./resources/XML_LNCS/6th Workshop of the Cross...
# 1     ./resources/XML_LNCS/6th Workshop of the Cross...
# 2     ./resources/XML_LNCS/6th Workshop of the Cross...
# 3     ./resources/XML_LNCS/6th Workshop of the Cross...
# 4     ./resources/XML_LNCS/6th Workshop of the Cross...
# ...                                                 ...
# 1220  ./resources/XML_LNCS/4th International Confere...
# 1221  ./resources/XML_LNCS/4th International Confere...
# 1222  ./resources/XML_LNCS/4th International Confere...
# 1223  ./resources/XML_LNCS/4th International Confere...
# 1224  ./resources/XML_LNCS/4th International Confere...
#
# [1225 rows x 13 columns]

# %%
from pathlib import Path

# Function to extract the required informations like author names, institutions and corresponding countries to the institutions from the XML-files transformed with GROBID

def extract_authors_info(path):
    authors_info = []
    file_path = Path(path)
    tree = ET.parse(file_path)
    root = tree.getroot()
    ns = {'ns0': 'http://www.tei-c.org/ns/1.0'}

    source_desc_elem = root.find('.//ns0:sourceDesc', namespaces=ns)
    if source_desc_elem is None:
        return authors_info
    
    for author_elem in source_desc_elem.findall('.//ns0:author', namespaces=ns):
        
        # Extract first name and surname of the author
        forename_elem = author_elem.find('./ns0:persName/ns0:forename', namespaces=ns)
        if forename_elem is not None:
            forename = forename_elem.text
        else:
            forename = ""
        
        surname_elem = author_elem.find('./ns0:persName/ns0:surname', namespaces=ns)
        if surname_elem is not None:
            surname = surname_elem.text
        else:
            surname = ""
        
        author_name = f"{forename} {surname}"
        
        for aff_elem in author_elem.findall('./ns0:affiliation', namespaces=ns):
            org_name_elem = aff_elem.find('./ns0:orgName', namespaces=ns)
            if org_name_elem is not None:
                org_name = org_name_elem.text
            else:
                org_name = ""
            address_elem = aff_elem.find('./ns0:address', namespaces=ns)
            if address_elem is not None:
                country_elem = address_elem.find('./ns0:country', namespaces=ns)
                if country_elem is not None and country_elem.text is not None and org_name != "":
                    authors_info.append([country_elem.text, org_name, author_name])
    return authors_info

# %%
import xml.etree.ElementTree as ET

list_metadata_grobid_extract = []

# Extracting the metadata based on the paths 

for i,j in df_lncs.iterrows():
    try:
        author_infos = extract_authors_info(j["paths"])
        list_metadata_grobid_extract.append(author_infos)
    except:
        list_metadata_grobid_extract.append([])
# Out:
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part I. Multilingual Textual Document Retrival (Ad Hoc)\11878773_2.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_3.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_4.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_5.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_6.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_7.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_8.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_9.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_10.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_11.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_12.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_13.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_14.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_15.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_16.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_17.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_18.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Cross-Language and More\11878773_19.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\11878773_20.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\11878773_21.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\11878773_22.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\11878773_23.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\11878773_24.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Information Retrieval (Domain-Specific)\11878773_25.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Information Retrieval (Domain-Specific)\11878773_26.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Information Retrieval (Domain-Specific)\11878773_27.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Information Retrieval (Domain-Specific)\11878773_28.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Information Retrieval (Domain-Specific)\11878773_29.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Information Retrieval (iCLEF)\11878773_30.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Information Retrieval (iCLEF)\11878773_31.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Information Retrieval (iCLEF)\11878773_32.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Information Retrieval (iCLEF)\11878773_33.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Information Retrieval (iCLEF)\11878773_34.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Information Retrieval (iCLEF)\11878773_35.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_36.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_37.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_38.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_39.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_40.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_41.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_42.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_43.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_44.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_45.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_46.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_47.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_48.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_49.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_50.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_51.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_52.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_53.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_54.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_55.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_56.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_57.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_58.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering (QA@CLEF)\11878773_59.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_60.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_61.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_62.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_63.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_64.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_65.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_66.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_67.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_68.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_69.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_70.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_71.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_72.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_73.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_74.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_75.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_76.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_77.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_78.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_79.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_80.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval In Image Collections (ImageCLEF)\11878773_81.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Speech Retrieval (CL-SR)\11878773_82.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Speech Retrieval (CL-SR)\11878773_83.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Speech Retrieval (CL-SR)\11878773_84.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Speech Retrieval (CL-SR)\11878773_85.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Speech Retrieval (CL-SR)\11878773_86.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Speech Retrieval (CL-SR)\11878773_87.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Speech Retrieval (CL-SR)\11878773_88.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VII. Multilingual Web Track (WebCLEF)\11878773_89.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VII. Multilingual Web Track (WebCLEF)\11878773_90.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VII. Multilingual Web Track (WebCLEF)\11878773_91.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VII. Multilingual Web Track (WebCLEF)\11878773_92.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VII. Multilingual Web Track (WebCLEF)\11878773_93.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VII. Multilingual Web Track (WebCLEF)\11878773_94.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VII. Multilingual Web Track (WebCLEF)\11878773_95.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VII. Multilingual Web Track (WebCLEF)\11878773_96.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VII. Multilingual Web Track (WebCLEF)\11878773_97.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VII. Multilingual Web Track (WebCLEF)\11878773_98.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VII. Multilingual Web Track (WebCLEF)\11878773_99.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VII. Multilingual Web Track (WebCLEF)\11878773_100.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VIII. Cross-Language Geographical Retrieval (GeoCLEF)\11878773_101.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VIII. Cross-Language Geographical Retrieval (GeoCLEF)\11878773_102.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VIII. Cross-Language Geographical Retrieval (GeoCLEF)\11878773_103.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VIII. Cross-Language Geographical Retrieval (GeoCLEF)\11878773_104.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VIII. Cross-Language Geographical Retrieval (GeoCLEF)\11878773_105.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VIII. Cross-Language Geographical Retrieval (GeoCLEF)\11878773_106.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VIII. Cross-Language Geographical Retrieval (GeoCLEF)\11878773_107.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VIII. Cross-Language Geographical Retrieval (GeoCLEF)\11878773_108.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VIII. Cross-Language Geographical Retrieval (GeoCLEF)\11878773_109.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VIII. Cross-Language Geographical Retrieval (GeoCLEF)\11878773_110.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Part VIII. Cross-Language Geographical Retrieval (GeoCLEF)\11878773_111.tei.xml
# test
# resources\XML_LNCS\6th Workshop of the Cross-Language Evaluation Forum\Evaluation Issues\11878773_112.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Full Papers\978-3-030-58219-7_1.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Full Papers\978-3-030-58219-7_2.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Full Papers\978-3-030-58219-7_3.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Full Papers\978-3-030-58219-7_4.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Full Papers\978-3-030-58219-7_5.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Short Papers\978-3-030-58219-7_6.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Short Papers\978-3-030-58219-7_7.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Best of CLEF 2019 Labs\978-3-030-58219-7_8.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Best of CLEF 2019 Labs\978-3-030-58219-7_9.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Best of CLEF 2019 Labs\978-3-030-58219-7_10.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Best of CLEF 2019 Labs\978-3-030-58219-7_11.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Best of CLEF 2019 Labs\978-3-030-58219-7_12.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Best of CLEF 2019 Labs\978-3-030-58219-7_13.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\Best of CLEF 2019 Labs\978-3-030-58219-7_14.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\CLEF 2020 Lab Overviews\978-3-030-58219-7_15.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\CLEF 2020 Lab Overviews\978-3-030-58219-7_16.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\CLEF 2020 Lab Overviews\978-3-030-58219-7_17.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\CLEF 2020 Lab Overviews\978-3-030-58219-7_18.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\CLEF 2020 Lab Overviews\978-3-030-58219-7_19.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\CLEF 2020 Lab Overviews\978-3-030-58219-7_20.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\CLEF 2020 Lab Overviews\978-3-030-58219-7_21.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\CLEF 2020 Lab Overviews\978-3-030-58219-7_22.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\CLEF 2020 Lab Overviews\978-3-030-58219-7_23.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\CLEF 2020 Lab Overviews\978-3-030-58219-7_24.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\CLEF 2020 Lab Overviews\978-3-030-58219-7_25.tei.xml
# test
# resources\XML_LNCS\11th International Conference of the CLEF Association\CLEF 2020 Lab Overviews\978-3-030-58219-7_26.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\I: Interactive Cross-Language Retrieval (iCLEF)\978-3-642-15751-6_2.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\I: Interactive Cross-Language Retrieval (iCLEF)\978-3-642-15751-6_3.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\I: Interactive Cross-Language Retrieval (iCLEF)\978-3-642-15751-6_4.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\I: Interactive Cross-Language Retrieval (iCLEF)\978-3-642-15751-6_5.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\II: Cross-Language Retrieval in Image Collections (ImageCLEF)\978-3-642-15751-6_6.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\II: Cross-Language Retrieval in Image Collections (ImageCLEF)\978-3-642-15751-6_7.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\II: Cross-Language Retrieval in Image Collections (ImageCLEF)\978-3-642-15751-6_8.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\II: Cross-Language Retrieval in Image Collections (ImageCLEF)\978-3-642-15751-6_9.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\II: Cross-Language Retrieval in Image Collections (ImageCLEF)\978-3-642-15751-6_10.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\II: Cross-Language Retrieval in Image Collections (ImageCLEF)\978-3-642-15751-6_11.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFPhoto\978-3-642-15751-6_12.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFPhoto\978-3-642-15751-6_13.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFPhoto\978-3-642-15751-6_14.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFPhoto\978-3-642-15751-6_15.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFPhoto\978-3-642-15751-6_16.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFPhoto\978-3-642-15751-6_17.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFwiki\978-3-642-15751-6_18.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFwiki\978-3-642-15751-6_19.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFwiki\978-3-642-15751-6_20.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFwiki\978-3-642-15751-6_21.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFmed\978-3-642-15751-6_22.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFmed\978-3-642-15751-6_23.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFmed\978-3-642-15751-6_24.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFmed\978-3-642-15751-6_25.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFmed\978-3-642-15751-6_26.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFmed\978-3-642-15751-6_27.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFmed Annotation\978-3-642-15751-6_28.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFmed Annotation\978-3-642-15751-6_29.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEFmed Annotation\978-3-642-15751-6_30.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Annotation and Robot Vision\978-3-642-15751-6_31.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Annotation and Robot Vision\978-3-642-15751-6_32.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Annotation and Robot Vision\978-3-642-15751-6_33.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Annotation and Robot Vision\978-3-642-15751-6_34.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Annotation and Robot Vision\978-3-642-15751-6_35.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Annotation and Robot Vision\978-3-642-15751-6_36.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Annotation and Robot Vision\978-3-642-15751-6_37.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Annotation and Robot Vision\978-3-642-15751-6_38.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Annotation and Robot Vision\978-3-642-15751-6_39.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Annotation and Robot Vision\978-3-642-15751-6_40.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Annotation and Robot Vision\978-3-642-15751-6_41.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Annotation and Robot Vision\978-3-642-15751-6_42.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Mixed\978-3-642-15751-6_43.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Mixed\978-3-642-15751-6_44.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\ImageCLEF Mixed\978-3-642-15751-6_45.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\III: Cross-Language Retrieval in Video Collections (VideoCLEF)\978-3-642-15751-6_46.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\III: Cross-Language Retrieval in Video Collections (VideoCLEF)\978-3-642-15751-6_47.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\III: Cross-Language Retrieval in Video Collections (VideoCLEF)\978-3-642-15751-6_48.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\III: Cross-Language Retrieval in Video Collections (VideoCLEF)\978-3-642-15751-6_49.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\III: Cross-Language Retrieval in Video Collections (VideoCLEF)\978-3-642-15751-6_50.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\III: Cross-Language Retrieval in Video Collections (VideoCLEF)\978-3-642-15751-6_51.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\III: Cross-Language Retrieval in Video Collections (VideoCLEF)\978-3-642-15751-6_52.tei.xml
# test
# resources\XML_LNCS\10th Workshop of the Cross-Language Evaluation Forum (Part II)\III: Cross-Language Retrieval in Video Collections (VideoCLEF)\978-3-642-15751-6_53.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\11519645_2.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_3.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_4.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_5.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_6.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_7.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_8.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_9.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_10.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_11.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_12.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_13.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_14.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_15.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_16.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_17.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_18.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_19.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_20.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_21.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Mainly Cross-Language Experiments\11519645_22.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Monolingual Experiments\11519645_23.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Monolingual Experiments\11519645_24.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Monolingual Experiments\11519645_25.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part I. Ad Hoc Text Retrieval Tracks\Part I. Ad Hoc Text Retrieval Tracks\Monolingual Experiments\11519645_26.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Document Retrieval\Part II. Domain-Specific Document Retrieval\Monolingual Experiments\11519645_27.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Document Retrieval\Part II. Domain-Specific Document Retrieval\Monolingual Experiments\11519645_28.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Document Retrieval\Part II. Domain-Specific Document Retrieval\Monolingual Experiments\11519645_29.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Document Retrieval\Part II. Domain-Specific Document Retrieval\Monolingual Experiments\11519645_30.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Document Retrieval\Part II. Domain-Specific Document Retrieval\Monolingual Experiments\11519645_31.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Information Retrieval\Part III. Interactive Cross-Language Information Retrieval\Monolingual Experiments\11519645_32.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Information Retrieval\Part III. Interactive Cross-Language Information Retrieval\Monolingual Experiments\11519645_33.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Information Retrieval\Part III. Interactive Cross-Language Information Retrieval\Monolingual Experiments\11519645_34.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Information Retrieval\Part III. Interactive Cross-Language Information Retrieval\Monolingual Experiments\11519645_35.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Information Retrieval\Part III. Interactive Cross-Language Information Retrieval\Monolingual Experiments\11519645_36.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Information Retrieval\Part III. Interactive Cross-Language Information Retrieval\Monolingual Experiments\11519645_37.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\Part IV. Multiple Language Question Answering\Monolingual Experiments\11519645_38.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\Part IV. Multiple Language Question Answering\Monolingual Experiments\11519645_39.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_40.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_41.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_42.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_43.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_44.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_45.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_46.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_47.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_48.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_49.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_50.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_51.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_52.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_53.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_54.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_55.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_56.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_57.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part IV. Multiple Language Question Answering\11519645_58.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_59.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_60.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_61.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_62.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_63.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_64.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_65.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_66.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_67.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_68.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_69.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_70.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_71.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_72.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_73.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_74.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_75.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_76.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_77.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Retrieval in Image Collections\11519645_78.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Spoken Document Retrieval\11519645_79.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part VII. Issues in CLIR and in Evaluation\11519645_80.tei.xml
# test
# resources\XML_LNCS\5th Workshop of the Cross-Language Evaluation Forum\Part VII. Issues in CLIR and in Evaluation\11519645_81.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Keynote Addresses\978-3-642-15998-5_1.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Keynote Addresses\978-3-642-15998-5_2.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Resources, Tools, and Methods\978-3-642-15998-5_3.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Resources, Tools, and Methods\978-3-642-15998-5_4.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Resources, Tools, and Methods\978-3-642-15998-5_5.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Experimental Collections and Datasets (1)\978-3-642-15998-5_6.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Experimental Collections and Datasets (1)\978-3-642-15998-5_7.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Experimental Collections and Datasets (2)\978-3-642-15998-5_8.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Experimental Collections and Datasets (2)\978-3-642-15998-5_9.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Evaluation Methodologies and Metrics (1)\978-3-642-15998-5_10.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Evaluation Methodologies and Metrics (1)\978-3-642-15998-5_11.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Evaluation Methodologies and Metrics (2)\978-3-642-15998-5_12.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Evaluation Methodologies and Metrics (2)\978-3-642-15998-5_13.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Evaluation Methodologies and Metrics (2)\978-3-642-15998-5_14.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Panels\978-3-642-15998-5_15.tei.xml
# test
# resources\XML_LNCS\International Conference of the Cross-Language Evaluation Forum\Panels\978-3-642-15998-5_16.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Full Papers\978-3-031-13643-6_1.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Full Papers\978-3-031-13643-6_2.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Full Papers\978-3-031-13643-6_3.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Full Papers\978-3-031-13643-6_4.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Full Papers\978-3-031-13643-6_5.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Full Papers\978-3-031-13643-6_6.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Full Papers\978-3-031-13643-6_7.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Short Papers\978-3-031-13643-6_8.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Short Papers\978-3-031-13643-6_9.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Short Papers\978-3-031-13643-6_10.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Best of 2021 Labs\978-3-031-13643-6_11.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Best of 2021 Labs\978-3-031-13643-6_12.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Best of 2021 Labs\978-3-031-13643-6_13.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Best of 2021 Labs\978-3-031-13643-6_14.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Best of 2021 Labs\978-3-031-13643-6_15.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Best of 2021 Labs\978-3-031-13643-6_16.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Best of 2021 Labs\978-3-031-13643-6_17.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_18.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_19.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_20.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_21.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_22.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_23.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_24.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_25.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_26.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_27.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_28.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_29.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_30.tei.xml
# test
# resources\XML_LNCS\13th International Conference of the CLEF Association\Overviews  of 2022 Labs\978-3-031-13643-6_31.tei.xml
# test
# resources\XML_LNCS\Third Workshop of the Cross-Language Evaluation Forum\System Evaluation Experiments at CLEF 2002\978-3-540-45237-9_2.tei.xml
# test
# ...
# test
# resources\XML_LNCS\12th International Conference of the CLEF Association\Overviews 2021 Labs\978-3-030-85251-1_22.tei.xml
# test
# resources\XML_LNCS\12th International Conference of the CLEF Association\Overviews 2021 Labs\978-3-030-85251-1_23.tei.xml
# test
# resources\XML_LNCS\12th International Conference of the CLEF Association\Overviews 2021 Labs\978-3-030-85251-1_24.tei.xml
# test
# resources\XML_LNCS\12th International Conference of the CLEF Association\Overviews 2021 Labs\978-3-030-85251-1_25.tei.xml
# test
# resources\XML_LNCS\12th International Conference of the CLEF Association\Overviews 2021 Labs\978-3-030-85251-1_26.tei.xml
# test
# resources\XML_LNCS\12th International Conference of the CLEF Association\Overviews 2021 Labs\978-3-030-85251-1_27.tei.xml
# test
# resources\XML_LNCS\12th International Conference of the CLEF Association\Overviews 2021 Labs\978-3-030-85251-1_28.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Benchmarking and Evaluation Initiatives\978-3-642-33247-0_1.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Benchmarking and Evaluation Initiatives\978-3-642-33247-0_2.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Benchmarking and Evaluation Initiatives\978-3-642-33247-0_3.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Benchmarking and Evaluation Initiatives\978-3-642-33247-0_4.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Benchmarking and Evaluation Initiatives\978-3-642-33247-0_5.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Information Access\978-3-642-33247-0_6.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Information Access\978-3-642-33247-0_7.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Information Access\978-3-642-33247-0_8.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Information Access\978-3-642-33247-0_9.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Information Access\978-3-642-33247-0_10.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Evaluation Methodologies and Infrastructure\978-3-642-33247-0_11.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Evaluation Methodologies and Infrastructure\978-3-642-33247-0_12.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Evaluation Methodologies and Infrastructure\978-3-642-33247-0_13.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Evaluation Methodologies and Infrastructure\978-3-642-33247-0_14.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Posters\978-3-642-33247-0_15.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Posters\978-3-642-33247-0_16.tei.xml
# test
# resources\XML_LNCS\Third International Conference of the CLEF Initiative\Posters\978-3-642-33247-0_17.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part I. Ad-hoc Text Retrieval Tracks\978-3-540-30222-3_5.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_6.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_7.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_8.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_9.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_10.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_11.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_12.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_13.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_14.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_15.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_16.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_17.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_18.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_19.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_20.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_21.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_22.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_23.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_24.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_25.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Mainly Cross-Language Experiments\978-3-540-30222-3_26.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\978-3-540-30222-3_27.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\978-3-540-30222-3_28.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\978-3-540-30222-3_29.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\978-3-540-30222-3_30.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\978-3-540-30222-3_31.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\978-3-540-30222-3_32.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\978-3-540-30222-3_33.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\978-3-540-30222-3_34.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\978-3-540-30222-3_35.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Monolingual Experiments\978-3-540-30222-3_36.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Document Retrieval\978-3-540-30222-3_37.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Document Retrieval\978-3-540-30222-3_38.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Document Retrieval\978-3-540-30222-3_39.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part II. Domain-Specific Document Retrieval\978-3-540-30222-3_40.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Retrieval\978-3-540-30222-3_41.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Retrieval\978-3-540-30222-3_42.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Retrieval\978-3-540-30222-3_43.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Retrieval\978-3-540-30222-3_44.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part III. Interactive Cross-Language Retrieval\978-3-540-30222-3_45.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part IV. Cross-Language Question Answering\978-3-540-30222-3_46.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part IV. Cross-Language Question Answering\978-3-540-30222-3_47.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part IV. Cross-Language Question Answering\978-3-540-30222-3_48.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part IV. Cross-Language Question Answering\978-3-540-30222-3_49.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part IV. Cross-Language Question Answering\978-3-540-30222-3_50.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part IV. Cross-Language Question Answering\978-3-540-30222-3_51.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part IV. Cross-Language Question Answering\978-3-540-30222-3_52.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part IV. Cross-Language Question Answering\978-3-540-30222-3_53.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part IV. Cross-Language Question Answering\978-3-540-30222-3_54.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part IV. Cross-Language Question Answering\978-3-540-30222-3_55.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Image Retrieval\978-3-540-30222-3_56.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Image Retrieval\978-3-540-30222-3_57.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Image Retrieval\978-3-540-30222-3_58.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Image Retrieval\978-3-540-30222-3_59.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part V. Cross-Language Image Retrieval\978-3-540-30222-3_60.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Spoken Document Retrieval\978-3-540-30222-3_61.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Spoken Document Retrieval\978-3-540-30222-3_62.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Spoken Document Retrieval\978-3-540-30222-3_63.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Spoken Document Retrieval\978-3-540-30222-3_64.tei.xml
# test
# resources\XML_LNCS\4th Workshop of the Cross-Language Evaluation Forum\Part VI. Cross-Language Spoken Document Retrieval\978-3-540-30222-3_65.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Evaluation and Visualization\978-3-642-40802-1_1.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Evaluation and Visualization\978-3-642-40802-1_2.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Evaluation and Visualization\978-3-642-40802-1_3.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Evaluation and Visualization\978-3-642-40802-1_4.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Evaluation and Visualization\978-3-642-40802-1_5.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Evaluation and Visualization\978-3-642-40802-1_6.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Evaluation and Visualization\978-3-642-40802-1_7.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Evaluation and Visualization\978-3-642-40802-1_8.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Evaluation and Visualization\978-3-642-40802-1_9.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Evaluation and Visualization\978-3-642-40802-1_10.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Multilinguality and Less-Resourced Languages\978-3-642-40802-1_11.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Multilinguality and Less-Resourced Languages\978-3-642-40802-1_12.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Multilinguality and Less-Resourced Languages\978-3-642-40802-1_13.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Multilinguality and Less-Resourced Languages\978-3-642-40802-1_14.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Multilinguality and Less-Resourced Languages\978-3-642-40802-1_15.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Multilinguality and Less-Resourced Languages\978-3-642-40802-1_16.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Applications\978-3-642-40802-1_17.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Applications\978-3-642-40802-1_18.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Applications\978-3-642-40802-1_19.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Applications\978-3-642-40802-1_20.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Applications\978-3-642-40802-1_21.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Applications\978-3-642-40802-1_22.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Lab Overviews\978-3-642-40802-1_23.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Lab Overviews\978-3-642-40802-1_24.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Lab Overviews\978-3-642-40802-1_25.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Lab Overviews\978-3-642-40802-1_26.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Lab Overviews\978-3-642-40802-1_27.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Lab Overviews\978-3-642-40802-1_28.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Lab Overviews\978-3-642-40802-1_29.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Lab Overviews\978-3-642-40802-1_30.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Lab Overviews\978-3-642-40802-1_31.tei.xml
# test
# resources\XML_LNCS\4th International Conference of the CLEF Initiative\Lab Overviews\978-3-642-40802-1_32.tei.xml

# %%
list_metadata_grobid_extract
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [['Russia', 'St. Petersburg State University', 'Pavel Efimov'],
#   ['Russia', 'Ural Federal University', 'Pavel Braslavski'],
#   ['Russia', 'JetBrains Research', 'Pavel Braslavski']],
#  [['Italy',
#    'Department of Mathematics "Tullio Levi-Civita"',
#    'Marco Ferrante'],
#   ['Italy', 'Department of Information Engineering', 'Nicola Ferro'],
#   ['Italy', 'Department of Information Engineering', 'Luca Piazzon']],
#  [['Germany',
#    'Berlin School of Library and Information Science',
#    'Vivien Petras'],
#   ['Germany', 'Göttingen State and University Library', 'Andreas Lüschow'],
#   ['Germany',
#    'Leibniz Institute for Psychology Information',
#    'Roland Ramthun'],
#   ['Germany', 'You, We & Digital', 'Juliane Stiller'],
#   ['Germany', 'DFKI GmbH', 'Cristina España-Bonet'],
#   ['Germany', 'Saarland University', 'Cristina España-Bonet'],
#   ['Germany', 'Saarland University', 'Sophie Henning']],
#  [['France', 'Synapse Développement', 'Camille Pradel'],
#   ['France', 'Synapse Développement', 'Damien Sileo'],
#   ['Spain', 'Universidad Nacional de Educación a Distanca', 'Álvaro Rodrigo'],
#   ['Spain', 'Universidad Nacional de Educación a Distanca', 'Anselmo Peñas'],
#   ['Spain', 'Ixa NLP Group', 'Eneko Agirre']],
#  [['Ethiopia', 'IT PhD Program', 'Tilahun Yeshambel'],
#   ['France', 'INSPE', 'Josiane Mothe'],
#   ['Ethiopia', 'Department of Computer Science', 'Yaregal Assabie']],
#  [['Germany',
#    'Berlin School of Library and Information Science',
#    'Florian Dietz']],
#  [['The Netherlands', 'University of Amsterdam', 'Mahsa Shahshahani'],
#   ['The Netherlands', 'University of Amsterdam', 'Jaap Kamps']],
#  [['Portugal', 'DETI/IEETA', 'João Almeida'],
#   ['Spain',
#    'Department of Information and Communications Technologies',
#    'João Almeida'],
#   ['Portugal', 'DETI/IEETA', 'Olga Fajarda'],
#   ['Portugal', 'DETI/IEETA', 'José Oliveira']],
#  [['Germany', 'Symanto Research GmbH & Co', 'Angelo Basile'],
#   ['The Netherlands', 'Rijksuniversiteit Groningen', 'Tommaso Caselli']],
#  [['Italy', 'Department of Information Engineering', 'Giorgio Di'],
#   ['Italy', 'Department of Mathematics', 'Giorgio Di']],
#  [['Denmark', 'Department of Computer Science', 'Casper Hansen'],
#   ['Denmark', 'Department of Computer Science', 'Christian Hansen'],
#   ['Denmark', 'Department of Computer Science', 'Jakob Simonsen'],
#   ['Denmark', 'Department of Computer Science', 'Christina Lioma']],
#  [['Belarus',
#    'United Institute of Informatics Problems',
#    'Siarhei Kazlouski']],
#  [['Canada', 'Faculty of Computer Science', 'Dijana Kosmajac'],
#   ['Canada', 'Faculty of Computer Science', 'Vlado Keselj']],
#  [['Greece', 'Department of Informatics', 'Vasiliki Kougia'],
#   ['Sweden', 'Department of Computer and Systems Sciences', 'Vasiliki Kougia'],
#   ['Greece', 'Department of Informatics', 'John Pavlopoulos'],
#   ['Sweden',
#    'Department of Computer and Systems Sciences',
#    'John Pavlopoulos'],
#   ['Greece', 'Department of Informatics', 'Ion Androutsopoulos']],
#  [['USA', 'Rochester Institute of Technology', 'Richard Zanibbi'],
#   ['USA', 'University of Maryland', 'Douglas Oard'],
#   ['USA', 'Rochester Institute of Technology', 'Anurag Agarwal'],
#   ['USA', 'Rochester Institute of Technology', 'Behrooz Mansouri']],
#  [['Greece',
#    'National Center for Scientific Research "Demokritos"',
#    'Anastasios Nentidis'],
#   ['Greece', 'Aristotle University of Thessaloniki', 'Anastasios Nentidis'],
#   ['Greece',
#    'National Center for Scientific Research "Demokritos"',
#    'Anastasia Krithara'],
#   ['Greece',
#    'National Center for Scientific Research "Demokritos"',
#    'Konstantinos Bougiatiotis'],
#   ['Greece',
#    'National and Kapodistrian University of Athens',
#    'Konstantinos Bougiatiotis'],
#   ['Spain', 'Barcelona Supercomputing Center', 'Martin Krallinger'],
#   ['Spain', 'Barcelona Supercomputing Center', 'Carlos Rodriguez-Penagos'],
#   ['Spain', 'Barcelona Supercomputing Center', 'Marta Villegas'],
#   ['Greece',
#    'National Center for Scientific Research "Demokritos"',
#    'Georgios Paliouras']],
#  [['Italy', 'DIT', 'Alberto Barrón-Cedeño'],
#   ['Qatar', 'Computer Science and Engineering Department', 'Preslav Nakov'],
#   ['Qatar', 'Qatar Computing Research Institute', 'Preslav Nakov'],
#   ['Qatar', 'Computer Science and Engineering Department', 'Maram Hasanain'],
#   ['Qatar', 'Computer Science and Engineering Department', 'Reem Suwaileh'],
#   ['Qatar', 'Computer Science and Engineering Department', 'Fatima Haouari'],
#   ['Bulgaria', 'FMI', 'Nikolay Babulkov'],
#   ['Bulgaria', 'FMI', 'Alex Nikolov'],
#   ['Qatar', 'Qatar Computing Research Institute', 'Shaden Shaar']],
#  [['Australia', 'The University of Melbourne', 'Jiayuan He'],
#   ['Australia', 'The University of Melbourne', 'Dat Nguyen'],
#   ['Vietnam', 'VinAI Research', 'Dat Nguyen'],
#   ['The Netherlands', 'Elsevier BV', 'Saber Akhondi'],
#   ['Germany', 'Elsevier Information Systems GmbH', 'Christian Druckenbrodt'],
#   ['Germany', 'Elsevier Information Systems GmbH', 'Camilo Thorne'],
#   ['The Netherlands', 'Elsevier BV', 'Zubair Afzal'],
#   ['Australia', 'The University of Melbourne', 'Zenan Zhai'],
#   ['Australia', 'The University of Melbourne', 'Biaoyan Fang'],
#   ['Australia', 'The University of Melbourne', 'Hiyori Yoshikawa'],
#   ['Japan', 'Fujitsu Laboratories Ltd', 'Hiyori Yoshikawa'],
#   ['Australia', 'RMIT University', 'Ameer Albahem'],
#   ['Australia', 'RMIT University', 'Lawrence Cavedon'],
#   ['Australia', 'The University of Melbourne', 'Trevor Cohn'],
#   ['Australia', 'The University of Melbourne', 'Timothy Baldwin'],
#   ['Australia', 'The University of Melbourne', 'Karin Verspoor']],
#  [['France', 'LIG', 'Lorraine Goeuriot'],
#   ['Australia', 'The Australian National University', 'Hanna Suominen'],
#   ['Australia',
#    'Data61/Commonwealth Scientific and Industrial Research Organisation',
#    'Hanna Suominen'],
#   ['Finland', 'University of Turku', 'Hanna Suominen'],
#   ['Ireland', 'Maynooth University', 'Liadh Kelly'],
#   ['Spain',
#    'Barcelona Supercomputing Center (BSC)',
#    'Antonio Miranda-Escalada'],
#   ['Spain', 'Barcelona Supercomputing Center (BSC)', 'Martin Krallinger'],
#   ['Australia', 'The Australian National University', 'Zhengyang Liu'],
#   ['Italy',
#    'Department of Informatics, Systems, and Communication',
#    'Gabriella Pasi'],
#   ['France', 'LIG', 'Gabriela Gonzalez Saez'],
#   ['Italy',
#    'Department of Informatics, Systems, and Communication',
#    'Marco Viviani'],
#   ['Australia', 'The Australian National University', 'Chenchen Xu'],
#   ['Australia',
#    'Data61/Commonwealth Scientific and Industrial Research Organisation',
#    'Chenchen Xu']],
#  [['Spain',
#    'Centro Singular de Investigación en Tecnoloxías Intelixentes (CiTIUS)',
#    'David Losada'],
#   ['Switzerland', 'Faculty of Informatics', 'Fabio Crestani'],
#   ['Spain', 'Information Retrieval Lab', 'Javier Parapar']],
#  [['Switzerland', 'Ecole Polytechnique Fédérale de Lausanne', 'Maud Ehrmann'],
#   ['Switzerland',
#    'Ecole Polytechnique Fédérale de Lausanne',
#    'Matteo Romanello']],
#  [['Romania', 'University Politehnica of Bucharest', 'Bogdan Ionescu'],
#   ['Switzerland',
#    'University of Applied Sciences Western Switzerland (HES-SO)',
#    'Henning Müller'],
#   ['France', 'University of La Rochelle', 'Renaud Péteri'],
#   ['USA', 'National Library of Medicine', 'Asma Abacha'],
#   ['USA', 'Philips Research Cambridge', 'Vivek Datla'],
#   ['USA', 'CVS Health', 'Sadid Hasan'],
#   ['USA', 'National Library of Medicine', 'Dina Demner-Fushman'],
#   ['Belarus', 'United Institute of Informatics Problems', 'Serge Kozlovski'],
#   ['Belarus', 'United Institute of Informatics Problems', 'Vitali Liauchuk'],
#   ['Belarus', 'United Institute of Informatics Problems', 'Vassili Kovalev'],
#   ['Germany',
#    'University of Applied Sciences and Arts Dortmund',
#    'Obioma Pelka'],
#   ['Germany',
#    'University of Applied Sciences and Arts Dortmund',
#    'Christoph Friedrich'],
#   ['Ireland', 'Dublin City University', 'Van-Tu Ninh'],
#   ['Ireland', 'Dublin City University', 'Tu-Khiem Le'],
#   ['Ireland', 'Dublin City University', 'Liting Zhou'],
#   ['Italy', 'Pluribus One and University of Cagliari', 'Luca Piras'],
#   ['Norway', 'University of Oslo', 'Michael Riegler'],
#   ['Norway', 'University of Oslo', 'Pål Halvorsen'],
#   ['Vietnam', 'University of Science', 'Minh-Triet Tran'],
#   ['Austria', 'Klagenfurt University', 'Mathias Lux'],
#   ['Ireland', 'Dublin City University', 'Cathal Gurrin'],
#   ['Norway', 'University of Bergen', 'Duc-Tien Dang-Nguyen'],
#   ['UK', 'University of Essex', 'Jon Chamberlain'],
#   ['UK', 'University of Essex', 'Adrian Clark'],
#   ['UK, Romania', 'Wellcome Trust', 'Antonio Campello'],
#   ['Romania', 'University Politehnica of Bucharest', 'Mihai Dogariu'],
#   ['Romania', 'University Politehnica of Bucharest', 'Mihai Constantin']],
#  [['France', 'Inria', 'Alexis Joly'],
#   ['France', 'UMR AMAP', 'Hervé Goëau'],
#   ['France', 'AMAP', 'Hervé Goëau'],
#   ['USA', 'Cornell Lab of Ornithology', 'Stefan Kahl'],
#   ['France', 'Inria', 'Benjamin Deneu'],
#   ['France', 'LIRMM', 'Maximillien Servajean'],
#   ['Czechia', 'Department of Cybernetics', 'Lukáš Picek'],
#   ['Switzerland', 'Faculty of Medicine', 'Rafael Ruiz De Castañeda'],
#   ['Switzerland', 'Faculty of Medicine', 'Isabelle Bolon'],
#   ['USA', 'Department of Biological Sciences', 'Andrew Durso'],
#   ['France', 'Inria', 'Titouan Lorieul'],
#   ['France', 'CNRS', 'Christophe Botella'],
#   ['France', 'Aix Marseille Univ', 'Hervé Glotin'],
#   ['France', 'Inria', 'Julien Champ'],
#   ['Switzerland', 'HES-SO', 'Ivan Eggel'],
#   ['The Netherlands', 'Xeno-canto Foundation', 'Willem-Pier Vellinga'],
#   ['France', 'UMR AMAP', 'Pierre Bonnet'],
#   ['France', 'AMAP', 'Pierre Bonnet'],
#   ['Switzerland', 'HES-SO', 'Henning Müller']],
#  [['Germany', 'TH Köln -University of Applied Sciences', 'Philipp Schaer'],
#   ['Germany',
#    'GESIS -Leibniz Institute for the Social Sciences',
#    'Johann Schaible']],
#  [['Germany', 'Bauhaus-Universität Weimar', 'Janek Bevendorff'],
#   ['Germany', 'Symanto Research', 'Bilal Ghanem'],
#   ['Spain', 'Universitat Politècnica de València', 'Bilal Ghanem'],
#   ['Spain', 'Universitat Politècnica de València', 'Anastasia Giachanou'],
#   ['Belgium', 'University of Antwerp', 'Mike Kestemont'],
#   ['Belgium', 'University of Antwerp', 'Enrique Manjavacas'],
#   ['Belgium', 'University of Antwerp', 'Ilia Markov'],
#   ['Austria', 'University of Innsbruck', 'Maximilian Mayerl'],
#   ['Germany', 'Leipzig University', 'Martin Potthast'],
#   ['Germany', 'Symanto Research', 'Francisco Rangel'],
#   ['Spain', 'Universitat Politècnica de València', 'Paolo Rosso'],
#   ['Austria', 'University of Innsbruck', 'Günther Specht'],
#   ['Greece', 'University of the Aegean', 'Efstathios Stamatatos'],
#   ['Germany', 'Bauhaus-Universität Weimar', 'Benno Stein'],
#   ['Germany', 'Bauhaus-Universität Weimar', 'Matti Wiegmann'],
#   ['Austria', 'University of Innsbruck', 'Eva Zangerle']],
#  [['Germany',
#    'Martin-Luther-Universität Halle-Wittenberg',
#    'Alexander Bondarenko'],
#   ['Germany', 'Martin-Luther-Universität Halle-Wittenberg', 'Maik Fröbe'],
#   ['Germany', 'Universität Hamburg', 'Meriem Beloucif'],
#   ['Germany', 'Universität Leipzig', 'Lukas Gienapp'],
#   ['Germany', 'Martin-Luther-Universität Halle-Wittenberg', 'Yamen Ajjour'],
#   ['Russia',
#    'Skolkovo Institute of Science and Technology',
#    'Alexander Panchenko'],
#   ['Germany', 'Universität Hamburg', 'Chris Biemann'],
#   ['Germany', 'Bauhaus-Universität Weimar', 'Benno Stein'],
#   ['Germany', 'Paderborn University', 'Henning Wachsmuth'],
#   ['Germany', 'Universität Leipzig', 'Martin Potthast'],
#   ['Germany', 'Martin-Luther-Universität Halle-Wittenberg', 'Matthias Hagen']],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [['Switzerland', 'Eurospider Information Technology AG', 'Martin Braschler'],
#   ['Italy', 'Department of Information Engineering', 'Giorgio Di'],
#   ['Italy', 'Department of Information Engineering', 'Nicola Ferro'],
#   ['Italy', 'ISTI-CNR', 'Carol Peters']],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [['Ireland', 'Department of Computer Science and Information Systems', ' ']],
#  [['Germany', 'LT-Lab', 'Günter Neumann'],
#   ['Germany', 'LT-Lab', 'Bogdan Sacaleanu']],
#  [['The Netherlands', 'Informatics Institute', ' ']],
#  [['Italy',
#    'Centro per la Ricerca Scientifica e Tecnologica Via Sommarive',
#    'Hristo Tanev'],
#   ['Italy',
#    'Centro per la Ricerca Scientifica e Tecnologica Via Sommarive',
#    'Matteo Negri'],
#   ['Italy',
#    'Centro per la Ricerca Scientifica e Tecnologica Via Sommarive',
#    'Bernardo Magnini'],
#   ['Italy',
#    'Centro per la Ricerca Scientifica e Tecnologica Via Sommarive',
#    'Milen Kouylekov']],
#  [['Scotland, UK', 'University of Edinburgh', 'Kisuh Ahn'],
#   ['Scotland, UK', 'University of Edinburgh', 'Beatrice Alex'],
#   ['Scotland, UK', 'University of Edinburgh', 'Johan Bos'],
#   ['Scotland, UK', 'University of Edinburgh', 'Tiphaine Dalmas'],
#   ['Scotland, UK', 'University of Edinburgh', 'Jochen Leidner'],
#   ['Scotland, UK', 'University of Edinburgh', 'Matthew Smillie']],
#  [['Bulgaria', 'Laboratory for Linguistic Modelling', 'Petya Osenova'],
#   ['Bulgaria', 'Laboratory for Linguistic Modelling', 'Alexander Simov'],
#   ['Bulgaria', 'Laboratory for Linguistic Modelling', 'Hristo Tanev'],
#   ['Italy', 'ITC-irst', 'Hristo Tanev'],
#   ['Italy', 'ITC-irst', 'Milen Kouylekov']],
#  [],
#  [['Finland', 'Department of Computer Science', 'Lili Aunimo'],
#   ['Finland', 'Department of Computer Science', 'Reeta Kuuskoski'],
#   ['Finland', 'Department of Computer Science', 'Juha Makkonen']],
#  [['Spain', 'Computer Science Department', 'César De Pablo-Sánchez'],
#   ['Spain', 'Computer Science Department', 'José Luis Martínez-Fernández'],
#   ['Spain', 'Computer Science Department', 'Julio Villena'],
#   ['Spain', 'DAEDALUS -Data, Decisions and Language S.A', 'Julio Villena']],
#  [['México', 'Óptica y Electrónica (INAOE)', ' '],
#   ['Spain', 'Dept. of Information Systems and Computation Poly-technic', ' ']],
#  [['Germany',
#    'Intelligent Information and Communication Systems (IICS)',
#    'Sven Hartrumpf']],
#  [['Norway', 'Linguateca at SINTEF ICT', ' Luís Costa']],
#  [['Portugal', 'Departamento de Informática', 'Paulo Quaresma'],
#   ['Portugal', 'Departamento de Informática', 'Luís Quintano'],
#   ['Portugal', 'Departamento de Informática', 'Irene Rodrigues'],
#   ['Portugal', 'Departamento de Informática', 'José Saias'],
#   ['Portugal', 'Departamento de Informática', 'Pedro Salgueiro']],
#  [['Spain', 'Departamento de Computación', 'Enrique Méndez Díaz'],
#   ['Spain', 'Departamento de Computación', 'Vilares Jesús'],
#   ['Spain', 'Departamento de Computación', 'David Ferro'],
#   ['Spain', 'Departamento de Computación', ' Souto']],
#  [['Spain',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'José Vicedo'],
#   ['Spain',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Maximiliano Saiz'],
#   ['Spain',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Rubén Izquierdo'],
#   ['Spain',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Fernando Llopis']],
#  [['Spain', 'TALP Research Center', 'Daniel Ferrés'],
#   ['Spain', 'TALP Research Center', 'Samir Kanaan'],
#   ['Spain', 'TALP Research Center', 'Alicia Ageno'],
#   ['Spain', 'TALP Research Center', 'Edgar González'],
#   ['Spain', 'TALP Research Center', 'Horacio Rodríguez'],
#   ['Spain', 'TALP Research Center', 'Mihai Surdeanu'],
#   ['Spain', 'TALP Research Center', 'Jordi Turmo']],
#  [['Italy',
#    'Istituto di Linguistica Computazionale (Consiglio Nazionale delle Ricerche)',
#    'Francesca Bertagna'],
#   ['Romania', 'Universita\' "A. I. Cuza"', 'Luminita Chiran'],
#   ['Italy', 'Dipartimento di Informatica (Università di Pisa)', 'Maria Simi']],
#  [['Spain', 'Juan del Rosal', ' ']],
#  [['Spain', 'Departamento de Lenguajes y Sistemas Informáticos', ' ']],
#  [['UK', 'University of Sheffield', 'Paul Clough'],
#   ['Switzerland', 'Service of Medical Informatics', 'Henning Müller'],
#   ['UK', 'University of Sheffield', 'Mark Sanderson']],
#  [['UK', 'University of Sheffield', 'Paul Clough']],
#  [['Spain',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Maximiliano Saiz-Noeda'],
#   ['Spain',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'José Vicedo'],
#   ['Spain',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Rubén Izquierdo']],
#  [['Switzerland', 'Service of Medical Informatics', 'Henning Müller'],
#   ['Switzerland', 'Service of Medical Informatics', 'Antoine Geissbühler']],
#  [['Spain',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Víctor Peinado'],
#   ['Spain',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Javier Artiles'],
#   ['Spain',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Fernando López-Ostenero'],
#   ['Spain',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Julio Gonzalo'],
#   ['Spain',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Felisa Verdejo']],
#  [['Ireland', 'School of Computing', 'Gareth Jones'],
#   ['Ireland', 'School of Computing', 'Declan Groves'],
#   ['Ireland', 'School of Computing', 'Anna Khasin'],
#   ['Ireland', 'School of Computing', 'Adenike Lam-Adesina'],
#   ['Ireland', 'School of Computing', 'Bart Mellebeek'],
#   ['Ireland', 'School of Computing', 'Andy Way']],
#  [['Taiwan',
#    'Department of Computer Science and Information Engineering',
#    'Wen-Cheng Lin'],
#   ['Taiwan',
#    'Department of Computer Science and Information Engineering',
#    'Yih-Chen Chang'],
#   ['Taiwan',
#    'Department of Computer Science and Information Engineering',
#    'Hsin-Hsi Chen']],
#  [['Canada', 'DIRO', 'Carmen Alvarez'],
#   ['Canada', 'DIRO', 'Ahmed Id Oumohmed'],
#   ['Canada', 'DIRO', 'Max Mignotte'],
#   ['Canada', 'DIRO', 'Jian-Yun Nie']],
#  [['Germany',
#    'Lehrstuhl für Informatik VI -Computer Science Department',
#    'Thomas Deselaers'],
#   ['Germany',
#    'Lehrstuhl für Informatik VI -Computer Science Department',
#    'Daniel Keysers'],
#   ['Germany',
#    'Lehrstuhl für Informatik VI -Computer Science Department',
#    'Hermann Ney']],
#  [['Spain', 'Computer Science Department', 'J Martínez-Fernández'],
#   ['S.A., Spain',
#    'DAEDALUS -Data, Decisiond and Language',
#    'J Martínez-Fernández'],
#   ['Spain', 'Artificial Intelligence Department', 'A García-Serrano'],
#   ['Spain', 'Department of Telematic Engineering', 'J Villena'],
#   ['S.A., Spain', 'DAEDALUS -Data, Decisiond and Language', 'J Villena'],
#   ['Spain', 'Artificial Intelligence Department', 'V Méndez-Sáenz']],
#  [['France',
#    'LIC2M (Multilingual Multimedia Knowledge Engineering Laboratory)',
#    'Romaric Besançon'],
#   ['France',
#    'LIC2M (Multilingual Multimedia Knowledge Engineering Laboratory)',
#    'Patrick Hède'],
#   ['France',
#    'LIC2M (Multilingual Multimedia Knowledge Engineering Laboratory)',
#    'Pierre-Alain Moellic'],
#   ['France',
#    'LIC2M (Multilingual Multimedia Knowledge Engineering Laboratory)',
#    'Christian Fluhr']],
#  [['Switzerland', 'Service of Medical Informatics', 'Henning Müller'],
#   ['Switzerland', 'Service of Medical Informatics', 'Antoine Geissbühler'],
#   ['Switzerland', 'Service of Medical Informatics', 'Patrick Ruch'],
#   ['Switzerland', 'LITH IN-Ecublens', 'Patrick Ruch']],
#  [['the Netherlands', 'ILK', 'Menno Van Zaanen'],
#   ['the Netherlands', 'Department of Computer Science', 'Guido De Croon'],
#   ['Australia', 'ICS', ' ']],
#  [['UK', 'Imperial College London', ' ']],
#  [['Taiwan',
#    'Department of Computer & Information Science',
#    'Pei-Cheng Cheng'],
#   ['Taiwan, R.O.C',
#    'Department of Computer Science and Information Engineering',
#    'Been-Chian Chien'],
#   ['Taiwan', 'Department of Computer & Information Science', 'Wei-Pang Yang'],
#   ['Taiwan, R.O.C', 'Department of Information Management', 'Wei-Pang Yang']],
#  [['The Netherlands', 'University of Twente', 'Koen Lubbers'],
#   ['The Netherlands',
#    'Centrum voor Wiskunde en Informatica (CWI)',
#    'Arjen De Vries'],
#   ['The Netherlands', 'University of Twente', 'Theo Huibers'],
#   ['The Netherlands', 'University of Twente', 'Paul Van Der Vet']],
#  [['USA', 'School of Informatics', 'Miguel Ruiz'],
#   ['USA', 'Language Computer Corporation Richardson', 'Munirathnam Srikanth']],
#  [['Germany', 'Department of Medical Informatics', 'Christian Thies'],
#   ['Germany', 'Department of Medical Informatics', 'Mark Güld'],
#   ['Germany', 'Department of Medical Informatics', 'Benedikt Fischer'],
#   ['Germany', 'Department of Medical Informatics', 'Thomas Lehmann']],
#  [['Taiwan',
#    'Department of Computer & Information Science',
#    'Pei-Cheng Cheng'],
#   ['Taiwan', 'Department of Computer & Information Science', 'Jen-Yuan Yeh'],
#   ['Taiwan', 'University Library', 'Hao-Ren Ke'],
#   ['Taiwan', 'Su Line St', 'Been-Chian Chien'],
#   ['Taiwan', 'Department of Computer & Information Science', 'Wei-Pang Yang'],
#   ['Taiwan', 'Department of Information Management', 'Wei-Pang Yang']],
#  [['U.S.A', 'Department of Computer Science and Engineering', 'Vineet Bansal'],
#   ['U.S.A', 'Department of Computer Science and Engineering', 'Chen Zhang'],
#   ['U.S.A', 'Department of Computer Science and Engineering', 'Joyce Chai'],
#   ['U.S.A', 'Department of Computer Science and Engineering', 'Rong Jin']],
#  [['Italy', 'ITC-irst', 'Marcello Federico'],
#   ['Italy', 'ITC-irst', 'Nicola Bertoldi'],
#   ['U.S.A', 'University of Chicago', 'Gina-Anne Levow'],
#   ['Ireland', 'Dublin City University', 'Gareth Jones']],
#  [],
#  [],
#  [['Germany', 'Faculty of Engineering', 'Norbert Fuhr']],
#  [['Spain',
#    'Yahoo! Research and Universitat Pompeu Fabra',
#    'Ricardo Baeza-Yates']],
#  [['Finland',
#    'Department of Information Studies and Interactive Media',
#    'Aki Loponen'],
#   ['Finland',
#    'Department of Information Studies and Interactive Media',
#    'Kalervo Järvelin']],
#  [['Brazil',
#    'Instituto de Informática -Universidade Federal do Rio Grande do Sul (UFRGS',
#    'Rafael Pereira'],
#   ['Brazil',
#    'Instituto de Informática -Universidade Federal do Rio Grande do Sul (UFRGS',
#    'Viviane Moreira'],
#   ['Brazil',
#    'Instituto de Informática -Universidade Federal do Rio Grande do Sul (UFRGS',
#    'Renata Galante']],
#  [],
#  [['The Netherlands', 'ISLA', 'Bouke Huurnink'],
#   ['The Netherlands', 'ISLA', 'Katja Hofmann'],
#   ['The Netherlands', 'ISLA', 'Maarten De Rijke'],
#   ['The Netherlands', 'ISLA', 'Marc Bron']],
#  [['Italy',
#    'European Commission -Joint Research Centre (JRC)',
#    'Marco Turchi'],
#   ['Italy',
#    'European Commission -Joint Research Centre (JRC)',
#    'Josef Steinberger'],
#   ['Italy',
#    'European Commission -Joint Research Centre (JRC)',
#    'Mijail Kabadjov'],
#   ['Italy',
#    'European Commission -Joint Research Centre (JRC)',
#    'Ralf Steinberger']],
#  [['The Netherlands', 'University of Twente', 'Djoerd Hiemstra'],
#   ['The Netherlands', 'University of Twente', 'Claudia Hauff']],
#  [['Germany',
#    'Berlin School of Library and Information Science',
#    'Maria Gäde'],
#   ['Germany',
#    'Berlin School of Library and Information Science',
#    'Vivien Petras'],
#   ['Germany',
#    'Berlin School of Library and Information Science',
#    'Juliane Stiller']],
#  [['Ireland',
#    'Centre for Next Generation Localization School of Computing',
#    'Walid Magdy'],
#   ['Ireland',
#    'Centre for Next Generation Localization School of Computing',
#    'Gareth Jones']],
#  [['The Netherlands', 'ISLA', 'Maarten De Rijke'],
#   ['The Netherlands', 'ISLA', 'Krisztian Balog'],
#   ['Denmark', 'Royal School of Library & Information Science', 'Toine Bogers'],
#   ['The Netherlands',
#    'ILK/Tilburg Centre for Creative Computing',
#    'Antal Van Den Bosch']],
#  [['Italy',
#    "Istituto di Scienza e Tecnologie dell'Informazione Consiglio Nazionale delle Ricerche",
#    ' ']],
#  [],
#  [['Austria', 'Information Retrieval Facility', 'Allan Hanbury'],
#   ['Switzerland',
#    'University of Applied Sciences Western Switzerland (HES-SO)',
#    'Henning Müller']],
#  [['USA',
#    'National Institute of Standards and Technology (NIST)',
#    'Donna Harman'],
#   ['Japan', 'National Institute of Informatics (NII)', 'Noriko Kando'],
#   ['UK', 'University of Glasgow', 'Mounia Lalmas'],
#   ['Italy',
#    'Institute of Information Science and Technologies',
#    'Carol Peters']],
#  [['Switzerland', 'Zurich University of Applied Sciences', 'Martin Braschler'],
#   ['France',
#    'Evaluations and Language resources Distribution Agency',
#    'Khalid Choukri'],
#   ['Italy', 'University of Padua', 'Nicola Ferro'],
#   ['Austria', 'Information Retrieval Facility', 'Allan Hanbury'],
#   ['Sweden', 'Swedish Institute of Computer Science', 'Jussi Karlgren'],
#   ['Switzerland',
#    'University of Applied Sciences Western Switzerland',
#    'Henning Müller'],
#   ['Germany', 'Humboldt-Universität zu Berlin', 'Vivien Petras'],
#   ['Italy',
#    'Centre for the Evaluation of Language Communication Technologies',
#    'Emanuele Pianta'],
#   ['The Netherlands', 'University of Amsterdam', 'Maarten De Rijke'],
#   ['Italy', 'Sapienza University of Rome', 'Giuseppe Santucci']],
#  [['Germany',
#    'Department of Information Science and Natural Language Processing',
#    'Linda Achilles'],
#   ['Germany',
#    'Department of Information Science and Natural Language Processing',
#    'Thomas Mandl'],
#   ['Germany',
#    'Department of Information Science and Natural Language Processing',
#    'Christa Womser-Hacker']],
#  [['France', 'Laboratoire L3i', 'Guillaume Bernard'],
#   ['France', 'Laboratoire L3i', 'Cyrille Suire'],
#   ['France', 'Laboratoire L3i', 'Cyril Faucher'],
#   ['France', 'Laboratoire L3i', 'Antoine Doucet'],
#   ['Spain', 'Universitat Politècnica de València', 'Paolo Rosso']],
#  [['Austria', 'Technische Universität Wien', 'Annisa Ningtyas'],
#   ['Indonesia', 'Universitas Gadjah Mada', 'Annisa Ningtyas'],
#   ['Austria', 'Technische Universität Wien', 'Alaa El-Ebshihy'],
#   ['Egypt', 'Alexandria University', 'Alaa El-Ebshihy'],
#   ['Austria', 'Technische Universität Wien', 'Florina Piroi'],
#   ['Austria', 'Technische Universität Wien', 'Allan Hanbury']],
#  [['Germany', 'Martin-Luther-Universität Halle-Wittenberg', 'Maik Fröbe'],
#   ['Germany', 'Leipzig University', 'Christopher Akiki'],
#   ['Germany', 'Leipzig University', 'Martin Potthast'],
#   ['Germany', 'Martin-Luther-Universität Halle-Wittenberg', 'Matthias Hagen']],
#  [['The Netherlands', 'University of Amsterdam', 'Mohammad Aliannejadi'],
#   ['The Netherlands', 'University of Twente', 'Theo Huibers'],
#   ['Switzerland', 'Università della Svizzera Italiana', 'Monica Landoni'],
#   ['Italy', 'Università degli Studi di Milano-Bicocca', 'Emiliana Murgia'],
#   ['USA', 'Boise State University', 'Maria Pera']],
#  [['Italy', 'Scuola Normale Superiore', 'Silvia Corbara'],
#   ['Spain', 'Universitat Politècnica de València', 'Berta Chulvi'],
#   ['Spain', 'Universitat de València', 'Berta Chulvi'],
#   ['Spain', 'Universitat Politècnica de València', 'Paolo Rosso'],
#   ['Italy',
#    "Istituto di Scienza e Tecnologie dell'Informazione",
#    'Alejandro Moreo']],
#  [['Germany', 'Technische Universität Berlin', 'Salar Mohtaj'],
#   ['Germany',
#    'German Research Centre for Artificial Intelligence (DFKI)',
#    'Salar Mohtaj'],
#   ['Germany', 'Technische Universität Berlin', 'Sebastian Möller'],
#   ['Germany',
#    'German Research Centre for Artificial Intelligence (DFKI)',
#    'Sebastian Möller']],
#  [],
#  [['Australia', 'School of Information Technology', 'Shashank Gupta'],
#   ['Australia', 'School of Information Technology', 'Mohamed Bouadjenek'],
#   ['Australia', 'School of Information Technology', 'Antonio Robles-Kelly']],
#  [['UK', 'Univerity of Glasgow', 'Erlend Frayling'],
#   ['UK', 'Univerity of Glasgow', 'Craig Macdonald'],
#   ['UK', 'Univerity of Glasgow', 'Graham Mcdonald'],
#   ['UK', 'Univerity of Glasgow', 'Iadh Ounis']],
#  [['Germany', 'Technische Hochschule Köln', 'Jüri Keller']],
#  [['Italy', 'Dipartimento di Informatica', 'Mirko Lai'],
#   ['Italy', 'Dipartimento di Informatica', 'Mirko Lai'],
#   ['Italy', 'Dipartimento di Informatica', 'Marco Stranisci'],
#   ['Italy', 'Dipartimento di Informatica', 'Marco Stranisci'],
#   ['Italy', 'Dipartimento di Informatica', 'Cristina Bosco'],
#   ['Italy', 'Dipartimento di Informatica', 'Rossana Damiano'],
#   ['Italy', 'Dipartimento di Informatica', 'Viviana Patti']],
#  [['France', 'INSA de Lyon', 'Alaa Alhamzeh'],
#   ['Germany', 'Universität Passau', 'Alaa Alhamzeh'],
#   ['Germany', 'Universität Passau', 'Mohamed Bouhaouel'],
#   ['France', 'INSA de Lyon', 'Előd Egyed-Zsigmond'],
#   ['Germany', 'Universität Passau', 'Jelena Mitrović'],
#   ['Serbia', 'Institute for AI Research and Development', 'Jelena Mitrović'],
#   ['France', 'INSA de Lyon', 'Lionel Brunie'],
#   ['Germany', 'Universität Passau', 'Harald Kosch']],
#  [['Germany', 'Database Systems Group', 'Anja Reusch'],
#   ['Germany', 'Hochschule für Technik und Wirtschaft Dresden', 'Maik Thiele'],
#   ['Germany', 'Database Systems Group', 'Wolfgang Lehner']],
#  [['Australia',
#    'Commonwealth Scientific and Industrial Research Organisation',
#    'Aaron Nicolson'],
#   ['Australia',
#    'Commonwealth Scientific and Industrial Research Organisation',
#    'Jason Dowling'],
#   ['Australia',
#    'Commonwealth Scientific and Industrial Research Organisation',
#    'Bevan Koopman']],
#  [['South Korea', 'Korea University', 'Wonjin Yoon'],
#   ['South Korea', 'Korea University', 'Jaehyo Yoo'],
#   ['South Korea', 'Korea University', 'Sumin Seo'],
#   ['South Korea', 'Korea University', 'Mujeen Sung'],
#   ['South Korea', 'Korea University', 'Minbyul Jeong'],
#   ['South Korea', 'Korea University', 'Gangwoo Kim'],
#   ['South Korea', 'Korea University', 'Jaewoo Kang'],
#   ['South Korea', 'AIGEN Sciences Inc', 'Jaewoo Kang']],
#  [['Italy',
#    'Department of Linguistic and Literary Studies',
#    'Federica Vezzani']],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [['Russia', 'Ural Federal University', 'Pavel Braslavski'],
#   ['The Netherlands', 'Radboud University', 'Suzan Verberne'],
#   ['Russia', 'Ural Federal University', 'Ruslan Talipov']],
#  [['Italy', 'Department of Information Engineering', 'Nicola Ferro'],
#   ['Italy', 'Department of Information Engineering', 'Gianmaria Silvello']],
#  [['Spain',
#    'Centro Singular de Investigación en Tecnoloxías da Información (CiTIUS)',
#    'David Losada'],
#   ['Switzerland', 'Faculty of Informatics', 'Fabio Crestani']],
#  [['Austria', 'Vienna University of Technology', 'Joao Palotti'],
#   ['Australia', 'Queensland University of Technology', 'Guido Zuccon'],
#   ['Austria', 'Medical University of Graz', 'Johannes Bernhardt'],
#   ['Austria', 'Vienna University of Technology', 'Allan Hanbury'],
#   ['France', 'Université Grenoble Alpes', 'Lorraine Goeuriot']],
#  [['Czech Republic',
#    'Institute of Formal and Applied Linguistics',
#    'Shadi Saleh'],
#   ['Czech Republic',
#    'Institute of Formal and Applied Linguistics',
#    'Pavel Pecina']],
#  [['The Netherlands',
#    'Institute for Logic, Language and Computation',
#    'Mostafa Dehghani'],
#   ['The Netherlands', 'Informatics Institute', 'Hosein Azarbonyad'],
#   ['The Netherlands',
#    'Institute for Logic, Language and Computation',
#    'Jaap Kamps'],
#   ['The Netherlands', 'Informatics Institute', 'Maarten Marx']],
#  [['Portugal', 'Faculdade de Engenharia', 'Carla Teixeira'],
#   ['Portugal', 'Faculdade de Engenharia', 'Cristina Ribeiro']],
#  [['UK', 'School of Computing Science', 'Jarana Manotumruksa'],
#   ['UK', 'School of Computing Science', 'Craig Macdonald'],
#   ['UK', 'School of Computing Science', 'Iadh Ounis']],
#  [['Mexico',
#    'Universidad Autónoma del Estado de Hidalgo (UAEH)',
#    'Rosa María Ortega-Mendoza'],
#   ['Mexico',
#    'Instituto Tecnológico Superior del Oriente del Estado de Hidalgo (ITESA)',
#    'Rosa María Ortega-Mendoza'],
#   ['Mexico',
#    'Universidad Autónoma del Estado de Hidalgo (UAEH)',
#    'Anilú Franco-Arcega'],
#   ['Mexico', 'Óptica y Electrónica (INAOE)', 'Adrián Pastor López-Monroy'],
#   ['Mexico', 'Óptica y Electrónica (INAOE)', 'Manuel Montes-Y-Gómez']],
#  [['UK', 'UCL', 'Gaurav Singh'],
#   ['USA', 'Yahoo! Research', 'Amin Mantrach'],
#   ['USA', 'Yahoo! Research', 'Fabrizio Silvestri']],
#  [['Austria', 'Intelligent and Interactive Systems', 'Sabrina Fontanella'],
#   ['Italy', 'Department of Computer Science', 'Sabrina Fontanella'],
#   ['Austria',
#    'Intelligent and Interactive Systems',
#    'Antonio Rodríguez-Sánchez'],
#   ['Austria', 'Intelligent and Interactive Systems', 'Justus Piater'],
#   ['Finland', 'Department of Computer Science', 'Sandor Szedmak']],
#  [['Mexico', 'Óptica y Electrónica (INAOE)', 'Luis Pellegrin'],
#   ['Colombia', 'MindLab Research Group', 'Jorge Vanegas'],
#   ['Colombia', 'MindLab Research Group', 'John Arevalo'],
#   ['Colombia', 'MindLab Research Group', 'Viviana Beltrán'],
#   ['Mexico', 'Óptica y Electrónica (INAOE)', 'Hugo Escalante'],
#   ['Mexico', 'Óptica y Electrónica (INAOE)', 'Manuel Montes-Y-Gómez'],
#   ['Colombia', 'MindLab Research Group', 'Fabio González']],
#  [['The Netherlands', 'Department of Medical Informatics', 'Zubair Afzal'],
#   ['The Netherlands', 'Department of Medical Informatics', 'Saber Akhondi'],
#   ['The Netherlands',
#    'Department of Medical Informatics',
#    'Herman Van Haagen'],
#   ['The Netherlands',
#    'Department of Medical Informatics',
#    'Erik Van Mulligen'],
#   ['The Netherlands', 'Department of Medical Informatics', 'Jan Kors']],
#  [['France', 'IRIT', 'Lamjed Jabeur'],
#   ['France', 'Sorbonne Universités', 'Laure Soulier'],
#   ['France', 'IRIT', 'Lynda Tamine'],
#   ['France', 'IRIT', 'Paul Mousset']],
#  [['The Netherlands', 'CWI', 'Gebrekirstos Gebremeskel'],
#   ['The Netherlands', 'Radboud University', 'Arjen De Vries']],
#  [['Iran',
#    'School of Electrical and Computer Engineering',
#    'Javid Dadashkarimi'],
#   ['Iran',
#    'School of Electrical and Computer Engineering',
#    'Hossein Esfahani'],
#   ['Iran', 'School of Electrical and Computer Engineering', 'Heshaam Faili'],
#   ['Iran', 'School of Electrical and Computer Engineering', 'Azadeh Shakery']],
#  [['Portugal', 'Faculdade de Engenharia', 'José Devezas'],
#   ['Portugal', 'Faculdade de Engenharia', 'Sérgio Nunes']],
#  [['Ireland', 'ADAPT Centre', 'Debasis Ganguly'],
#   ['Ireland', 'ADAPT Centre', 'Gareth Jones']],
#  [['Sweden', 'KTH', 'Vide Karlsson'],
#   ['Sweden', 'KTH', 'Pawel Herman'],
#   ['Sweden', 'KTH', 'Jussi Karlgren']],
#  [['Germany', 'Cologne University of Applied Sciences', 'Philipp Schaer'],
#   ['Germany',
#    'GESIS -Leibniz Institute for the Social Sciences',
#    'Philipp Mayr'],
#   ['Germany', 'Hamburg University of Applied Sciences', 'Sebastian Sünkler'],
#   ['Germany', 'Hamburg University of Applied Sciences', 'Dirk Lewandowski']],
#  [['Norway', 'University of Stavanger', 'Natalia Shepeleva'],
#   ['Norway', 'University of Stavanger', 'Krisztian Balog']],
#  [['Portugal', 'Department of Informatics Engineering', 'Carla Lopes'],
#   ['Portugal', 'INESC TEC', 'Carla Lopes'],
#   ['Portugal', 'Department of Informatics Engineering', 'Tiago Fernandes']],
#  [['Brazil', 'Computer Science Department', 'Leila Weitzel'],
#   ['Brazil', 'Computer Science Department', 'Flávia Bernardini'],
#   ['Portugal', 'Universidade de Évora', 'Paulo Quaresma'],
#   ['Brazil', 'Computer Science Department', 'Claudio Alves'],
#   ['Brazil', 'Computer Science Department', 'Wladek Zacharski'],
#   ['Brazil', 'Computer Science Department', 'Luis De Figueiredo']],
#  [['Ireland', 'ADAPT Centre', 'Liadh Kelly'],
#   ['France', 'LIG', 'Lorraine Goeuriot'],
#   ['Australia', 'Data61', 'Hanna Suominen'],
#   ['Finland', 'University of Turku', 'Hanna Suominen'],
#   ['France', 'LIMSI CNRS UPR 3251', 'Aurélie Névéol'],
#   ['Austria', 'Vienna University of Technology', 'João Palotti'],
#   ['Australia', 'Queensland University of Technology', 'Guido Zuccon']],
#  [['Spain', 'Universitat Politècnica de València', 'Mauricio Villegas'],
#   ['Switzerland',
#    'University of Applied Sciences Western Switzerland (HES-SO)',
#    'Henning Müller'],
#   ['USA', 'National Library of Medicine', 'Seco De Herrera'],
#   ['Switzerland',
#    'University of Applied Sciences Western Switzerland (HES-SO)',
#    'Roger Schaer'],
#   ['The Netherlands', 'Open University of the Netherlands', 'Stefano Bromuri'],
#   ['UK', 'University of Surrey', 'Andrew Gilbert'],
#   ['Italy', 'University of Cagliari', 'Luca Piras'],
#   ['UK', 'University of Sheffield', 'Josiah Wang'],
#   ['UK', 'University of Surrey', 'Fei Yan'],
#   ['Spain',
#    'Institut de Robòtica i Informàtica Industrial (UPC-CSIC)',
#    'Arnau Ramisa'],
#   ['France', 'École Centrale de Lyon', 'Emmanuel Dellandrea'],
#   ['UK', 'University of Sheffield', 'Robert Gaizauskas'],
#   ['UK', 'Imperial College London', 'Krystian Mikolajczyk'],
#   ['Spain', 'Universitat Politècnica de València', 'Joan Puigcerver'],
#   ['Spain', 'Universitat Politècnica de València', 'Alejandro Toselli'],
#   ['Spain', 'Universitat Politècnica de València', 'Joan-Andreu Sánchez'],
#   ['Spain', 'Universitat Politècnica de València', 'Enrique Vidal']],
#  [['France', 'Inria', 'Alexis Joly'],
#   ['France', 'IRD', 'Hervé Goëau'],
#   ['France', 'AMU', 'Hervé Glotin'],
#   ['Italy', 'University of Catania', 'Concetto Spampinato'],
#   ['France', 'UMR AMAP', 'Pierre Bonnet'],
#   ['The Netherlands', 'Xeno-canto Foundation', 'Willem-Pier Vellinga'],
#   ['France', 'Inria', 'Julien Champ'],
#   ['The Netherlands', 'Xeno-canto Foundation', 'Robert Planqué'],
#   ['Italy', 'University of Catania', 'Simone Palazzo'],
#   ['Switzerland', 'HES-SO', 'Henning Müller']],
#  [['Germany', 'TU Berlin', 'Benjamin Kille'],
#   ['Germany', 'TU Berlin', 'Andreas Lommatzsch'],
#   ['The Netherlands', 'CWI', 'Gebrekirstos Gebremeskel'],
#   ['UK', 'University of Glasgow', 'Frank Hopfgartner'],
#   ['The Netherlands', 'TU Delft', 'Martha Larson'],
#   ['The Netherlands', 'Radboud University Nijmegen', 'Martha Larson'],
#   ['Germany', 'Plista GmbH', 'Jonas Seiler'],
#   ['Italy', 'ContentWise R&D -Moviri', 'Davide Malagoli'],
#   ['Hungary', 'Gravity Research', 'András Serény'],
#   ['Germany', 'Plista GmbH', 'Torben Brodt'],
#   ['The Netherlands', 'Radboud University Nijmegen', 'Arjen De Vries']],
#  [['Spain', 'PRHLT Research Center', 'Paolo Rosso'],
#   ['Spain', 'Autoritas Consulting, S.A', 'Francisco Rangel'],
#   ['Germany', 'Web Technology and Information Systems', 'Martin Potthast'],
#   ['Greece',
#    'Department of Information and Communication Systems Engineering',
#    'Efstathios Stamatatos'],
#   ['Austria', 'Department of Computer Science', 'Michael Tschuggnall'],
#   ['Germany', 'Web Technology and Information Systems', 'Benno Stein']],
#  [['The Netherlands', 'University of Amsterdam', 'Marijn Koolen'],
#   ['The Netherlands',
#    'Netherlands Institute for Sound and Vision',
#    'Marijn Koolen'],
#   ['Denmark', 'Aalborg University Copenhagen', 'Toine Bogers'],
#   ['Germany', 'Humboldt University Berlin', 'Maria Gäde'],
#   ['The Netherlands', 'CLS/CLST', 'Mark Hall'],
#   ['UK', 'Edge Hill University', 'Iris Hendrickx'],
#   ['The Netherlands', 'University of Amsterdam', 'Hugo Huurdeman'],
#   ['The Netherlands', 'University of Amsterdam', 'Jaap Kamps'],
#   ['Denmark', 'Aalborg University', 'Mette Skov'],
#   ['UK', 'Edge Hill University', 'Suzan Verberne'],
#   ['The Netherlands', 'CLS/CLST', 'David Walsh']],
#  [['France', 'LIG', 'Lorraine Goeuriot'],
#   ['France', 'IRIT', 'Josiane Mothe'],
#   ['France', 'LIG', 'Philippe Mulhem'],
#   ['UK', 'University of Derby', 'Fionn Murtagh'],
#   ['UK', 'Goldsmiths University of London', 'Fionn Murtagh'],
#   ['France', 'LIA', 'Eric Sanjuan']],
#  [['Switzerland',
#    'Eurospider Information Technology AG Schaffhauserstr. 18',
#    'Martin Braschler'],
#   ['Spain', 'Greenwich Univ. (UK)', 'Martin Braschler'],
#   ['Canada), UK) IAI (Germany',
#    'HKUST (Hong Kong) Univ. Amsterdam (Netherlands)',
#    'Martin Braschler'],
#   ['USA) *', 'IRIT (France)', 'Martin Braschler'],
#   ['Canada) * JHU-APL (USA',
#    'ITC-irst (Italy) * Univ. Montreal/RALI',
#    'Martin Braschler'],
#   ['Thailand', 'Univ. Neuchâtel (Switzerland)', 'Martin Braschler'],
#   ['Spain', 'Univ. Salamanca', 'Martin Braschler'],
#   ['Canada', 'KCSL Inc', 'Martin Braschler'],
#   ['UK) * Medialab (Netherlands', 'Univ. Sheffield', 'Martin Braschler'],
#   ['Finland', 'Univ. Tampere', 'Martin Braschler'],
#   ['Japan), Netherlands) *', 'Nara Inst. of Tech. (', 'Martin Braschler']],
#  [['Switzerland', "Institut interfacultaire d'informatique", 'Jacques Savoy']],
#  [['USA', 'School of Information Management and Systems', 'Aitao Chen']],
#  [['U.K', 'Department of Computer Science', 'Gareth Jones'],
#   ['U.K', 'Department of Computer Science', 'Adenike Lam-Adesina'],
#   ['U.K', 'Department of Computer Science', '{g Jones'],
#   ['U.K', 'Department of Computer Science', 'A Lam']],
#  [['The Netherlands', 'TNO-TPD', 'Wessel Kraaij']],
#  [['Italy',
#    'ITC-irst -Centro per la Ricerca Scientifica e Tecnologica',
#    'Nicola Bertoldi'],
#   ['Italy',
#    'ITC-irst -Centro per la Ricerca Scientifica e Tecnologica',
#    'Marcello Federico']],
#  [['Switzerland',
#    'Eurospider Information Technology AG Schaffhauserstr. 18',
#    'Martin Braschler'],
#   ['Switzerland',
#    'Eurospider Information Technology AG Schaffhauserstr. 18',
#    'Bärbel Ripplinger'],
#   ['Switzerland',
#    'Eurospider Information Technology AG Schaffhauserstr. 18',
#    'Peter Schäuble']],
#  [['TAIWAN',
#    'Department of Computer Science and Information Engineering',
#    'Wen-Cheng Lin'],
#   ['TAIWAN',
#    'Department of Computer Science and Information Engineering',
#    'Hsin-Hsi Chen']],
#  [['Finland', 'Department of Information Studies', 'Turid Hedlund'],
#   ['Finland', 'Department of Information Studies', 'Heikki Keskustalo'],
#   ['Finland', 'Department of Information Studies', 'Ari Pirkola'],
#   ['Finland', 'Department of Information Studies', 'Eija Airio'],
#   ['Finland', 'Department of Information Studies', 'Kalervo Järvelin']],
#  [['Canada',
#    "Département d'Informatique et Recherche Opérationnelle",
#    'Jian-Yun Nie'],
#   ['Canada',
#    "Département d'Informatique et Recherche Opérationnelle",
#    'Michel Simard']],
#  [],
#  [],
#  [['Sweden', 'Swedish Institute of Computer Science', 'Magnus Sahlgren'],
#   ['Sweden', 'Swedish Institute of Computer Science', 'Jussi Karlgren']],
#  [['Japan', 'Graduate School of Information Science', 'Fatiha Sadat'],
#   ['Japan', 'Graduate School of Information Science', 'Akira Maeda'],
#   ['Japan', 'CREST', 'Akira Maeda'],
#   ['Japan', 'Graduate School of Information Science', 'Masatoshi Yoshikawa'],
#   ['Japan', 'Graduate School of Information Science', 'Shunsuke Uemura']],
#  [['Spain', 'Dpto. Computer Science', 'Fernando Martínez-Santiago'],
#   ['Spain', 'Dpto. Computer Science', 'L Alfonso Ureña-López'],
#   ['Spain', 'Dpto. Computer Science', 'M Carlos Díaz-Galiano'],
#   ['Spain', 'Dpto. Computer Science', 'Maite Martín-Valdivia'],
#   ['Spain', 'Dpto. Computer Science', 'Manuel García-Vega']],
#  [['USA', 'Applied Physics Lab', 'Paul Mcnamee'],
#   ['USA', 'Applied Physics Lab', 'James Mayfield']],
#  [['Thailand', 'Department of Computer Science', 'Jaruskulchai Chuleerat']],
#  [['Scotland', 'Department of Computing Science', 'Mirna Adriani']],
#  [['USA', 'Thomson Legal & Regulatory', 'Hugo Molina-Salgado'],
#   ['USA', 'Thomson Legal & Regulatory', 'Isabelle Moulinier'],
#   ['USA', 'Thomson Legal & Regulatory', 'Mark Knudson'],
#   ['USA', 'Thomson Legal & Regulatory', 'Elizabeth Lund'],
#   ['USA', 'Thomson Legal & Regulatory', 'Kirat Sekhon']],
#  [['USA', 'School of Information Management and Systems', 'Hailing Jiang'],
#   ['USA', 'School of Information Management and Systems', 'Natalia Perelman']],
#  [['Spain',
#    'Grupo de investigación en Procesamiento del Lenguaje y Sistemas de Información Departamento de Lenguajes y Sistemas Informáticos Universidad de Alicante Alicante',
#    'Fernando Llopis'],
#   ['Spain',
#    'Grupo de investigación en Procesamiento del Lenguaje y Sistemas de Información Departamento de Lenguajes y Sistemas Informáticos Universidad de Alicante Alicante',
#    'José Vicedo']],
#  [['Spain',
#    'Universidad de Salamanca c/ Francisco de Vitoria',
#    'Carlos Figuerola'],
#   ['Spain',
#    'Universidad de Salamanca c/ Francisco de Vitoria',
#    'Raquel Gómez'],
#   ['Spain',
#    'Universidad de Salamanca c/ Francisco de Vitoria',
#    'Angel Zazo Rodríguez'],
#   ['Spain', 'Universidad de Salamanca c/ Francisco de Vitoria', 'José Luis'],
#   ['Spain',
#    'Universidad de Salamanca c/ Francisco de Vitoria',
#    'Alonso Berrocal']],
#  [['The Netherlands', 'Language & Inference Technology', ' ']],
#  [['Canada', 'Hummingbird Ottawa', 'Stephen Tomlinson']],
#  [],
#  [],
#  [],
#  [['The Netherlands', 'Océ Technologies', 'Jakob Klok'],
#   ['The Netherlands', 'Océ Technologies', 'Samuel Driessen'],
#   ['The Netherlands', 'Océ Technologies', 'Marvin Brunner']],
#  [['USA',
#    'Human Computer Interaction Laboratory College of Information Studies and Institute for Advanced Computer Studies',
#    'Douglas Oard'],
#   ['SPAIN',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Julio Gonzalo']],
#  [['SPAIN',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Fernando López-Ostenero'],
#   ['SPAIN',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Julio Gonzalo'],
#   ['SPAIN',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Anselmo Peñas'],
#   ['SPAIN',
#    'Departamento de Lenguajes y Sistemas Informáticos',
#    'Felisa Verdejo']],
#  [['UK', 'Department of Information Studies', 'Mark Sanderson'],
#   ['UK', 'Department of Information Studies', 'Zoë Bathie']],
#  [['USA',
#    'Human Computer Interaction Laboratory College of Information Studies and Institute for Advanced Computer Studies',
#    'Jianqiang Wang'],
#   ['USA',
#    'Human Computer Interaction Laboratory College of Information Studies and Institute for Advanced Computer Studies',
#    'Douglas Oard']],
#  [['USA', 'National Institute of Standards and Technology', 'Ellen Voorhees']],
#  [['Japan', 'National Institute of Informatics (NII', 'Noriko Kando'],
#   ['Japan) Fujitsu Laboratories (Japan), China PRC',
#    'Fujitsu R&D Center',
#    'Noriko Kando'],
#   ['Japan', 'Central Research Laboratory', 'Noriko Kando'],
#   ['China PRC', 'Hong Kong Polytechnic (Hong Kong', 'Noriko Kando'],
#   ['China', 'Institute of Software', 'Noriko Kando'],
#   ['Japan', 'JUSTSYSTEM Corp', 'Noriko Kando'],
#   ['Japan', 'Kanagawa Univ', 'Noriko Kando'],
#   ['Korea', 'KAIST/KORTERM', 'Noriko Kando'],
#   ['Japan', 'Matsushita Electric Industrial', 'Noriko Kando'],
#   ['Taiwan, ROC), Japan', 'NEC Media Research Laboratories', 'Noriko Kando'],
#   ['Japan', 'National Institute of Informatics', 'Noriko Kando'],
#   ['Japan', 'NTT-CS & NAIST', 'Noriko Kando'],
#   ['Japan', 'OASIS', 'Noriko Kando'],
#   ['Japan', 'Osaka Kyoiku Univ', 'Noriko Kando'],
#   ['Japan), Japan', 'Surugadai Univ', 'Noriko Kando'],
#   ['Taiwan ROC', 'Trans EZ Co', 'Noriko Kando'],
#   ['Japan), UK', 'Univ. of California Berkeley (US)', 'Noriko Kando'],
#   ['Japan',
#    'Univ. of Library and Information Science (Japan) Univ. of Maryland (US)',
#    'Noriko Kando'],
#   ['Japan), Japan', 'Yokohama National Univ', 'Noriko Kando'],
#   ['Japan', 'Waseda Univ', 'Noriko Kando']],
#  [['Germany', 'Information Science', 'Christa Womser-Hacker']],
#  [['Switzerland',
#    'Eurospider Information Technology AG Schaffhauserstr. 18',
#    'Martin Braschler'],
#   ['Italy', 'IEI-CNR', 'Carol Peters']],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...
#   ['Switzerland', 'BiTeM Group', 'Arnaud Gaudinat'],
#   ['Switzerland', 'BiTeM Group', 'Patrick Ruch'],
#   ['Switzerland', 'SIBtex Group', 'Patrick Ruch']],
#  [['Switzerland', 'Université de Neuchâtel', 'Melanie Imhof'],
#   ['Switzerland', 'Zurich University of Applied Sciences', 'Melanie Imhof'],
#   ['Switzerland',
#    'Zurich University of Applied Sciences',
#    'Martin Braschler']],
#  [['Croatia',
#    'Faculty of Electrical Engineering and Computing',
#    'Mladen Karan'],
#   ['Croatia',
#    'Faculty of Electrical Engineering and Computing',
#    'Jan Šnajder']],
#  [['Sweden', 'Kungl Tekniska Högskolan', 'Jussi Karlgren'],
#   ['USA', 'University of Michigan', 'Kevyn Collins-Thompson'],
#   ['Canada', 'McGill University', 'David Jurgens'],
#   ['UK', 'University of Cambridge', 'Anna Korhonen'],
#   ['Germany', 'Ludwig-Maximilians-Universität', 'Hinrich Schütze']],
#  [['The Netherlands',
#    'Department of Information and Computing Sciences',
#    'Hendrik Koops'],
#   ['The Netherlands',
#    'Department of Information and Computing Sciences',
#    'Jan Van Balen'],
#   ['The Netherlands',
#    'Department of Information and Computing Sciences',
#    'Frans Wiering']],
#  [['Greece', 'University of the Aegean', 'Dimitrios Pritsos'],
#   ['Greece', 'University of the Aegean', 'Efstathios Stamatatos']],
#  [['Spain', 'NLE Lab', 'Francisco Rangel'],
#   ['Spain', 'Autoritas Consulting, S.A', 'Francisco Rangel'],
#   ['Spain', 'NLE Lab', 'Paolo Rosso']],
#  [['Canada', 'DIRO', 'Wei Shen'], ['Canada', 'DIRO', 'Jian-Yun Nie']],
#  [['Austria',
#    'Institute of Software Technology and Interactive Systems (ISIS)',
#    ' ']],
#  [['Czech Republic', 'Faculty of Informatics', 'Šimon Suchomel'],
#   ['Czech Republic', 'Faculty of Informatics', 'Michal Brandejs']],
#  [['Austria',
#    'Institute of Software Technology and Interactive Systems',
#    'Wolfgang Tannebaum'],
#   ['Austria',
#    'Institute of Software Technology and Interactive Systems',
#    'Andreas Rauber']],
#  [['UK', 'Information School', 'Simon Wakeling'],
#   ['UK', 'Information School', 'Paul Clough']],
#  [['Germany', 'Technische Universität Chemnitz', 'Thomas Wilhelm-Stein'],
#   ['Germany', 'Technische Universität Chemnitz', 'Maximilian Eibl']],
#  [['Tunisia', 'INSAT', ' Zingla'],
#   ['Tunisia', 'Faculty of Sciences of Tunis', ' Zingla'],
#   ['Tunisia', 'Faculty of Sciences of Tunis', 'Chiraz Latiri'],
#   ['Tunisia', 'INSAT', 'Yahya Slimani']],
#  [['Czech Republic', 'Masaryk University', 'Petra Budikova'],
#   ['Czech Republic', 'Masaryk University', 'Michal Batko'],
#   ['Czech Republic', 'Masaryk University', 'Jan Botorek'],
#   ['Czech Republic', 'Masaryk University', 'Pavel Zezula']],
#  [['France',
#    "LIA/Université d'Avignon Et des Pays de Vaucluse",
#    'Jean-Valère Cossu'],
#   ['France',
#    "LIA/Université d'Avignon Et des Pays de Vaucluse",
#    'Emmanuel Ferreira'],
#   ['France',
#    "LIA/Université d'Avignon Et des Pays de Vaucluse",
#    'Killian Janod'],
#   ['France', 'ORKIS', 'Killian Janod'],
#   ['France',
#    "LIA/Université d'Avignon Et des Pays de Vaucluse",
#    'Julien Gaillard'],
#   ['France',
#    "LIA/Université d'Avignon Et des Pays de Vaucluse",
#    'Marc El-Bèze']],
#  [['France',
#    'Institut de Recherche en Informatique de Toulouse',
#    'Liana Ermakova'],
#   ['Russia', 'Perm State National Research University', 'Liana Ermakova']],
#  [['Germany', 'Animal Sound Archive', 'Mario Lasseck']],
#  [['Germany',
#    'Agent Technologies in Business Applications and Telecommunication Group (AOT)',
#    'Andreas Lommatzsch'],
#   ['Germany',
#    'Database Systems and Information Management Group (DIMA)',
#    'Sebastian Werner']],
#  [['India',
#    'International Institute of Information Technology',
#    'Veera Raghavendra Chikka'],
#   ['India', 'Research and Development Centre', 'Nestor Mariyasagayam'],
#   ['Japan', 'Central Research Laboratory', 'Yoshiki Niwa'],
#   ['India',
#    'International Institute of Information Technology',
#    'Kamalakar Karlapalem']],
#  [['Mexico', 'Centro de Investigacin en Computacin', 'Miguel Sanchez-Perez'],
#   ['Mexico', 'Centro de Investigacin en Computacin', 'Alexander Gelbukh'],
#   ['Mexico', 'Centro de Investigacin en Computacin', 'Grigori Sidorov']],
#  [['China', 'Institute of Computer Science & Technology', 'Kun Xu'],
#   ['China', 'Institute of Computer Science & Technology', 'Yansong Feng'],
#   ['China', 'China Research Lab', 'Songfang Huang'],
#   ['China', 'Institute of Computer Science & Technology', 'Dongyan Zhao']],
#  [['France', 'LIG', 'Lorraine Goeuriot'],
#   ['Ireland', 'ADAPT Centre', 'Liadh Kelly'],
#   ['Australia', 'NICTA', 'Hanna Suominen'],
#   ['Australia', 'The Australian National University', 'Hanna Suominen'],
#   ['Australia', 'University of Canberra', 'Hanna Suominen'],
#   ['Finland', 'University of Turku', 'Hanna Suominen'],
#   ['Australia', 'NICTA', 'Leif Hanlen'],
#   ['Australia', 'The Australian National University', 'Leif Hanlen'],
#   ['Australia', 'University of Canberra', 'Leif Hanlen'],
#   ['France', 'LIMSI CNRS UPR 3251', 'Aurélie Névéol'],
#   ['France', 'LIMSI CNRS UPR 3251', 'Cyril Grouin'],
#   ['Austria', 'Vienna University of Technology', 'João Palotti'],
#   ['Australia', 'Queensland University of Technology', 'Guido Zuccon']],
#  [['Spain', 'Universitat Politècnica de València', 'Mauricio Villegas'],
#   ['Switzerland',
#    'University of Applied Sciences Western Switzerland (HES-SO)',
#    'Henning Müller'],
#   ['UK', 'University of Surrey', 'Andrew Gilbert'],
#   ['Italy', 'University of Cagliari', 'Luca Piras'],
#   ['UK', 'University of She\ue001eld', 'Josiah Wang'],
#   ['UK', 'University of Surrey', 'Krystian Mikolajczyk'],
#   ['Switzerland',
#    'University of Applied Sciences Western Switzerland (HES-SO)',
#    'Alba Seco De Herrera'],
#   ['Switzerland',
#    'University of Applied Sciences Western Switzerland (HES-SO)',
#    'Stefano Bromuri'],
#   ['Bangladesh', 'Independent University', 'M Amin'],
#   ['Bangladesh', 'Sir Salimullah Medical College', 'Mahmood Kazi Mohammed'],
#   ['Turkey', 'Bogazici University', 'Burak Acar'],
#   ['Turkey', 'Bogazici University', 'Suzan Uskudarli'],
#   ['Turkey', 'Bogazici University', 'Neda Marvasti'],
#   ['Spain', 'University of Malaga', 'José Aldana'],
#   ['Spain', 'University of Malaga', 'Roldán García']],
#  [['France', 'Inria', 'Alexis Joly'],
#   ['France', 'Inria', 'Hervé Goëau'],
#   ['France', 'IUF & University de Toulon', 'Hervé Glotin'],
#   ['Italy', 'University of Catania', 'Concetto Spampinato'],
#   ['France', 'CIRAD-Amap', 'Pierre Bonnet'],
#   ['The Netherlands', 'Xeno-canto Foundation', 'Willem-Pier Vellinga'],
#   ['The Netherlands', 'Xeno-canto Foundation', 'Robert Planqué'],
#   ['Austria', 'Vienna University of Technology', 'Andreas Rauber'],
#   ['Italy', 'University of Catania', 'Simone Palazzo'],
#   ['UK', 'University of Edinburgh', 'Bob Fisher'],
#   ['Switzerland', 'HES-SO', 'Henning Müller']],
#  [['The Netherlands', 'University of Amsterdam', 'Anne Schuth'],
#   ['Norway', 'University of Stavanger', 'Krisztian Balog'],
#   ['Ireland', 'ADAPT Centre', 'Liadh Kelly']],
#  [['Germany', 'TU Berlin', 'Benjamin Kille'],
#   ['Germany', 'TU Berlin', 'Andreas Lommatzsch'],
#   ['Italy', 'ContentWise R&D -Moviri', 'Roberto Turrin'],
#   ['Hungary', 'Gravity R&D', 'András Serény'],
#   ['The Netherlands', 'TU Delft', 'Martha Larson'],
#   ['Germany', 'Plista GmbH', 'Torben Brodt'],
#   ['Germany', 'Plista GmbH', 'Jonas Seiler'],
#   ['UK', 'University of Glasgow', 'Frank Hopfgartner']],
#  [['Greece',
#    'Department of Information & Communication Systems Engineering',
#    'Efstathios Stamatatos'],
#   ['Germany', 'Web Technology & Information Systems', 'Martin Potthast'],
#   ['Spain', 'Autoritas Consulting, S.A', 'Francisco Rangel'],
#   ['Spain', 'Natural Language Engineering Lab', 'Francisco Rangel'],
#   ['Spain', 'Natural Language Engineering Lab', 'Paolo Rosso'],
#   ['Germany', 'Web Technology & Information Systems', 'Benno Stein']],
#  [['Spain', 'NLP&IR Group', 'Anselmo Peñas'],
#   ['Germany', 'CITEC', 'Christina Unger'],
#   ['Greece', 'IIT', 'Georgios Paliouras'],
#   ['USA', 'Deptartment of Computer Science', 'Ioannis Kakadiaris']],
#  [['Netherlands', 'University of Amsterdam', 'Marijn Koolen'],
#   ['Denmark', 'Aalborg University Copehagen', 'Toine Bogers'],
#   ['Germany', 'Humboldt University Berlin', 'Maria Gäde'],
#   ['UK', 'Edge Hill University', 'Mark Hall'],
#   ['Netherlands', 'University of Amsterdam', 'Hugo Huurdeman'],
#   ['Netherlands', 'University of Amsterdam', 'Jaap Kamps'],
#   ['Denmark', 'Aalborg University', 'Mette Skov'],
#   ['UK', 'University of She\ue001eld', 'Elaine Toms'],
#   ['UK', 'Edge Hill University', 'David Walsh']],
#  [['Russia', 'Ural Federal University', 'Vladislav Blinov'],
#   ['Russia', 'Ural Federal University', 'Kirill Mishchenko'],
#   ['Russia', 'Ural Federal University', 'Valeria Bolotova'],
#   ['Russia', 'Ural Federal University', 'Pavel Braslavski']],
#  [['Germany',
#    'Berlin School of Library and Information Science',
#    'Florian Dietz'],
#   ['Germany',
#    'Berlin School of Library and Information Science',
#    'Vivien Petras']],
#  [['Germany',
#    'Berlin School of Library and Information Science',
#    'Florian Dietz'],
#   ['Germany',
#    'Berlin School of Library and Information Science',
#    'Vivien Petras']],
#  [['Ireland', 'School of Computing', 'Ahmad Khwileh'],
#   ['Ireland', 'School of Computing', 'Andy Way'],
#   ['Ireland', 'School of Computing', 'Gareth Jones']],
#  [['Germany', 'Department of Computer Science', 'Sven Koitka'],
#   ['Germany', 'Department of Computer Science', 'Sven Koitka'],
#   ['Germany', 'Department of Computer Science', 'Christoph Friedrich']],
#  [['France', 'UMR 5505', 'Serge Molina'],
#   ['France', 'UMR 5505', 'Josiane Mothe'],
#   ['France', 'UMR 5505', 'Dorian Roques'],
#   ['France', 'CLLE-ERSS', 'Ludovic Tanguy'],
#   ['France', 'UMR 5505', 'Zia Ullah']],
#  [['Germany', 'University of Konstanz', 'Moritz Schubotz'],
#   ['Germany', 'University of Konstanz', 'Leonard Krämer'],
#   ['Germany', 'University of Konstanz', 'Norman Meuschke'],
#   ['Germany', 'University of Konstanz', 'Felix Hamborg'],
#   ['Germany', 'University of Konstanz', 'Bela Gipp']],
#  [['Ireland', 'School of Computing', 'Piyush Arora'],
#   ['Ireland', 'School of Computing', 'Jennifer Foster'],
#   ['Ireland', 'School of Computing', 'Gareth Jones']],
#  [['USA', 'Carnegie Mellon University', 'Khyathi Chandu'],
#   ['India', 'Microsoft India', 'Manoj Chinnakotla'],
#   ['USA', 'Carnegie Mellon University', 'Alan Black'],
#   ['India', 'IIIT Hyderabad', 'Manish Shrivastava']],
#  [['Italy', 'Dipartimento di Informatica', 'Mirko Lai'],
#   ['Spain', 'PRHLT Research Center', 'Mirko Lai'],
#   ['Italy', 'Dipartimento di Informatica', 'Marcella Tambuscio'],
#   ['Italy', 'Dipartimento di Informatica', 'Viviana Patti'],
#   ['Italy', 'Dipartimento di Informatica', 'Giancarlo Ruffo'],
#   ['Spain', 'PRHLT Research Center', 'Paolo Rosso']],
#  [['Russia', 'RusProfiling Lab', 'Tatiana Litvinova'],
#   ['Russia', 'The Kurchatov Institute', 'Tatiana Litvinova'],
#   ['Russia', 'RusProfiling Lab', 'Pavel Seredin'],
#   ['Russia', 'Voronezh State University', 'Pavel Seredin'],
#   ['Russia', 'The Kurchatov Institute', 'Pavel Seredin'],
#   ['Russia', 'RusProfiling Lab', 'Olga Litvinova'],
#   ['Russia', 'RusProfiling Lab', 'Ekaterina Ryzhkova']],
#  [['Ireland', 'Insight Centre for Data Analytics', 'Raul Moreno'],
#   ['Ireland', 'Insight Centre for Data Analytics', 'Wěipéng Huáng'],
#   ['Ireland', 'Insight Centre for Data Analytics', 'Arjumand Younus'],
#   ['Ireland', 'Insight Centre for Data Analytics', "Michael O'mahony"],
#   ['Ireland', 'Insight Centre for Data Analytics', 'Neil Hurley']],
#  [['Sweden', 'Uppsala University', 'Magdalena Parks'],
#   ['Sweden', 'Uppsala University', 'Sara Stymne']],
#  [['Greece', 'University of the Aegean', 'Nektaria Potha'],
#   ['Greece', 'University of the Aegean', 'Efstathios Stamatatos']],
#  [['Mexico', 'Center for Computing Research', 'Miguel Sanchez-Perez'],
#   ['Mexico', 'Center for Computing Research', 'Ilia Markov'],
#   ['Mexico', 'Center for Computing Research', 'Helena Gómez-Adorno'],
#   ['Mexico', 'Center for Computing Research', 'Grigori Sidorov']],
#  [['Germany', 'TH Köln (University of Applied Sciences)', 'Philipp Schaer'],
#   ['Germany', 'TH Köln (University of Applied Sciences)', 'Mandy Neumann']],
#  [['Germany',
#    'Agent Technologies in Business Applications and Telecommunication Group (AOT)',
#    'Jaschar Domann'],
#   ['Germany',
#    'Agent Technologies in Business Applications and Telecommunication Group (AOT)',
#    'Andreas Lommatzsch']],
#  [['Bulgaria', 'Faculty of Mathematics and Informatics', 'Georgi Karadzhov'],
#   ['Bulgaria',
#    'Faculty of Mathematics and Informatics',
#    'Tsvetomila Mihaylova'],
#   ['Bulgaria', 'Faculty of Mathematics and Informatics', 'Yasen Kiprov'],
#   ['Bulgaria', 'Faculty of Mathematics and Informatics', 'Georgi Georgiev'],
#   ['Bulgaria', 'Faculty of Mathematics and Informatics', 'Ivan Koychev'],
#   ['Qatar', 'Qatar Computing Research Institute', 'Preslav Nakov']],
#  [['Switzerland', 'Computer Science Department', 'Mirco Kocher'],
#   ['Switzerland', 'Computer Science Department', 'Jacques Savoy']],
#  [['USA', 'Department of Computer and Information Sciences', 'Pengyuan Li'],
#   ['USA',
#    'Department of Computer and Information Sciences',
#    'Xiangying Jiang'],
#   ['USA',
#    'Department of Computer and Information Sciences',
#    'Chandra Kambhamettu'],
#   ['USA', 'Department of Computer and Information Sciences', 'Hagit Shatkay']],
#  [['The Netherlands', 'University of Groningen', 'Maria Medvedeva'],
#   ['The Netherlands', 'University of Groningen', 'Hessel Haagsma'],
#   ['The Netherlands', 'University of Groningen', 'Malvina Nissim']],
#  [['France', 'LIG', 'Philippe Mulhem'],
#   ['France', 'LIG', 'Lorraine Goeuriot'],
#   ['France', 'LIG', 'Nayanika Dogra'],
#   ['France', 'LIG', 'Nawal Amer']],
#  [['Germany', 'TU Berlin', 'Andreas Lommatzsch'],
#   ['Germany', 'TU Berlin', 'Benjamin Kille'],
#   ['UK', 'University of Glasgow', 'Frank Hopfgartner'],
#   ['Netherlands', 'Radboud University', 'Martha Larson'],
#   ['Netherlands', 'TU Delft', 'Martha Larson'],
#   ['Germany', 'Plista GmbH', 'Torben Brodt'],
#   ['Germany', 'Plista GmbH', 'Jonas Seiler'],
#   ['Norway', 'NTNU', 'Özlem Özgöbek']],
#  [['France', 'Inria', 'Alexis Joly'],
#   ['France', 'UMR AMAP', 'Hervé Goëau'],
#   ['France', 'AMU', 'Hervé Glotin'],
#   ['Italy', 'University of Catania', 'Concetto Spampinato'],
#   ['France', 'UMR AMAP', 'Pierre Bonnet'],
#   ['The Netherlands', 'Xeno-canto Foundation', 'Willem-Pier Vellinga'],
#   ['France', 'Inria', 'Jean-Christophe Lombardo'],
#   ['The Netherlands', 'Xeno-canto Foundation', 'Robert Planqué'],
#   ['Italy', 'University of Catania', 'Simone Palazzo'],
#   ['Switzerland', 'HES-SO', 'Henning Müller']],
#  [['Germany', 'Web Technology and Information Systems', 'Martin Potthast'],
#   ['Spain', 'Autoritas Consulting, S.A', 'Francisco Rangel'],
#   ['Spain', 'PRHLT Research Center', 'Francisco Rangel'],
#   ['Austria', 'Department of Computer Science', 'Michael Tschuggnall'],
#   ['Greece',
#    'Department of Information and Communication Systems Engineering',
#    'Efstathios Stamatatos'],
#   ['Spain', 'PRHLT Research Center', 'Paolo Rosso'],
#   ['Germany', 'Web Technology and Information Systems', 'Benno Stein']],
#  [['France', 'LIG', 'Lorraine Goeuriot'],
#   ['Ireland', 'ADAPT Centre', 'Liadh Kelly'],
#   ['Australia', 'Data61/CSIRO', 'Hanna Suominen'],
#   ['Australia', 'University of Canberra', 'Hanna Suominen'],
#   ['Finland', 'University of Turku', 'Hanna Suominen'],
#   ['France', 'LIMSI CNRS UPR 3251', 'Aurélie Névéol'],
#   ['France', 'INSERM -CépiDc', 'Aude Robert'],
#   ['Netherlands', 'Informatics Institute', 'Evangelos Kanoulas'],
#   ['Cochrane Netherlands, Netherlands',
#    'Julius Center for Health Sciences and Primary Care',
#    'Rene Spijker'],
#   ['Austria', 'Vienna University of Technology', 'João Palotti'],
#   ['Australia', 'Queensland University of Technology', 'Guido Zuccon']],
#  [['France', 'LISIS (UPEM', 'Liana Ermakova'],
#   ['France', 'LIG', 'Lorraine Goeuriot'],
#   ['France', 'IRIT', 'Josiane Mothe'],
#   ['France', 'LIG', 'Philippe Mulhem'],
#   ['Canada', 'RALI', 'Jian-Yun Nie'],
#   ['France', 'LIA', 'Eric Sanjuan']],
#  ...]

# %%
df_lncs["grobid"] = list_metadata_grobid_extract

# %%
df_lncs
# Out:
#      PubYear                                      Book Subtitle  \
# 0       2005  6th Workshop of the Cross-Language Evaluation ...
# 1       2005  6th Workshop of the Cross-Language Evaluation ...
# 2       2005  6th Workshop of the Cross-Language Evaluation ...
# 3       2005  6th Workshop of the Cross-Language Evaluation ...
# 4       2005  6th Workshop of the Cross-Language Evaluation ...
# ...      ...                                                ...
# 1220    2013  4th International Conference of the CLEF Initi...
# 1221    2013  4th International Conference of the CLEF Initi...
# 1222    2013  4th International Conference of the CLEF Initi...
# 1223    2013  4th International Conference of the CLEF Initi...
# 1224    2013  4th International Conference of the CLEF Initi...
#
#                                              Book Title  \
# 0       Accessing Multilingual Information Repositories
# 1       Accessing Multilingual Information Repositories
# 2       Accessing Multilingual Information Repositories
# 3       Accessing Multilingual Information Repositories
# 4       Accessing Multilingual Information Repositories
# ...                                                 ...
# 1220  Information Access Evaluation. Multilinguality...
# 1221  Information Access Evaluation. Multilinguality...
# 1222  Information Access Evaluation. Multilinguality...
# 1223  Information Access Evaluation. Multilinguality...
# 1224  Information Access Evaluation. Multilinguality...
#
#                       Filename  \
# 0               11878773_2.pdf
# 1               11878773_3.pdf
# 2               11878773_4.pdf
# 3               11878773_5.pdf
# 4               11878773_6.pdf
# ...                        ...
# 1220  978-3-642-40802-1_28.pdf
# 1221  978-3-642-40802-1_29.pdf
# 1222  978-3-642-40802-1_30.pdf
# 1223  978-3-642-40802-1_31.pdf
# 1224  978-3-642-40802-1_32.pdf
#
#                                                   Title  \
# 0                      CLEF 2005: Ad Hoc Track Overview
# 1     Ad-Hoc Mono- and Bilingual Retrieval Experimen...
# 2     MIRACLE at Ad-Hoc CLEF 2005: Merging and Combi...
# 3           The XLDB Group at the CLEF 2005 Ad-Hoc Task
# 4     Thomson Legal and Regulatory Experiments at CL...
# ...                                                 ...
# 1220  Recent Trends in Digital Text Forensics and It...
# 1221  QA4MRE 2011-2013: Overview of Question Answeri...
# 1222  Multilingual Question Answering over Linked Da...
# 1223  Overview of RepLab 2013: Evaluating Online Rep...
# 1224  Entity Recognition in Parallel Multi-lingual B...
#
#                                                 Section     Subsection  \
# 0     Part I. Multilingual Textual Document Retrival...  Uncategorized
# 1                               Cross-Language and More  Uncategorized
# 2                               Cross-Language and More  Uncategorized
# 3                               Cross-Language and More  Uncategorized
# 4                               Cross-Language and More  Uncategorized
# ...                                                 ...            ...
# 1220                                      Lab Overviews  Uncategorized
# 1221                                      Lab Overviews  Uncategorized
# 1222                                      Lab Overviews  Uncategorized
# 1223                                      Lab Overviews  Uncategorized
# 1224                                      Lab Overviews  Uncategorized
#
#                                                DOI Citation count  \
# 0               https://doi.org/10.1007/11878773_2             17
# 1               https://doi.org/10.1007/11878773_3      Not found
# 2               https://doi.org/10.1007/11878773_4              4
# 3               https://doi.org/10.1007/11878773_5              3
# 4               https://doi.org/10.1007/11878773_6              1
# ...                                            ...            ...
# 1220  https://doi.org/10.1007/978-3-642-40802-1_28             15
# 1221  https://doi.org/10.1007/978-3-642-40802-1_29             13
# 1222  https://doi.org/10.1007/978-3-642-40802-1_30             36
# 1223  https://doi.org/10.1007/978-3-642-40802-1_31             49
# 1224  https://doi.org/10.1007/978-3-642-40802-1_32              9
#
#                                  Authors & Affiliations         ID  \
# 0     [['Department of Information Engineering, Univ...     lncs_2
# 1     [['Information Science, University of Hildeshe...     lncs_3
# 2     [['Universidad Politécnica de Madrid, \xa0', [...     lncs_4
# 3     [['Departamento de Informática, Grupo XLDB, Fa...     lncs_5
# 4     [['Thomson Legal and Regulatory, 610 Opperman ...     lncs_6
# ...                                                 ...        ...
# 1220  [['Web Technology and Information Systems, Bau...  lncs_1339
# 1221  [['NLP&IR Group, UNED, Spain', ['Anselmo Peñas...  lncs_1340
# 1222  [['CITEC, Universität Bielefeld, Germany', ['P...  lncs_1341
# 1223  [['UNED NLP and IR Group, Juan del Rosal, 16, ...  lncs_1342
# 1224  [['Department of Computational Linguistics, Un...  lncs_1343
#
#                                               Countries  \
# 0     [[Italy, University of Padua, Giorgio Maria Di...
# 1     [[Germany, University of Hildesheim, René Hack...
# 2     [[Spain, Universidad Politécnica de Madrid, Jo...
# 3     [[Portugal, University of Lisbon, Nuno Cardoso...
# 4     [[United States, Thomson Reuters (United State...
# ...                                                 ...
# 1220  [[Germany, Bauhaus-Universität Weimar, Tim Gol...
# 1221  [[Spain, National University of Distance Educa...
# 1222  [[Germany, Bielefeld University, Philipp Cimia...
# 1223  [[Spain, National University of Distance Educa...
# 1224  [[Switzerland, University of Zurich, Dietrich ...
#
#                                                   paths  \
# 0     ./resources/XML_LNCS/6th Workshop of the Cross...
# 1     ./resources/XML_LNCS/6th Workshop of the Cross...
# 2     ./resources/XML_LNCS/6th Workshop of the Cross...
# 3     ./resources/XML_LNCS/6th Workshop of the Cross...
# 4     ./resources/XML_LNCS/6th Workshop of the Cross...
# ...                                                 ...
# 1220  ./resources/XML_LNCS/4th International Confere...
# 1221  ./resources/XML_LNCS/4th International Confere...
# 1222  ./resources/XML_LNCS/4th International Confere...
# 1223  ./resources/XML_LNCS/4th International Confere...
# 1224  ./resources/XML_LNCS/4th International Confere...
#
#                                                  grobid
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1220  [[Germany, Web Technology and Information Syst...
# 1221  [[Spain, NLP&IR Group, Anselmo Pen ˜as], [USA,...
# 1222  [[Germany, CITEC, Philipp Cimiano], [Ireland, ...
# 1223  [[Spain, UNED NLP and IR Group Juan del Rosal,...
# 1224  [[U.K, European Bioinformatics Institute, Diet...
#
# [1225 rows x 14 columns]

# %%
df_lncs.to_parquet("../../../data/network_parquet_files/Network_preparations_LNCS.parquet")
