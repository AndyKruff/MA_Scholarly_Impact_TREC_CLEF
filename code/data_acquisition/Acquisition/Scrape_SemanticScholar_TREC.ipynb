# %%
import re
import pandas as pd
import requests
import time
import json
from thefuzz import fuzz
import urllib.parse

# %%
url = "https://api.semanticscholar.org/graph/v1/paper/search/match"

# Insert your API key here
api_key = ""

headers = {
    "x-api-key": api_key  
}

# %%
def extract_years(title):
    return re.findall(r'\b\d{4}\b', title)

# %%
def fuzzy_match_lists(list1, list2, threshold_single, threshhold_avg):
    if len(list1) != len(list2):
        return False
        
    total_similarity = 0
    for item1, item2 in zip(list1, list2):
        similarity_score = fuzz.ratio(item1, item2)
        total_similarity += similarity_score
        if fuzz.ratio(item1, item2) < threshold_single:
            return False
    average_similarity = total_similarity / len(list1)

    if average_similarity > threshhold_avg:
        return True

# %%
df_trec = pd.read_parquet("../../../data/metadata_TREC.parquet")

# %%
data_trec = {}
non_matching_rows = []
threshhold = 75                   # Threshold for matching author names
threshold_avg = 85                # Threshold for average similarity in matching

for i, j in df_trec.iterrows():

    # Parameters for the API request to search for the paper by title
    params = {
        "query": j["Title"],
        "limit": 1,
        "fields": "corpusId,externalIds,citationCount,influentialCitationCount,authors,journal,title,citations.paperId"
    }

    # Send the API request and convert the response to JSON
    resp = requests.get(url, params=params, headers=headers).json()
   
    try:
        # Extract the title from the Semantic Scholar API response
        title_semantic = resp["data"][0]["title"]
        title_df = j["Title"]

        # Extract publication years from both titles
        years_semantic = extract_years(title_semantic)
        years_df = extract_years(title_df)

        # Extract and sort author last names from both sources
        sorted_author_list1 = sorted([i["name"].split()[-1] for i in resp["data"][0]["authors"]])
        sorted_author_list2 = sorted([i.split()[-1] for i in j["Authors"]])
        
        print(sorted_author_list1)
        print(sorted_author_list2)

        # Check if titles, years, and author lists match based on specified thresholds
        if fuzz.ratio(title_df, title_semantic) > 90 and years_df == years_semantic and fuzzy_match_lists(sorted_author_list1, sorted_author_list2, threshhold, threshold_avg) == True:
            # If matching, add the response data to data_trec
            data_trec[j["ID"]] = resp["data"]
        else:
            # If not matching, add the row to non_matching_rows
            non_matching_rows.append(j)
    except:
        # In case of errors, add the row to non_matching_rows
        non_matching_rows.append(j)

    # Wait for 3.5 seconds between API requests to avoid overloading the server
    time.sleep(3.5)

# Convert the non-matching rows into a DataFrame and save it as a Parquet file
non_matching_df = pd.DataFrame(non_matching_rows, columns=df_trec.columns)
non_matching_df.to_parquet("../../../data/metadata_TREC_SemanticScholar_not_found.parquet")

# Save the matching data (found results) into a JSON file
with open('../../../data/SemanticScholar_TREC_found.json', 'w', encoding='utf-8') as f:
    json.dump(data_trec, f, ensure_ascii=False, indent=4)
# Out:
# 1 / 1972
# ['Harman', 'Voorhees']
# ['Harman', 'Voorhees']
# +
# 2 / 1972
# ['Chen', 'Gey']
# ['Chen', 'Gey']
# +
# 3 / 1972
# ['Hull', 'Robertson']
# ['Hull', 'Robertson']
# +
# 4 / 1972
# ['Hersh', 'Over']
# ['Hersh', 'Over']
# +
# 5 / 1972
# ['Buckley', 'Liggett']
# ['Buckley', 'Liggett']
# +
# 6 / 1972
# ['Voorhees']
# ['Voorhees']
# +
# 7 / 1972
# ['Buckley']
# ['Buckley']
# +
# 8 / 1972
# ['Hawking']
# ['Hawking']
# +
# 9 / 1972
# ['Honma', 'Mano', 'Narita', 'Ogawa']
# ['Honma', 'Mano', 'Narita', 'Ogawa']
# +
# 10 / 1972
# ['Beitzel', 'Chowdhury', 'Frieder', 'Grossman', 'Holmes', 'Jensen', 'McCabe', 'Sailee']
# ['Beitzel', 'Chowdhury', 'Frieder', 'Grossman', 'Holmes', 'Jensen', 'McCabe', 'Sailee']
# +
# 11 / 1972
# ['Chan', 'Dinstl', 'Grunfeld', 'Kwok']
# ['Chan', 'Dinstl', 'Grunfeld', 'Kwok']
# +
# 12 / 1972
# ['Gao', 'Huang', 'Nie', 'Su', 'Xun', 'Zhang', 'Zhou']
# ['Gao', 'Huang', 'Nie', 'Su', 'Xun', 'Zhang', 'Zhou']
# +
# 13 / 1972
# ['Bunescu', 'Girju', 'Harabagiu', 'Mihalcea', 'Moldovan', 'Morarescu', 'Pasca', 'Rus', 'Surdeanu']
# ['Bunescu', 'Girju', 'Harabagiu', 'Mihalcea', 'Moldovan', 'Morarescu', 'Pasca', 'Rus', 'Surdeanu']
# +
# 14 / 1972
# ['Franz', 'Ittycheriah', 'Mammone', 'Ratnaparkhi', 'Zhu']
# ['Franz', 'Ittycheriah', 'Mammone', 'Ratnaparkhi', 'Zhu']
# +
# 15 / 1972
# ['Clarke', 'Cormack', 'Kisman', 'Lynam']
# ['Clarke', 'Cormack', 'Kisman', 'Lynam']
# +
# 16 / 1972
# ['Gerber', 'Hermjakob', 'Hovy', 'Junk', 'Lin']
# ['Gerber', 'Hermjakob', 'Hovy', 'Junk', 'Lin']
# +
# 17 / 1972
# ['Catona', 'Eichmann', 'Srinivasan']
# ['Catona', 'Eichmann', 'Srinivasan']
# +
# 18 / 1972
# ['Adda', 'Barras', 'Gauvain', 'Kercadio', 'Lamel']
# ['Adda', 'Barras', 'Gauvain', 'Kercadio', 'Lamel']
# +
# 19 / 1972
# ['Robertson', 'Walker']
# ['Robertson', 'Walker']
# +
# 20 / 1972
# 21 / 1972
# ['Johnson', 'Jones', 'Jourlin', 'Woodland']
# ['Johnson', 'Jones', 'Jourlin', 'Woodland']
# +
# 22 / 1972
# ['Ault', 'Yang']
# ['Ault', 'Yang']
# +
# 23 / 1972
# ['Callan', 'Zhang']
# ['Callan', 'Zhang']
# +
# 24 / 1972
# ['Vogt']
# ['Vogt']
# +
# 25 / 1972
# ['Jin', 'Wong']
# ['Jin', 'Wong']
# +
# 26 / 1972
# ['Litkowski']
# ['Litkowski']
# +
# 27 / 1972
# ['Gurrin', 'Smeaton']
# ['Gurrin', 'Smeaton']
# +
# 28 / 1972
# ['Guo', 'Huang', 'Liu', 'Wu', 'Zhang']
# ['Guo', 'Huang', 'Liu', 'Wu', 'Zhang']
# +
# 29 / 1972
# ['Namba']
# ['Namba']
# +
# 30 / 1972
# ['Blackwell', 'Tomlinson']
# ['Blackwell', 'Tomlinson']
# +
# 31 / 1972
# ['Franz', 'McCarley', 'Zhu']
# ['Franz', 'McCarley', 'Zhu']
# +
# 32 / 1972
# ['Brown', 'Czuba', 'Prager', 'Radev']
# ['Brown', 'Czuba', 'Prager', 'Radev']
# +
# 33 / 1972
# ['Dreyfus', 'Stricker', 'Vichot', 'Wolinski']
# ['Dreyfus', 'Stricker', 'Vichot', 'Wolinski']
# +
# 34 / 1972
# ['Abchiche', 'Boughanem', 'Dkaki', 'Mothe', 'Soulé-Dupuy', 'Tmar']
# ['Abchiche', 'Boughanem', 'Dkaki', 'Mothe', 'Soulé-Dupuy', 'Tmar']
# +
# 35 / 1972
# ['Mayfield', 'McNamee', 'Piatko']
# ['Mayfield', 'McNamee', 'Piatko']
# +
# 36 / 1972
# ['Hasegawa', 'Hashimoto', 'Hoashi', 'Inoue', 'Matsumoto', 'Shirai']
# ['Hasegawa', 'Hashimoto', 'Hoashi', 'Inoue', 'Matsumoto', 'Shirai']
# +
# 37 / 1972
# ['Choi', 'Huang', 'Kim', 'Lee', 'Oh']
# ['Choi', 'Huang', 'Kim', 'Lee', 'Oh']
# +
# 38 / 1972
# ['Baek', 'Kim', 'Kim', 'Rim']
# ['Baek', 'Kim', 'Kim', 'Rim']
# +
# 39 / 1972
# ['Ferret', 'Grau', 'Hurault-Plantet', 'Illouz', 'Jacquemin', 'Lecuyer', 'Masson']
# ['Ferret', 'Grau', 'Hurault-Plantet', 'Illouz', 'Jacquemin', 'Lecuyer', 'Masson']
# +
# 40 / 1972
# ['Elworthy']
# ['Elworthy']
# +
# 41 / 1972
# ['Takaki']
# ['Takaki']
# +
# 42 / 1972
# ['Chen', 'Lin', 'Lin']
# ['Chen', 'Lin', 'Lin']
# +
# 43 / 1972
# ['Chan', 'Hersh', 'Kraemer', 'Olson', 'Price', 'Sacherek', 'Turpin']
# ['Chan', 'Hersh', 'Kraemer', 'Olson', 'Price', 'Sacherek', 'Turpin']
# +
# 44 / 1972
# ["D'Souza", 'Fuller', 'Thom', 'Vines', 'Zobel']
# ["D'Souza", 'Fuller', 'Thom', 'Vines', 'Zobel']
# +
# 45 / 1972
# ['Belkin', 'Carballo', 'Keller', 'Kelly', 'Sikora', 'Sun']
# ['Belkin', 'Carballo', 'Keller', 'Kelly', 'Sikora', 'Sun']
# +
# 46 / 1972
# ['Green', 'Houston', 'Martin', 'Woods']
# ['Green', 'Houston', 'Martin', 'Woods']
# +
# 47 / 1972
# ['Chen', 'Diekema', 'Liddy', 'Liu', 'McCracken', 'Wang', 'Yilmazel']
# ['Chen', 'Diekema', 'Liddy', 'Liu', 'McCracken', 'Wang', 'Yilmazel']
# +
# 48 / 1972
# ['Forrester', 'Rowe', 'Ruiz', 'Sheridan']
# ['Forrester', 'Rowe', 'Ruiz', 'Sheridan']
# +
# 49 / 1972
# ['Kraaij', 'Westerveld']
# ['Kraaij', 'Westerveld']
# +
# 50 / 1972
# ['González', 'Rodríguez']
# ['González', 'Rodríguez']
# +
# 51 / 1972
# ['Attardi', 'Burrini']
# ['Attardi', 'Burrini']
# +
# 52 / 1972
# ['Kosseim', 'Lapalme', 'Laszlo']
# ['Kosseim', 'Lapalme', 'Laszlo']
# +
# 53 / 1972
# ['Brouard', 'Nie']
# ['Brouard', 'Nie']
# +
# 54 / 1972
# ['Rasolofo', 'Savoy']
# ['Rasolofo', 'Savoy']
# +
# 55 / 1972
# ['Chen', 'Gey', 'Jiang']
# ['Chen', 'Gey', 'Jiang']
# +
# 56 / 1972
# ['Alexander', 'Brown', 'Jose', 'Ruthven', 'Tombros']
# ['Alexander', 'Brown', 'Jose', 'Ruthven', 'Tombros']
# +
# 57 / 1972
# ['Allan', 'Connell', 'Croft', 'Feng', 'Fisher', 'Li']
# ['Allan', 'Connell', 'Croft', 'Feng', 'Fisher', 'Li']
# +
# 58 / 1972
# ['Newby']
# ['Newby']
# +
# 59 / 1972
# ['Crivellari', 'Melucci']
# ['Crivellari', 'Melucci']
# +
# 60 / 1972
# ['Abberley', 'Renals']
# ['Abberley', 'Renals']
# +
# 61 / 1972
# ['Gaizauskas', 'Scott']
# ['Gaizauskas', 'Scott']
# +
# 62 / 1972
# ['Vries']
# ['Vries']
# +
# 63 / 1972
# ['Weischedel', 'Xu']
# ['Weischedel', 'Xu']
# +
# 64 / 1972
# ['Fowkes', 'Hancock-Beaulieu', 'Joho']
# ['Fowkes', 'Hancock-Beaulieu', 'Joho']
# +
# 65 / 1972
# ['Fujita']
# ['Fujita']
# +
# 66 / 1972
# ['Arampatzis', 'Beney', 'Koster', 'Weide']
# ['Arampatzis', 'Beney', 'Koster', 'Weide']
# +
# 67 / 1972
# ['Hawking']
# ['Hawking']
# +
# 68 / 1972
# 69 / 1972
# ['Buckley', 'Walz']
# ['Buckley', 'Walz']
# +
# 70 / 1972
# ['Cooper', 'Rüger']
# ['Cooper', 'Rüger']
# +
# 71 / 1972
# ['Cabezas', 'Levow', 'Oard']
# ['Cabezas', 'Levow', 'Oard']
# +
# 72 / 1972
# ['Boros', 'Kantor', 'Neu']
# ['Boros', 'Kantor', 'Neu']
# +
# 73 / 1972
# ['Breck', 'Burger', 'Ferro', 'Greiff', 'Light', 'Mani', 'Rennie']
# ['Breck', 'Burger', 'Ferro', 'Greiff', 'Light', 'Mani', 'Rennie']
# +
# 74 / 1972
# ['Voorhees']
# ['Voorhees']
# +
# 75 / 1972
# ['Gey', 'Oard']
# ['Gey', 'Oard']
# +
# 76 / 1972
# ['Wang']
# ['Robertson', 'Soboroff']
# -
# 77 / 1972
# ['Hersh', 'Over']
# ['Hersh', 'Over']
# +
# 78 / 1972
# ['Voorhees']
# ['Voorhees']
# +
# 79 / 1972
# ['Over', 'Smeaton', 'Taban']
# ['Over', 'Smeaton', 'Taban']
# +
# 80 / 1972
# ['Fraser', 'Weischedel', 'Xu']
# ['Fraser', 'Weischedel', 'Xu']
# +
# 81 / 1972
# ['Bai', 'Bu', 'Cheng', 'Liu', 'Wang', 'Xu', 'Yang']
# ['Bai', 'Bu', 'Cheng', 'Liu', 'Wang', 'Xu', 'Yang']
# +
# 82 / 1972
# ['Litkowski']
# ['Litkowski']
# +
# 83 / 1972
# ['Bennett', 'Evans', 'Grefenstette', 'Montgomery', 'Roma', 'Shanahan', 'Sheftel', 'Stoica', 'Tong']
# ['Bennett', 'Evans', 'Grefenstette', 'Montgomery', 'Roma', 'Shanahan', 'Sheftel', 'Stoica', 'Tong']
# +
# 84 / 1972
# ['Quénot']
# ['Quénot']
# +
# 85 / 1972
# ['Callan', 'Zhang']
# ['Callan', 'Zhang']
# +
# 86 / 1972
# ['Ault', 'Yang']
# ['Ault', 'Yang']
# +
# 87 / 1972
# ['Hauptmann', 'Houghton', 'Jin', 'Ng', 'Papernick', 'Qi', 'Thornton']
# ['Hauptmann', 'Houghton', 'Jin', 'Ng', 'Papernick', 'Qi', 'Thornton']
# +
# 88 / 1972
# ['Callan', 'Ogilvie']
# ['Callan', 'Ogilvie']
# +
# 89 / 1972
# ['Craswell', 'Hawking', 'Wilkinson', 'Wu']
# ['Craswell', 'Hawking', 'Wilkinson', 'Wu']
# +
# 90 / 1972
# ['Lewis']
# ['Lewis']
# +
# 91 / 1972
# ['Browne', 'Gurrin', 'Lee', 'McDonald', 'Sav', 'Smeaton', 'Ye']
# ['Browne', 'Gurrin', 'Lee', 'McDonald', 'Sav', 'Smeaton', 'Ye']
# +
# 92 / 1972
# ['Rennert']
# ['Rennert']
# +
# 93 / 1972
# ['Amati', 'Carpineto', 'Romano']
# ['Amati', 'Carpineto', 'Romano']
# +
# 94 / 1972
# ['Feng', 'Guo', 'Huang', 'Niu', 'Wu', 'Xia']
# ['Feng', 'Guo', 'Huang', 'Niu', 'Wu', 'Xia']
# +
# 95 / 1972
# ['Namba']
# ['Namba']
# +
# 96 / 1972
# ['Tomlinson']
# ['Tomlinson']
# +
# 97 / 1972
# ['Amitay', 'Carmel', 'Herscovici', 'Maarek', 'Petruschka', 'Soffer']
# ['Amitay', 'Carmel', 'Herscovici', 'Maarek', 'Petruschka', 'Soffer']
# +
# 98 / 1972
# ['Kanungo', 'Zien']
# ['Kanungo', 'Zien']
# +
# 99 / 1972
# ['Amir', 'Basu', 'Iyengar', 'Lin', 'Naphade', 'Ponceleón', 'Smith', 'Srinivasan', 'Tseng']
# ['Amir', 'Basu', 'Iyengar', 'Lin', 'Naphade', 'Ponceleon', 'Smith', 'Srinivasan', 'Tseng']
# +
# 100 / 1972
# ['Chu-Carroll', 'Czuba', 'Prager']
# ['Chu-Carroll', 'Czuba', 'Prager']
# +
# 101 / 1972
# ['Franz', 'Ittycheriah', 'Roukos']
# ['Franz', 'Ittycheriah', 'Roukos']
# +
# 102 / 1972
# ['Aljlayl', 'Beitzel', 'Chowdhury', 'Frieder', 'Grossman', 'Holmes', 'Jensen', 'Lee']
# ['Aljlayl', 'Beitzel', 'Chowdhury', 'Frieder', 'Grossman', 'Holmes', 'Jensen', 'Lee']
# +
# 103 / 1972
# ['Pickering', 'Rüger']
# ['Pickering', 'Rüger']
# +
# 104 / 1972
# ['Gevrey', 'Rüger']
# ['Gevrey', 'Rüger']
# +
# 105 / 1972
# ['Soubbotin']
# ['Soubbotin']
# +
# 106 / 1972
# ['Boughanem', 'Chrisment', 'Tmar']
# ['Boughanem', 'Chrisment', 'Tmar']
# +
# 107 / 1972
# ['Magnini', 'Negri', 'Prevete', 'Tanev']
# ['Magnini', 'Negri', 'Prevete', 'Tanev']
# +
# 108 / 1972
# ['Banerjee', 'Costello', 'Mayfield', 'McNamee', 'Piatko']
# ['Banerjee', 'Costello', 'Mayfield', 'McNamee', 'Piatko']
# +
# 109 / 1972
# ['Fujita']
# ['Fujita']
# +
# 110 / 1972
# ['Chang', 'Choi', 'Lee', 'Oh', 'Seo']
# ['Chang', 'Choi', 'Lee', 'Oh', 'Seo']
# +
# 111 / 1972
# ['Narasetsathaporn', 'Rungsawang']
# ['Narasetsathaporn', 'Rungsawang']
# +
# 112 / 1972
# ['Bunescu', 'Girju', 'Harabagiu', 'Lacatusu', 'Mihalcea', 'Moldovan', 'Morarescu', 'Pasca', 'Rus', 'Surdeanu']
# ['Bunescu', 'Girju', 'Harabagiu', 'Lacatusu', 'Mihalcea', 'Moldovan', 'Morarescu', 'Pasca', 'Rus', 'Surdeanu']
# +
# 113 / 1972
# ['Ferret', 'Grau', 'Hurault-Plantet', 'Illouz', 'Monceaux', 'Robba', 'Vilnat']
# ['Ferret', 'Grau', 'Hurault-Plantet', 'Illouz', 'Monceaux', 'Robba', 'Vilnat']
# +
# 114 / 1972
# ['Chen', 'Ma', 'Sheng', 'Zhang']
# ['Chen', 'Ma', 'Sheng', 'Zhang']
# +
# 115 / 1972
# ['Robertson', 'Walker', 'Zaragoza']
# ['Robertson', 'Walker', 'Zaragoza']
# +
# 116 / 1972
# ['Cao', 'Gao', 'He', 'Nie', 'Robertson', 'Walker', 'Zhang']
# ['Cao', 'Gao', 'He', 'Nie', 'Robertson', 'Walker', 'Zhang']
# +
# 117 / 1972
# ['Banko', 'Brill', 'Dumais', 'Lin', 'Ng']
# ['Banko', 'Brill', 'Dumais', 'Lin', 'Ng']
# +
# 118 / 1972
# ['Anand', 'Anderson', 'Burger', 'Griffith', 'Light', 'Mardis', 'Morgan']
# ['Anand', 'Anderson', 'Burger', 'Griffith', 'Light', 'Mardis', 'Morgan']
# +
# 119 / 1972
# ['Chen', 'Lin']
# ['Chen', 'Lin']
# +
# 120 / 1972
# ['Clare', 'Hendrikse']
# ['Clare', 'Hendrikse']
# +
# 121 / 1972
# ['Isozaki', 'Kazawa', 'Maeda']
# ['Isozaki', 'Kazawa', 'Maeda']
# +
# 122 / 1972
# ['Hersh', 'Olson', 'Sacherek']
# ['Hersh', 'Olson', 'Sacherek']
# +
# 123 / 1972
# ['Alpha', 'Dixon', 'Liao', 'Yang']
# ['Alpha', 'Dixon', 'Liao', 'Yang']
# +
# 124 / 1972
# ['An', 'Cha', 'Cho', 'Jung', 'Kim', 'Kim', 'Kim', 'Kwak', 'Lee', 'Lee', 'Lee', 'Seo']
# ['An', 'Cha', 'Cho', 'Jung', 'Kim', 'Kim', 'Kim', 'Kwak', 'Lee', 'Lee', 'Lee', 'Seo']
# +
# 125 / 1972
# ['Chan', 'Dinstl', 'Grunfeld', 'Kwok']
# ['Chan', 'Dinstl', 'Grunfeld', 'Kwok']
# +
# 126 / 1972
# ['Itoh', 'Mano', 'Ogawa']
# ['Itoh', 'Mano', 'Ogawa']
# +
# 127 / 1972
# ['Belkin', 'Cool', 'Jeng', 'Keller', 'Kelly', 'Kim', 'Lee', 'Tang', 'Yuan']
# ['Belkin', 'Cool', 'Jeng', 'Keller', 'Kelly', 'Kim', 'Lee', 'Tang', 'Yuan']
# +
# 128 / 1972
# ['Rujan']
# ['Rujan']
# +
# 129 / 1972
# ['Green', 'Houston', 'Martin', 'Woods']
# ['Green', 'Houston', 'Martin', 'Woods']
# +
# 130 / 1972
# ['Chen', 'Diekema', 'Liddy', 'McCracken', 'Ozgencil', 'Taffet', 'Yilmazel']
# ['Chen', 'Diekema', 'Liddy', 'McCracken', 'Ozgencil', 'Taffet', 'Yilmazel']
# +
# 131 / 1972
# ['Mäkinen', 'Toivonen', 'Vesanen', 'Visa']
# ['Mäkinen', 'Toivonen', 'Vesanen', 'Visa']
# +
# 132 / 1972
# ['Baan', 'Ballegooij', 'Geusenbroek', 'Hartog', 'Hiemstra', 'List', 'Patras', 'Raaijmakers', 'Snoek', 'Todoran', 'Vendrig', 'Vries', 'Westerveld']
# []
# -
# 133 / 1972
# ['Buchholz']
# ['Buchholz']
# +
# 134 / 1972
# ['González', 'Llopis', 'Rodríguez']
# ['González', 'Llopis', 'Rodríguez']
# +
# 135 / 1972
# ['Jose', 'Ruthven', 'White']
# ['Jose', 'Ruthven', 'White']
# +
# 136 / 1972
# ['Rasolofo', 'Savoy']
# ['Rasolofo', 'Savoy']
# +
# 137 / 1972
# ['Monz', 'Rijke']
# ['Monz', 'Rijke']
# +
# 138 / 1972
# ['Chen', 'Gey']
# ['Chen', 'Gey']
# +
# 139 / 1972
# ['Alm', 'Kao', 'Li', 'Moran', 'Nagarajan', 'Punyakanok', 'Rizzolo', 'Roth', 'Yih']
# ['Alm', 'Kao', 'Li', 'Moran', 'Nagarajan', 'Punyakanok', 'Rizzolo', 'Roth', 'Yih']
# +
# 140 / 1972
# ['Darwish', 'Doermann', 'Jones', 'Oard', 'Rautiainen']
# ['Darwish', 'Doermann', 'Jones', 'Oard', 'Rautiainen']
# +
# 141 / 1972
# ['Connell', 'Larkey']
# ['Connell', 'Larkey']
# +
# 142 / 1972
# ['Bhavnani']
# ['Bhavnani']
# +
# 143 / 1972
# ['Kosseim', 'Lapalme', 'Plamondon']
# ['Kosseim', 'Lapalme', 'Plamondon']
# +
# 144 / 1972
# ['Newby']
# ['Newby']
# +
# 145 / 1972
# ['Yang']
# ['Yang']
# +
# 146 / 1972
# ['Anusuri', 'Jenkins', 'Jeong', 'Oyarce', 'Pachlag', 'Rorvig']
# ['Anusuri', 'Jenkins', 'Jeong', 'Oyarce', 'Pachlag', 'Rorvig']
# +
# 147 / 1972
# ['Arampatzis']
# ['Arampatzis']
# +
# 148 / 1972
# ['Alberair', 'Sanderson']
# ['Alberair', 'Sanderson']
# +
# 149 / 1972
# ['Hermjakob', 'Hovy', 'Lin']
# ['Hermjakob', 'Hovy', 'Lin']
# +
# 150 / 1972
# ['Bartlett', 'Freund', 'Kopak', 'Toms']
# ['Bartlett', 'Freund', 'Kopak', 'Toms']
# +
# 151 / 1972
# ['Hiemstra', 'Kraaij', 'Westerveld']
# ['Hiemstra', 'Kraaij', 'Westerveld']
# +
# 152 / 1972
# ['Clarke', 'Cormack', 'Li', 'Lynam', 'McLearn']
# ['Clarke', 'Cormack', 'Li', 'Lynam', 'McLearn']
# +
# 153 / 1972
# ['Crivellari', 'Melucci']
# ['Crivellari', 'Melucci']
# +
# 154 / 1972
# ['Attardi', 'Cisternino', 'Formica', 'Simi', 'Tommasi']
# ['Attardi', 'Cisternino', 'Formica', 'Simi', 'Tommasi']
# +
# 155 / 1972
# ['Alfonseca', 'Boni', 'Jara-Valencia', 'Manandhar']
# ['Alfonseca', 'Boni', 'Jara-Valencia', 'Manandhar']
# +
# 156 / 1972
# ['Fox', 'Xi']
# ['Fox', 'Xi']
# +
# 157 / 1972
# ['Jang', 'Park', 'Ra']
# ['Jang', 'Park', 'Ra']
# +
# 158 / 1972
# ['Voorhees']
# ['Voorhees']
# +
# 159 / 1972
# ['Gey', 'Oard']
# ['Gey', 'Oard']
# +
# 160 / 1972
# ['Robertson', 'Soboroff']
# ['Robertson', 'Soboroff']
# +
# 161 / 1972
# ['Hersh']
# ['Hersh']
# +
# 162 / 1972
# ['Harman']
# ['Harman']
# +
# 163 / 1972
# ['Voorhees']
# ['Voorhees']
# +
# 164 / 1972
# ['Over', 'Smeaton']
# ['Over', 'Smeaton']
# +
# 165 / 1972
# ['Craswell', 'Hawking']
# ['Craswell', 'Hawking']
# +
# 166 / 1972
# ['Fraser', 'Weischedel', 'Xu']
# ['Fraser', 'Weischedel', 'Xu']
# +
# 167 / 1972
# ['Licuanan', 'May', 'Miller', 'Weischedel', 'Xu']
# ['Licuanan', 'May', 'Miller', 'Weischedel', 'Xu']
# +
# 168 / 1972
# ['Bai', 'Cheng', 'Cheng', 'Liu', 'Liu', 'Wang', 'Xu', 'Yang', 'Yang']
# ['Bai', 'Cheng', 'Cheng', 'Liu', 'Liu', 'Wang', 'Xu', 'Yang', 'Yang']
# +
# 169 / 1972
# ['Bai', 'Xu', 'Zhang']
# ['Bai', 'Xu', 'Zhang']
# +
# 170 / 1972
# ['MacFarlane']
# ['MacFarlane']
# +
# 171 / 1972
# ['Litkowski']
# ['Litkowski']
# +
# 172 / 1972
# ['Bennett', 'Evans', 'Hull', 'Montgomery', 'Roma', 'Shanahan', 'Sheftel', 'Stoica', 'Tembe']
# ['Bennett', 'Evans', 'Hull', 'Montgomery', 'Roma', 'Shanahan', 'Sheftel', 'Stoica', 'Tembe']
# +
# 173 / 1972
# ['Brouard']
# ['Brouard']
# +
# 174 / 1972
# ['Besacier', 'Moraru', 'Mulhem', 'Quénot']
# ['Besacier', 'Moraru', 'Mulhem', 'Quénot']
# +
# 175 / 1972
# ['Callan', 'Collins-Thompson', 'Ogilvie', 'Zhang']
# ['Callan', 'Collins-Thompson', 'Ogilvie', 'Zhang']
# +
# 176 / 1972
# ['Baron', 'Chen', 'Christel', 'Derthick', 'Hauptmann', 'Jin', 'Lin', 'Ng', 'Qi', 'Yan']
# ['Baron', 'Chen', 'Christel', 'Derthick', 'Hauptmann', 'Jin', 'Lin', 'Ng', 'Qi', 'Yan']
# +
# 177 / 1972
# ['Callan', 'Carbonell', 'Collins-Thompson', 'Czuba', 'Duggan', 'Hiyakumoto', 'Hu', 'Huang', 'Ko', 'Lita', 'Mitamura', 'Murtagh', 'Nyberg', 'Pedro', 'Svoboda']
# ['Callan', 'Carbonell', 'Collins-Thompson', 'Czuba', 'Duggan', 'Hiyakumoto', 'Hu', 'Huang', 'Ko', 'Lita', 'Mitamura', 'Murtagh', 'Nyberg', 'Pedro', 'Svoboda']
# +
# 178 / 1972
# ['Schiffman']
# ['Schiffman']
# +
# 179 / 1972
# ['Craswell', 'Hawking', 'Thom', 'Upstill', 'Wilkinson', 'Wu']
# ['Craswell', 'Hawking', 'Thom', 'Upstill', 'Wilkinson', 'Wu']
# +
# 180 / 1972
# ['Ballegooij', 'Vries', 'Westerveld']
# ['Ballegooij', 'Vries', 'Westerveld']
# +
# 181 / 1972
# ['Browne', 'Czirjek', 'Gurrin', 'Jarina', 'Lee', 'Marlow', 'McDonald', 'Murphy', "O'Connor", 'Smeaton', 'Ye']
# ['Browne', 'Czirjek', 'Gurrin', 'Jarina', 'Lee', 'Marlow', 'McDonald', 'Murphy', "O'Connor", 'Smeaton', 'Ye']
# +
# 182 / 1972
# ['Huet', 'Mérialdo', 'Souvannavong']
# ['Huet', 'Mérialdo', 'Souvannavong']
# +
# 183 / 1972
# ['Feng', 'Huang', 'Niu', 'Wu', 'Xia', 'Zhou']
# ['Feng', 'Huang', 'Niu', 'Wu', 'Xia', 'Zhou']
# +
# 184 / 1972
# ['Tomlinson']
# ['Tomlinson']
# +
# 185 / 1972
# ['Franz', 'McCarley']
# ['Franz', 'McCarley']
# +
# 186 / 1972
# ['Amitay', 'Carmel', 'Darlow', 'Lempel', 'Soffer']
# ['Amitay', 'Carmel', 'Darlow', 'Lempel', 'Soffer']
# +
# 187 / 1972
# ['Ittycheriah', 'Roukos']
# ['Ittycheriah', 'Roukos']
# +
# 188 / 1972
# ['Chu-Carroll', 'Czuba', 'Ferrucci', 'Prager', 'Welty']
# ['Chu-Carroll', 'Czuba', 'Ferrucci', 'Prager', 'Welty']
# +
# 189 / 1972
# ['Adams', 'Amir', 'Ashwin', 'Dorai', 'Ghosal', 'Iyengar', 'Jaimes', 'Lang', 'Lin', 'Naphade', 'Natsev', 'Neti', 'Nock', 'Permuter', 'Singh', 'Smith', 'Srinivasan', 'Tseng', 'Zhang']
# ['Adams', 'Amir', 'Ashwin', 'Dorai', 'Ghosal', 'Iyengar', 'Jaimes', 'Lang', 'Lin', 'Naphade', 'Natsev', 'Neti', 'Nock', 'Permuter', 'Singh', 'Smith', 'Srinivasan', 'Tseng', 'Zhang']
# +
# 190 / 1972
# ['Aljlayl', 'Beitzel', 'Chowdhury', 'Frieder', 'Grossman', 'Jensen']
# ['Aljlayl', 'Beitzel', 'Chowdhury', 'Frieder', 'Grossman', 'Jensen']
# +
# 191 / 1972
# ['Albertson', 'Fieber', 'Mostafa']
# ['Albertson', 'Fieber', 'Mostafa']
# +
# 192 / 1972
# ['Bull', 'Heesch', "O'Callaghan", 'Pickering', 'Rüger']
# ['Bull', 'Heesch', "O'Callaghan", 'Pickering', 'Rüger']
# +
# 193 / 1972
# ['Soubbotin', 'Soubbotin']
# ['Soubbotin', 'Soubbotin']
# +
# 194 / 1972
# ['Augé', 'Dkaki', 'Mothe']
# ['Augé', 'Dkaki', 'Mothe']
# +
# 195 / 1972
# ['Boughanem', 'Tebri', 'Tmar']
# ['Boughanem', 'Tebri', 'Tmar']
# +
# 196 / 1972
# ['Benammar', 'Boughanem', 'Hubert', 'Laffaire', 'Mothe']
# ['Benammar', 'Boughanem', 'Hubert', 'Laffaire', 'Mothe']
# +
# 197 / 1972
# ['Magnini', 'Negri', 'Prevete', 'Tanev']
# ['Magnini', 'Negri', 'Prevete', 'Tanev']
# +
# 198 / 1972
# ['Mayfield', 'McNamee', 'Piatko']
# ['Mayfield', 'McNamee', 'Piatko']
# +
# 199 / 1972
# ['Malawong', 'Rungsawang']
# ['Malawong', 'Rungsawang']
# +
# 200 / 1972
# ['Cancedda', 'Cesa-Bianchi', 'Conconi', 'Gentile', 'Goutte', 'Graepel', 'Li', 'Renders', 'Shawe-Taylor', 'Vinokourov']
# ['Cancedda', 'Cesa-Bianchi', 'Conconi', 'Gentile', 'Goutte', 'Graepel', 'Li', 'Renders', 'Shawe-Taylor', 'Vinokourov']
# +
# 201 / 1972
# ['Ji', 'Yang', 'Yu']
# ['Ji', 'Yang', 'Yu']
# +
# 202 / 1972
# ['Badulescu', 'Bolohan', 'Girju', 'Harabagiu', 'Lacatusu', 'Moldovan', 'Morarescu', 'Novischi']
# ['Badulescu', 'Bolohan', 'Girju', 'Harabagiu', 'Lacatusu', 'Moldovan', 'Morarescu', 'Novischi']
# +
# 203 / 1972
# ['Bellot', 'Crestan', 'El-Bèze', 'Gillard', 'Loupy']
# ['Bellot', 'Crestan', 'El-Bèze', 'Gillard', 'Loupy']
# +
# 204 / 1972
# ['Chalendar', 'Dalmas', 'Elkateb-Gara', 'Ferret', 'Grau', 'Hurault-Plantet', 'Illouz', 'Monceaux', 'Robba', 'Vilnat']
# ['Chalendar', 'Dalmas', 'Elkateb-Gara', 'Ferret', 'Grau', 'Hurault-Plantet', 'Illouz', 'Monceaux', 'Robba', 'Vilnat']
# +
# 205 / 1972
# ['Hartog', 'Leeuwen', 'Patras', 'Raaijmakers', 'Rest', 'Snoek', 'Vendrig', 'Worring']
# ['Hartog', 'Leeuwen', 'Patras', 'Raaijmakers', 'Rest', 'Snoek', 'Vendrig', 'Worring']
# +
# 206 / 1972
# ['Herbrich', 'Robertson', 'Walker', 'Zaragoza']
# ['Herbrich', 'Robertson', 'Walker', 'Zaragoza']
# +
# 207 / 1972
# ['Fernandes', 'Katz', 'Lin', 'Marton', 'Tellex']
# ['Fernandes', 'Katz', 'Lin', 'Marton', 'Tellex']
# +
# 208 / 1972
# 209 / 1972
# ['Aizawa', 'Kageura', 'Lee']
# ['Aizawa', 'Kageura', 'Lee']
# +
# 210 / 1972
# ['Hirao', 'Isozaki', 'Kazawa', 'Maeda']
# ['Hirao', 'Isozaki', 'Kazawa', 'Maeda']
# +
# 211 / 1972
# ['Chen', 'Tsai']
# ['Chen', 'Tsai']
# +
# 212 / 1972
# ['Chua', 'Yang']
# ['Chua', 'Yang']
# +
# 213 / 1972
# ['Chandrashekhara', 'Chua', 'Feng']
# ['Chandrashekhara', 'Chua', 'Feng']
# +
# 214 / 1972
# ['Lee', 'Zhang']
# ['Lee', 'Zhang']
# +
# 215 / 1972
# ['Hersh', 'Kraemer', 'Moy', 'Olson', 'Sacherek']
# ['Hersh', 'Kraemer', 'Moy', 'Olson', 'Sacherek']
# +
# 216 / 1972
# ['Kang', 'Lee', 'Lee', 'Na']
# ['Kang', 'Lee', 'Lee', 'Na']
# +
# 217 / 1972
# ['Chan', 'Deng', 'Dinstl', 'Kwok']
# ['Chan', 'Deng', 'Dinstl', 'Kwok']
# +
# 218 / 1972
# ['Tahaghoghi', 'Thom', 'Williams']
# ['Tahaghoghi', 'Thom', 'Williams']
# +
# 219 / 1972
# ['Belkin', 'Cool', 'Kelly', 'Kim', 'Kim', 'Lee', 'Muresan', 'Tang', 'Yuan']
# ['Belkin', 'Cool', 'Kelly', 'Kim', 'Kim', 'Lee', 'Muresan', 'Tang', 'Yuan']
# +
# 220 / 1972
# ['Anghelescu', 'Boros', 'Kantor', 'Lewis', 'Menkov', 'Neu']
# ['Anghelescu', 'Boros', 'Kantor', 'Lewis', 'Menkov', 'Neu']
# +
# 221 / 1972
# ['Rennert']
# ['Rennert']
# +
# 222 / 1972
# ['Chen', 'Diekema', 'Liddy', 'McCracken', 'Ozgencil', 'Taffet', 'Yilmazel']
# ['Chen', 'Diekema', 'Liddy', 'McCracken', 'Ozgencil', 'Taffet', 'Yilmazel']
# +
# 223 / 1972
# ['Back', 'Mäkinen', 'Toivonen', 'Vanharanta', 'Vesanen', 'Visa']
# ['Back', 'Mäkinen', 'Toivonen', 'Vanharanta', 'Vesanen', 'Visa']
# +
# 224 / 1972
# ['Cai', 'Chen', 'Ma', 'Ma', 'Zhang']
# ['Cai', 'Chen', 'Ma', 'Ma', 'Zhang']
# +
# 225 / 1972
# ['Jiang', 'Jin', 'Lin', 'Liu', 'Ma', 'Song', 'Zhang', 'Zhao']
# ['Jiang', 'Jin', 'Lin', 'Liu', 'Ma', 'Song', 'Zhang', 'Zhao']
# +
# 226 / 1972
# ['González', 'Llopis', 'Rodríguez']
# ['González', 'Llopis', 'Rodríguez']
# +
# 227 / 1972
# ['Kamps', 'Monz', 'Rijke']
# ['Kamps', 'Monz', 'Rijke']
# +
# 228 / 1972
# ['Fathi', 'Hermes', 'Herzog', 'Ioannidis', 'Miene']
# ['Fathi', 'Hermes', 'Herzog', 'Ioannidis', 'Miene']
# +
# 229 / 1972
# ['Chen', 'Gey']
# ['Chen', 'Gey']
# +
# 230 / 1972
# ['Bethard', 'Blair-Goldensohn', 'Duboue', 'Filatova', 'Hatzivassiloglou', 'Illouz', 'Jurafsky', 'Krugler', 'Martin', 'McKeown', 'Passonneau', 'Pradhan', 'Schlaikjer', 'Ward', 'Yu']
# ['Bethard', 'Blair-Goldensohn', 'Duboue', 'Filatova', 'Hatzivassiloglou', 'Illouz', 'Jurafsky', 'Krugler', 'Martin', 'McKeown', 'Passonneau', 'Pradhan', 'Schlaikjer', 'Ward', 'Yu']
# +
# 231 / 1972
# ['Osdin', 'Ounis', 'White']
# ['Osdin', 'Ounis', 'White']
# +
# 232 / 1972
# ['Amati', 'Ounis', 'Plachouras', 'Rijsbergen']
# ['Amati', 'Ounis', 'Plachouras', 'Rijsbergen']
# +
# 233 / 1972
# ['Dickerson', 'Lyon', 'Malcolm']
# ['Dickerson', 'Lyon', 'Malcolm']
# +
# 234 / 1972
# ['Liu', 'Wu', 'Yu']
# ['Liu', 'Wu', 'Yu']
# +
# 235 / 1972
# ['Cumby', 'Li', 'Morie', 'Nagarajan', 'Rizzolo', 'Roth', 'Small', 'Yih']
# ['Cumby', 'Li', 'Morie', 'Nagarajan', 'Rizzolo', 'Roth', 'Small', 'Yih']
# +
# 236 / 1972
# ['Eichmann', 'Srinivasan']
# ['Eichmann', 'Srinivasan']
# +
# 237 / 1972
# ['Sutcliffe']
# ['Sutcliffe']
# +
# 238 / 1972
# ['Allan', 'Bolivar', 'Connell', 'Larkey', 'Wade']
# ['Allan', 'Bolivar', 'Connell', 'Larkey', 'Wade']
# +
# 239 / 1972
# ['Cost', 'Kallurkar', 'Majithia', 'Nicholas', 'Shi']
# ['Cost', 'Kallurkar', 'Majithia', 'Nicholas', 'Shi']
# +
# 240 / 1972
# ['Darwish', 'Oard']
# ['Darwish', 'Oard']
# +
# 241 / 1972
# ['Doermann', 'Rautiainen', 'Wolf']
# ['Doermann', 'Rautiainen', 'Wolf']
# +
# 242 / 1972
# ['Anh', 'Moffat']
# ['Anh', 'Moffat']
# +
# 243 / 1972
# ['Otterbacher', 'Qi', 'Radev', 'Winkel']
# ['Otterbacher', 'Qi', 'Radev', 'Winkel']
# +
# 244 / 1972
# ['Kosseim', 'Lapalme', 'Plamondon']
# ['Kosseim', 'Lapalme', 'Plamondon']
# +
# 245 / 1972
# ['Newby']
# ['Newby']
# +
# 246 / 1972
# ['Rasolofo', 'Savoy']
# ['Rasolofo', 'Savoy']
# +
# 247 / 1972
# ['Mihalcea']
# ['Mihalcea']
# +
# 248 / 1972
# ['Srihari', 'Srikanth', 'Wu']
# ['Srihari', 'Srikanth', 'Wu']
# +
# 249 / 1972
# ['Hosio', 'Matinmikko', 'Mäkelä', 'Noponen', 'Ojala', 'Peltola', 'Penttilä', 'Rautiainen', 'Seppänen', 'Vorobiev', 'Väyrynen']
# ['Hosio', 'Matinmikko', 'Mäkelä', 'Noponen', 'Ojala', 'Peltola', 'Penttilä', 'Rautiainen', 'Seppänen', 'Vorobiev', 'Väyrynen']
# +
# 250 / 1972
# ['Attardi', 'Cisternino', 'Formica', 'Simi', 'Tommasi']
# ['Attardi', 'Cisternino', 'Formica', 'Simi', 'Tommasi']
# +
# 251 / 1972
# ['Gaizauskas', 'Greenwood', 'Roberts']
# ['Gaizauskas', 'Greenwood', 'Roberts']
# +
# 252 / 1972
# ['Echihabi', 'Hermjakob', 'Marcu']
# ['Echihabi', 'Hermjakob', 'Marcu']
# +
# 253 / 1972
# ['Stokoe', 'Tait']
# ['Stokoe', 'Tait']
# +
# 254 / 1972
# ['Freund', 'Li', 'Toms']
# ['Freund', 'Li', 'Toms']
# +
# 255 / 1972
# ['Clarke', 'Cormack', 'Kemkes', 'Laszlo', 'Lynam', 'Terra', 'Tilker']
# ['Clarke', 'Cormack', 'Kemkes', 'Laszlo', 'Lynam', 'Terra', 'Tilker']
# +
# 256 / 1972
# ['Boni', 'Jara-Valencia', 'Manandhar']
# ['Boni', 'Jara-Valencia', 'Manandhar']
# +
# 257 / 1972
# ['Jang', 'Moon', 'Park', 'Ra']
# ['Jang', 'Moon', 'Park', 'Ra']
# +
# 258 / 1972
# ['Voorhees']
# ['Voorhees']
# +
# 259 / 1972
# ['Bhupatiraju', 'Hersh']
# ['Bhupatiraju', 'Hersh']
# +
# 260 / 1972
# ['Allan']
# ['Allan']
# +
# 261 / 1972
# ['Harman', 'Soboroff']
# ['Harman', 'Soboroff']
# +
# 262 / 1972
# ['Voorhees']
# ['Voorhees']
# +
# 263 / 1972
# ['Voorhees']
# ['Voorhees']
# +
# 264 / 1972
# ['Craswell', 'Hawking', 'Wilkinson', 'Wu']
# ['Craswell', 'Hawking', 'Wilkinson', 'Wu']
# +
# 265 / 1972
# ['Hull', 'Waldman']
# ['Hull', 'Waldman']
# +
# 266 / 1972
# ['Licuanan', 'Weischedel', 'Xu']
# ['Licuanan', 'Weischedel', 'Xu']
# +
# 267 / 1972
# ['Ferdous', 'Guillén']
# ['Ferdous', 'Guillén']
# +
# 268 / 1972
# ['Du', 'Sun', 'Wu', 'Ye']
# ['Du', 'Sun', 'Wu', 'Ye']
# +
# 269 / 1972
# ['Jin', 'Xu', 'Zhao']
# ['Jin', 'Xu', 'Zhao']
# +
# 270 / 1972
# ['Cheng', 'Pan', 'Sun', 'Wang', 'Yang', 'Zhang']
# ['Cheng', 'Pan', 'Sun', 'Wang', 'Yang', 'Zhang']
# -
# 271 / 1972
# ['Bai', 'Chang', 'Xu']
# ['Bai', 'Chang', 'Xu']
# +
# 272 / 1972
# ['Bennett', 'Evans', 'Hull', 'Montgomery', 'Shanahan']
# ['Bennett', 'Evans', 'Hull', 'Montgomery', 'Shanahan']
# +
# 273 / 1972
# ['Litkowski']
# ['Litkowski']
# +
# 274 / 1972
# ['Callan', 'Ogilvie']
# ['Callan', 'Ogilvie']
# +
# 275 / 1972
# ['Callan', 'Carbonell', 'Collins-Thompson', 'Durme', 'Frederking', 'Hiyakumoto', 'Huang', 'Huttenhower', 'Judy', 'Ko', 'Kupsc', 'Lita', 'Mitamura', 'Nyberg', 'Pedro', 'Svoboda']
# ['Callan', 'Carbonell', 'Collins-Thompson', 'Durme', 'Frederking', 'Hiyakumoto', 'Huang', 'Huttenhower', 'Judy', 'Ko', 'Kupsc', 'Lita', 'Mitamura', 'Nyberg', 'Pedro', 'Svoboda']
# +
# 276 / 1972
# ['Blair-Goldensohn', 'McKeown', 'Schlaikjer']
# ['Blair-Goldensohn', 'McKeown', 'Schlaikjer']
# +
# 277 / 1972
# ['Craswell', 'Hawking', 'McLean', 'Upstill', 'Wilkinson', 'Wu']
# ['Craswell', 'Hawking', 'McLean', 'Upstill', 'Wilkinson', 'Wu']
# +
# 278 / 1972
# ['Craswell', 'Hawking', 'Wilkinson', 'Wu']
# ['Craswell', 'Hawking', 'Wilkinson', 'Wu']
# +
# 279 / 1972
# 280 / 1972
# ['Eijk', 'Jelier', 'Kors', 'Mons', 'Mulligen', 'Schijvenaars', 'Schuemie', 'Weeber']
# ['Eijk', 'Jelier', 'Kors', 'Mons', 'Mulligen', 'Schijvenaars', 'Schuemie', 'Weeber']
# +
# 281 / 1972
# ['Amati', 'Carpineto', 'Romano']
# ['Amati', 'Carpineto', 'Romano']
# +
# 282 / 1972
# ['Du', 'Huang', 'Wu', 'You', 'Zhou']
# ['Du', 'Huang', 'Wu', 'You', 'Zhou']
# +
# 283 / 1972
# ['Tomlinson']
# ['Tomlinson']
# +
# 284 / 1972
# ['Brown', 'Dolbey', 'Hunter']
# ['Brown', 'Dolbey', 'Hunter']
# +
# 285 / 1972
# ['Amitay', 'Carmel', 'Darlow', 'Herscovici', 'Kraft', 'Lempel', 'Soffer', 'Zien']
# ['Amitay', 'Carmel', 'Darlow', 'Herscovici', 'Kraft', 'Lempel', 'Soffer', 'Zien']
# +
# 286 / 1972
# ['Chu-Carroll', 'Czuba', 'Ittycheriah', 'Mahindru', 'Prager', 'Welty']
# ['Chu-Carroll', 'Czuba', 'Ittycheriah', 'Mahindru', 'Prager', 'Welty']
# +
# 287 / 1972
# ['Conroy', 'Dunlavy', 'O’Leary']
# ['Conroy', 'Dunlavy', "O'Leary"]
# +
# 288 / 1972
# ['Bellare', 'Paranjpe', 'Ramakrishnan', 'Shah']
# ['Bellare', 'Paranjpe', 'Ramakrishnan', 'Shah']
# +
# 289 / 1972
# 290 / 1972
# ['Beitzel', 'Cathey', 'Chowdhury', 'Frieder', 'Grossman', 'Jensen', 'Ma', 'Pass', 'Vandermolen']
# ['Beitzel', 'Cathey', 'Chowdhury', 'Frieder', 'Grossman', 'Jensen', 'Ma', 'Pass', 'Vandermolen']
# +
# 291 / 1972
# ['Mostafa', 'Seki', 'Sheth']
# ['Mostafa', 'Seki', 'Sheth']
# +
# 292 / 1972
# ['Albertson', 'Yang']
# ['Albertson', 'Yang']
# +
# 293 / 1972
# ['Dkaki', 'Mothe']
# ['Dkaki', 'Mothe']
# -
# 294 / 1972
# ['Boughanem', 'Laffaire', 'Pinel-Sauvagnat']
# ['Boughanem', 'Laffaire', 'Sauvagnat']
# +
# 295 / 1972
# ['Kouylekov', 'Magnini', 'Negri', 'Tanev']
# ['Kouylekov', 'Magnini', 'Negri', 'Tanev']
# +
# 296 / 1972
# ['Mayfield', 'McNamee']
# ['Mayfield', 'McNamee']
# +
# 297 / 1972
# ['Ingongngam', 'Rungsawang']
# ['Ingongngam', 'Rungsawang']
# +
# 298 / 1972
# ['Han', 'Kim', 'Rim', 'Seo', 'Song']
# ['Han', 'Kim', 'Rim', 'Seo', 'Song']
# +
# 299 / 1972
# ['Bensley', 'Bowden', 'Clark', 'Harabagiu', 'Moldovan', 'Williams']
# ['Bensley', 'Bowden', 'Clark', 'Harabagiu', 'Moldovan', 'Williams']
# +
# 300 / 1972
# ['Davison', 'Miller', 'Zhang']
# ['Davison', 'Miller', 'Zhang']
# +
# 301 / 1972
# ['Geller']
# ['Geller']
# +
# 302 / 1972
# ['Aliod']
# ['Aliod']
# +
# 303 / 1972
# ['Aizawa', 'Ohgaya', 'Shimmura', 'Takagi']
# ['Aizawa', 'Ohgaya', 'Shimmura', 'Takagi']
# +
# 304 / 1972
# ['Cai', 'Ma', 'Song', 'Wen', 'Ye', 'Yu', 'Zhu']
# ['Cai', 'Ma', 'Song', 'Wen', 'Ye', 'Yu', 'Zhu']
# +
# 305 / 1972
# ['Robertson', 'Taylor', 'Zaragoza']
# ['Robertson', 'Taylor', 'Zaragoza']
# +
# 306 / 1972
# ['Bilotti', 'Felshin', 'Fernandes', 'Hildebrandt', 'Katz', 'Lin', 'Loreto', 'Marton', 'Mora']
# ['Bilotti', 'Felshin', 'Fernandes', 'Hildebrandt', 'Katz', 'Lin', 'Loreto', 'Marton', 'Mora']
# +
# 307 / 1972
# ['Burger']
# ['Burger']
# +
# 308 / 1972
# ['Aronson', 'Bodenreider', 'Demner-Fushman', 'Humphrey', 'Ide', 'Kayaalp', 'Loane', 'Mork', 'Smith', 'Tanabe']
# ['Aronson', 'Bodenreider', 'Demner-Fushman', 'Humphrey', 'Ide', 'Kayaalp', 'Loane', 'Mork', 'Smith', 'Tanabe']
# +
# 309 / 1972
# ['Bruijn', 'Martin']
# ['Bruijn', 'Martin']
# +
# 310 / 1972
# ['Hirao', 'Isozaki', 'Izumitani', 'Kazawa', 'Maeda', 'Taira']
# ['Hirao', 'Isozaki', 'Izumitani', 'Kazawa', 'Maeda', 'Taira']
# +
# 311 / 1972
# ['Chen', 'Hou', 'Lee', 'Teng']
# ['Chen', 'Hou', 'Lee', 'Teng']
# +
# 312 / 1972
# ['Chen', 'Hsu', 'Tsai']
# ['Chen', 'Hsu', 'Tsai']
# +
# 313 / 1972
# ['Chua', 'Cui', 'Kan', 'Maslennikov', 'Qiu', 'Yang']
# ['Chua', 'Cui', 'Kan', 'Maslennikov', 'Qiu', 'Yang']
# +
# 314 / 1972
# ['Lee', 'Zhang']
# ['Lee', 'Zhang']
# +
# 315 / 1972
# ['Brand', 'Driessen', 'Iljin', 'Klok']
# ['Brand', 'Driessen', 'Iljin', 'Klok']
# +
# 316 / 1972
# ['Bhupatiraju', 'Hersh', 'Price']
# ['Bhupatiraju', 'Hersh', 'Price']
# +
# 317 / 1972
# ['Deng', 'Dinstl', 'Grunfeld', 'Kwok']
# ['Deng', 'Dinstl', 'Grunfeld', 'Kwok']
# +
# 318 / 1972
# ['Dayanik', 'Nevill-Manning', 'Oughtred']
# ['Dayanik', 'Nevill-Manning', 'Oughtred']
# +
# 319 / 1972
# ['Belkin', 'Kelly', 'Lee', 'Li', 'Muresan', 'Tang', 'Yuan', 'Zhang']
# ['Belkin', 'Kelly', 'Lee', 'Li', 'Muresan', 'Tang', 'Yuan', 'Zhang']
# +
# 320 / 1972
# ['Boros', 'Kantor', 'Neu']
# ['Boros', 'Kantor', 'Neu']
# +
# 321 / 1972
# ['Quackenbush', 'Snuffin', 'Tong']
# ['Quackenbush', 'Snuffin', 'Tong']
# +
# 322 / 1972
# ['Chen', 'Ma', 'Ma', 'Shi', 'Tan', 'Wang', 'Wang', 'Xiao']
# ['Chen', 'Ma', 'Ma', 'Shi', 'Tan', 'Wang', 'Wang', 'Xiao']
# +
# 323 / 1972
# ['Lin', 'Liu', 'Ma', 'Zhang', 'Zhao']
# ['Lin', 'Liu', 'Ma', 'Zhang', 'Zhao']
# +
# 324 / 1972
# ['Newby']
# ['Newby']
# +
# 325 / 1972
# ['Duan', 'Liu', 'Strzalkowski', 'Wu', 'Zheng']
# ['Duan', 'Liu', 'Strzalkowski', 'Wu', 'Zheng']
# +
# 326 / 1972
# ['Jijkoun', 'Mishne', 'Monz', 'Rijke', 'Schlobach', 'Tsur']
# ['Jijkoun', 'Mishne', 'Monz', 'Rijke', 'Schlobach', 'Tsur']
# +
# 327 / 1972
# ['Kamps', 'Monz', 'Rijke', 'Sigurbjörnsson']
# ['Kamps', 'Monz', 'Rijke', 'Sigurbjörnsson']
# +
# 328 / 1972
# ['Clifton', 'Colquhoun', 'Teahan']
# ['Clifton', 'Colquhoun', 'Teahan']
# +
# 329 / 1972
# ['Divoli', 'Hearst', 'Nakov', 'Schwartz']
# ['Bhalotia', 'Hearst', 'Nakov', 'Schwartz']
# -
# 330 / 1972
# ['Altman', 'Chang', 'Cuminskey', 'Mehra', 'Osborne', 'Rotemberg', 'Sinclair', 'Smillie', 'Webber']
# ['Altman', 'Chang', 'Cuminskey', 'Mehra', 'Osborne', 'Rotemberg', 'Sinclair', 'Smillie', 'Webber']
# +
# 331 / 1972
# ['Bannard', 'Bos', 'Clark', 'Curran', 'Dalmas', 'Leidner', 'Steedman', 'Webber']
# ['Bannard', 'Bos', 'Clark', 'Curran', 'Dalmas', 'Leidner', 'Steedman', 'Webber']
# +
# 332 / 1972
# ['He', 'Ounis']
# ['He', 'Ounis']
# +
# 333 / 1972
# ['Cacheda', 'Ounis', 'Plachouras', 'Rijsbergen']
# ['Cacheda', 'Ounis', 'Plachouras', 'Rijsbergen']
# +
# 334 / 1972
# ['Liu', 'Yu']
# ['Liu', 'Yu']
# +
# 335 / 1972
# ['Shen', 'Zhai']
# ['Shen', 'Zhai']
# +
# 336 / 1972
# ['Fang', 'Shang', 'Tao', 'Zhai']
# ['Fang', 'Shang', 'Tao', 'Zhai']
# +
# 337 / 1972
# ['Shakery', 'Zhai']
# ['Shakery', 'Zhai']
# +
# 338 / 1972
# ['Arens', 'Eichmann', 'Light', 'Qiu', 'Sehgal', 'Srinivasan', 'Wang']
# ['Arens', 'Eichmann', 'Light', 'Qiu', 'Sehgal', 'Srinivasan', 'Wang']
# +
# 339 / 1972
# ['Gabbay', 'Mulcahy', 'Sutcliffe', 'White']
# ['Gabbay', 'Mulcahy', 'Sutcliffe', 'White']
# +
# 340 / 1972
# ['Bhatkar', 'Cost', 'James', 'Java', 'Kallurkar', 'Nicholas', 'Ogle', 'Rajavaram', 'Shanbhag', 'Shi']
# ['Bhatkar', 'Cost', 'James', 'Java', 'Kallurkar', 'Nicholas', 'Ogle', 'Rajavaram', 'Shanbhag', 'Shi']
# +
# 341 / 1972
# ['Demner-Fushman', 'He']
# ['Demner-Fushman', 'He']
# +
# 342 / 1972
# ['Allan', 'Corrada-Emmanuel', 'Jaleel', 'Li', 'Liu', 'Wade']
# ['Allan', 'Corrada-Emmanuel', 'Jaleel', 'Li', 'Liu', 'Wade']
# +
# 343 / 1972
# ['Anh', 'Moffat']
# ['Anh', 'Moffat']
# +
# 344 / 1972
# ['Hakim', 'Otterbacher', 'Qi', 'Radev']
# ['Hakim', 'Otterbacher', 'Qi', 'Radev']
# +
# 345 / 1972
# ['Perret', 'Rasolofo', 'Savoy']
# ['Perret', 'Rasolofo', 'Savoy']
# +
# 346 / 1972
# ['Ruiz', 'Srihari', 'Srikanth']
# ['Ruiz', 'Srihari', 'Srikanth']
# +
# 347 / 1972
# ['Chichester', 'Cohen', 'Coray', 'Ehrler', 'Ghorbel', 'Müller', 'Pallotta', 'Ruch']
# ['Chichester', 'Cohen', 'Coray', 'Ehrler', 'Ghorbel', 'Müller', 'Pallotta', 'Ruch']
# +
# 348 / 1972
# ['Ferrés', 'Massot', 'Rodríguez']
# ['Ferrés', 'Massot', 'Rodríguez']
# +
# 349 / 1972
# ['Echihabi', 'Hermjakob', 'Hovy', 'Marcu', 'Melz', 'Ravichandran']
# ['Echihabi', 'Hermjakob', 'Hovy', 'Marcu', 'Melz', 'Ravichandran']
# +
# 350 / 1972
# 351 / 1972
# ['Stokoe', 'Tait']
# ['Stokoe', 'Tait']
# +
# 352 / 1972
# ['Leppänen', 'Pirkola']
# ['Leppänen', 'Pirkola']
# +
# 353 / 1972
# ['Ao', 'Takagi', 'Yamamoto']
# ['Ao', 'Takagi', 'Yamamoto']
# +
# 354 / 1972
# ['Clarke', 'Cormack', 'Lynam', 'Terra', 'Yeung']
# ['Clarke', 'Cormack', 'Lynam', 'Terra', 'Yeung']
# +
# 355 / 1972
# ['Karamuftuoglu', 'Lam', 'Vechtomova']
# ['Karamuftuoglu', 'Lam', 'Vechtomova']
# +
# 356 / 1972
# ['Fan', 'Fox', 'Luo', 'Wang', 'Xi', 'Yang', 'Zhou']
# ['Fan', 'Fox', 'Luo', 'Wang', 'Xi', 'Yang', 'Zhou']
# +
# 357 / 1972
# ['Fan', 'Fox', 'Luo', 'Wang', 'Xi', 'Yang', 'Zhou']
# ['Fan', 'Fox', 'Luo', 'Wang', 'Xi', 'Yang', 'Zhou']
# +
# 358 / 1972
# ['Voorhees']
# ['Voorhees']
# +
# 359 / 1972
# 360 / 1972
# ['Allan']
# ['Allan']
# +
# 361 / 1972
# ['Soboroff']
# ['Soboroff']
# +
# 362 / 1972
# []
# ['Voorhees']
# -
# 363 / 1972
# ['Voorhees']
# ['Voorhees']
# +
# 364 / 1972
# ['Clarke', 'Craswell', 'Soboroff']
# ['Clarke', 'Craswell', 'Soboroff']
# +
# 365 / 1972
# ['Craswell', 'Hawking']
# ['Craswell', 'Hawking']
# +
# 366 / 1972
# ['Carpenter']
# ['Carpenter']
# +
# 367 / 1972
# ['Ding', 'Robles-Flores', 'Roussinov']
# ['Ding', 'Robles-Flores', 'Roussinov']
# +
# 368 / 1972
# ['Guillén']
# ['Guillén']
# +
# 369 / 1972
# ['Callan', 'Collins-Thompson', 'Ogilvie']
# ['Callan', 'Collins-Thompson', 'Ogilvie']
# +
# 370 / 1972
# ['Bai', 'Cheng', 'Wang', 'Xu', 'Zhang']
# ['Bai', 'Cheng', 'Wang', 'Xu', 'Zhang']
# +
# 371 / 1972
# ['Cheng', 'Guo', 'Wang', 'Xu', 'Zhang', 'Zhou']
# ['Cheng', 'Guo', 'Wang', 'Xu', 'Zhang', 'Zhou']
# +
# 372 / 1972
# ['Xu', 'Xu', 'Zhao']
# ['Xu', 'Xu', 'Zhao']
# +
# 373 / 1972
# ['Sun', 'Sun', 'Zhang']
# ['Sun', 'Sun', 'Zhang']
# +
# 374 / 1972
# ['Bennett', 'Evans', 'Hull', 'Montgomery', 'Shanahan', 'Sheftel']
# ['Bennett', 'Evans', 'Hull', 'Montgomery', 'Shanahan', 'Sheftel']
# +
# 375 / 1972
# ['Litkowski']
# ['Litkowski']
# +
# 376 / 1972
# ['McKeown', 'Schiffman']
# ['McKeown', 'Schiffman']
# +
# 377 / 1972
# ['Cherry', 'Crangle', 'Hong', 'Zbyslaw']
# ['Cherry', 'Crangle', 'Hong', 'Zbyslaw']
# +
# 378 / 1972
# ['Cox', 'Keselj']
# ['Cox', 'Keselj']
# +
# 379 / 1972
# ['Blott', 'Boydell', 'Camous', 'Ferguson', 'Gaughan', 'Gurrin', 'Jones', 'Murphy', 'O’Connor', 'Smeaton', 'Smyth', 'Wilkins']
# ['Blott', 'Boydell', 'Camous', 'Ferguson', 'Gaughan', 'Gurrin', 'Jones', 'Murphy', "O'Connor", 'Smeaton', 'Smyth', 'Wilkins']
# +
# 380 / 1972
# ['Nassar']
# ['Nassar']
# +
# 381 / 1972
# ['Amati', 'Carpineto', 'Romano']
# ['Amati', 'Carpineto', 'Romano']
# +
# 382 / 1972
# ['Huang', 'Li', 'Wu', 'You', 'Zhang', 'Zhou']
# ['Huang', 'Li', 'Wu', 'You', 'Zhang', 'Zhou']
# +
# 383 / 1972
# ['Darwish', 'Madkour']
# ['Darwish', 'Madkour']
# +
# 384 / 1972
# ['Luk', 'Wang', 'Wong']
# ['Luk', 'Wang', 'Wong']
# +
# 385 / 1972
# ['Tomlinson']
# ['Tomlinson']
# +
# 386 / 1972
# ['Amitay', 'Carmel', 'Darlow', 'Fine', 'Yom-Tov']
# ['Amitay', 'Carmel', 'Darlow', 'Fine', 'Yom-Tov']
# +
# 387 / 1972
# ['Blair-Goldensohn', 'Chu-Carroll', 'Czuba', 'Ittycheriah', 'Prager']
# ['Blair-Goldensohn', 'Chu-Carroll', 'Czuba', 'Ittycheriah', 'Prager']
# +
# 388 / 1972
# ['Conroy']
# ['Conroy']
# +
# 389 / 1972
# ['Frieder', 'Grossman', 'Heard']
# ['Frieder', 'Grossman', 'Heard']
# +
# 390 / 1972
# ['Friend', 'Lee', 'Li', 'Rowe', 'Wead', 'Yang', 'Yu']
# ['Friend', 'Lee', 'Li', 'Rowe', 'Wead', 'Yang', 'Yu']
# +
# 391 / 1972
# ['Costello', 'Mostafa', 'Seki', 'Singan']
# ['Costello', 'Mostafa', 'Seki', 'Singan']
# +
# 392 / 1972
# ['Dkaki', 'Mothe']
# ['Dkaki', 'Mothe']
# +
# 393 / 1972
# ['Kouylekov', 'Magnini', 'Tanev']
# ['Kouylekov', 'Magnini', 'Tanev']
# +
# 394 / 1972
# ['Cost', 'Mayfield', 'McNamee', 'Piatko']
# ['Cost', 'Mayfield', 'McNamee', 'Piatko']
# +
# 395 / 1972
# ['Chung', 'Han', 'Kim', 'Lee', 'Rim', 'Song']
# ['Chung', 'Han', 'Kim', 'Lee', 'Rim', 'Song']
# +
# 396 / 1972
# ['Farah', 'Vanderpooten']
# ['Farah', 'Vanderpooten']
# +
# 397 / 1972
# ['Geller']
# ['Geller']
# +
# 398 / 1972
# ['Aliod', 'Gardiner']
# ['Gardiner', 'Mollá']
# -
# 399 / 1972
# ['Kakuta', 'Karoji', 'Kondo', 'Takagi', 'Tomiyama']
# ['Kakuta', 'Karoji', 'Kondo', 'Takagi', 'Tomiyama']
# +
# 400 / 1972
# ['Liu', 'Ma', 'Qin', 'Shi', 'Song', 'Wen', 'Xin', 'Xue', 'Zhang', 'Zheng']
# ['Liu', 'Ma', 'Qin', 'Shi', 'Song', 'Wen', 'Xin', 'Xue', 'Zhang', 'Zheng']
# +
# 401 / 1972
# ['Craswell', 'Robertson', 'Saria', 'Taylor', 'Zaragoza']
# ['Craswell', 'Robertson', 'Saria', 'Taylor', 'Zaragoza']
# +
# 402 / 1972
# ['Bilotti', 'Felshin', 'Fernandes', 'Hildebrandt', 'Katz', 'Katzir', 'Lin', 'Loreto', 'Marton', 'Mora', 'Uzuner']
# ['Bilotti', 'Felshin', 'Fernandes', 'Hildebrandt', 'Katz', 'Katzir', 'Lin', 'Loreto', 'Marton', 'Mora', 'Uzuner']
# +
# 403 / 1972
# ['Lee', 'Zhang']
# ['Lee', 'Zhang']
# +
# 404 / 1972
# ['Aronson', 'Demner-Fushman', 'Humphrey', 'Ide', 'Kim', 'Liu', 'Loane', 'Mork', 'Smith', 'Tanabe', 'Wilbur', 'Xie']
# ['Aronson', 'Demner-Fushman', 'Humphrey', 'Ide', 'Kim', 'Liu', 'Loane', 'Mork', 'Smith', 'Tanabe', 'Wilbur', 'Xie']
# +
# 405 / 1972
# ['Chen', 'Hou', 'Lee']
# ['Chen', 'Hou', 'Lee']
# +
# 406 / 1972
# ['Chen', 'Hsu', 'Tsai']
# ['Chen', 'Hsu', 'Tsai']
# +
# 407 / 1972
# ['Chua', 'Cui', 'Kan', 'Li', 'Sun']
# ['Chua', 'Cui', 'Kan', 'Li', 'Sun']
# +
# 408 / 1972
# ['Bhupatiraju', 'Cohen', 'Hersh']
# ['Bhupatiraju', 'Cohen', 'Hersh']
# +
# 409 / 1972
# ['Fujita']
# ['Fujita']
# +
# 410 / 1972
# ['Hu', 'Lai', 'Lü', 'Su', 'Swen', 'Xiang', 'Zan']
# ['Hu', 'Lai', 'Lü', 'Su', 'Swen', 'Xiang', 'Zan']
# +
# 411 / 1972
# ['Deng', 'Grunfeld', 'Kwok', 'Sun']
# ['Deng', 'Grunfeld', 'Kwok', 'Sun']
# +
# 412 / 1972
# ['Billerbeck', 'Cannane', 'Chattaraj', 'Lester', 'Webber', 'Williams', 'Yiannis', 'Zobel']
# ['Billerbeck', 'Cannane', 'Chattaraj', 'Lester', 'Webber', 'Williams', 'Yiannis', 'Zobel']
# +
# 413 / 1972
# ['Harper', 'Koychev', 'Liu', 'Muresan', 'Wettschereck', 'Wiratunga']
# ['Harper', 'Koychev', 'Liu', 'Muresan', 'Wettschereck', 'Wiratunga']
# +
# 414 / 1972
# ['Belkin', 'Chaleva', 'Cole', 'Li', 'Liu', 'Liu', 'Muresan', 'Smith', 'Sun', 'Yuan', 'Zhang']
# ['Belkin', 'Chaleva', 'Cole', 'Li', 'Liu', 'Liu', 'Muresan', 'Smith', 'Sun', 'Yuan', 'Zhang']
# +
# 415 / 1972
# ['Dayanik', 'Fradkin', 'Genkin', 'Kantor', 'Lewis', 'Madigan', 'Menkov']
# ['Dayanik', 'Fradkin', 'Genkin', 'Kantor', 'Lewis', 'Madigan', 'Menkov']
# +
# 416 / 1972
# ['Becker', 'Kaisser']
# ['Becker', 'Kaißer']
# +
# 417 / 1972
# ['Hu', 'Lu', 'Ma']
# ['Hu', 'Lu', 'Ma']
# +
# 418 / 1972
# ['Ruiz', 'Srihari', 'Srikanth']
# ['Ruiz', 'Srihari', 'Srikanth']
# +
# 419 / 1972
# ['Tong']
# ['Tong']
# +
# 420 / 1972
# ['Jelier', 'Kraaij', 'Raaijmakers', 'Weeber']
# ['Jelier', 'Kraaij', 'Raaijmakers', 'Weeber']
# +
# 421 / 1972
# ['Li', 'Zhang', 'Zhang', 'Zhu']
# ['Li', 'Zhang', 'Zhang', 'Zhu']
# +
# 422 / 1972
# ['Ma', 'Ru', 'Zhang', 'Zhao']
# ['Ma', 'Ru', 'Zhang', 'Zhao']
# +
# 423 / 1972
# ['Chen', 'Ma', 'Tan']
# ['Chen', 'Ma', 'Tan']
# +
# 424 / 1972
# ['Jin', 'Ma', 'Qi', 'Zhang']
# ['Jin', 'Ma', 'Qi', 'Zhang']
# +
# 425 / 1972
# ['Liu', 'Ma', 'Wang', 'Zhang']
# ['Liu', 'Ma', 'Wang', 'Zhang']
# +
# 426 / 1972
# ['Bassi', 'Ciany', 'Kulman', 'Mayfield', 'McNamee', 'Schone']
# ['Bassi', 'Ciany', 'Kulman', 'Mayfield', 'McNamee', 'Schone']
# +
# 427 / 1972
# ['Newby']
# ['Newby']
# +
# 428 / 1972
# ['Ahn', 'Jijkoun', 'Mishne', 'Müller', 'Rijke', 'Schlobach']
# ['Ahn', 'Jijkoun', 'Mishne', 'Müller', 'Rijke', 'Schlobach']
# -
# 429 / 1972
# ['Kamps', 'Mishne', 'Rijke']
# ['Kamps', 'Mishne', 'Rijke']
# +
# 430 / 1972
# ['Hearst', 'Nakov', 'Schwartz', 'Stoica']
# ['Hearst', 'Nakov', 'Schwartz', 'Stoica']
# +
# 431 / 1972
# ['Levow']
# ['Levow']
# +
# 432 / 1972
# ['Sinclair', 'Webber']
# ['Sinclair', 'Webber']
# +
# 433 / 1972
# ['Ahn', 'Bos', 'Clark', 'Curran', 'Dalmas', 'Leidner', 'Smillie', 'Webber']
# ['Ahn', 'Bos', 'Clark', 'Curran', 'Dalmas', 'Leidner', 'Smillie', 'Webber']
# +
# 434 / 1972
# ['He', 'Ounis', 'Plachouras']
# ['He', 'Ounis', 'Plachouras']
# +
# 435 / 1972
# ['Abdou', 'Ehrler', 'Ruch', 'Savoy']
# ['Chichester', 'Cohen', 'Ehrler', 'Fabry', 'Geissbühler', 'Marty', 'Müller', 'Ruch']
# -
# 436 / 1972
# ['Liu', 'Sun', 'Yu']
# ['Liu', 'Sun', 'Yu']
# +
# 437 / 1972
# ['Jiang', 'Zhai']
# ['Jiang', 'Zhai']
# +
# 438 / 1972
# ['Bradshaw', 'Eichmann', 'Qiu', 'Sehgal', 'Srinivasan', 'Wong', 'Zhang', 'Zhou']
# ['Bradshaw', 'Eichmann', 'Qiu', 'Sehgal', 'Srinivasan', 'Wong', 'Zhang', 'Zhou']
# +
# 439 / 1972
# ['Chali', 'Dubien']
# ['Chali', 'Dubien']
# +
# 440 / 1972
# ['Gabbay', 'Mulcahy', "O'Gorman", 'Sutcliffe', 'White']
# ['Gabbay', 'Mulcahy', "O'Gorman", 'Sutcliffe', 'White']
# +
# 441 / 1972
# ['Allan', 'Croft', 'Diaz', 'Jaleel', 'Larkey', 'Li', 'Smucker', 'Wade']
# ['Allan', 'Croft', 'Diaz', 'Jaleel', 'Larkey', 'Li', 'Smucker', 'Wade']
# +
# 442 / 1972
# ['Croft', 'Metzler', 'Strohman', 'Turtle']
# ['Croft', 'Metzler', 'Strohman', 'Turtle']
# +
# 443 / 1972
# ['Demner-Fushman', 'He', 'Karakos', 'Khudanpur', 'Oard']
# ['Demner-Fushman', 'He', 'Karakos', 'Khudanpur', 'Oard']
# +
# 444 / 1972
# ['Anh', 'Moffat']
# ['Anh', 'Moffat']
# +
# 445 / 1972
# ['Erkan']
# ['Erkan']
# +
# 446 / 1972
# ['Dollu', 'Fu', 'Kelly']
# ['Dollu', 'Fu', 'Kelly']
# +
# 447 / 1972
# ['Chen', 'Ge', 'Jiang', 'Wu']
# ['Chen', 'Ge', 'Jiang', 'Wu']
# +
# 448 / 1972
# ['Bacchin', 'Melucci']
# ['Bacchin', 'Melucci']
# +
# 449 / 1972
# ['Amrani', 'Azé', 'Heitz', 'Kodratoff', 'Roche']
# ['Amrani', 'Azé', 'Heitz', 'Kodratoff', 'Roche']
# +
# 450 / 1972
# ['Ageno', 'Ferrés', 'González', 'Kanaan', 'Rodríguez', 'Surdeanu', 'Turmo']
# ['Ageno', 'Ferrés', 'González', 'Kanaan', 'Rodríguez', 'Surdeanu', 'Turmo']
# +
# 451 / 1972
# ['Attardi', 'Esuli', 'Patel']
# ['Attardi', 'Esuli', 'Patel']
# +
# 452 / 1972
# ['Hovy', 'Kim', 'Ravichandran']
# ['Hovy', 'Kim', 'Ravichandran']
# +
# 453 / 1972
# ['Gaizauskas', 'Guo', 'Harkema']
# ['Gaizauskas', 'Guo', 'Harkema']
# +
# 454 / 1972
# ['Gaizauskas', 'Greenwood', 'Harkema', 'Hepple', 'Saggion', 'Sanka']
# ['Gaizauskas', 'Greenwood', 'Hepple', 'Roberts', 'Saggion']
# -
# 455 / 1972
# ['Pirkola']
# ['Pirkola']
# +
# 456 / 1972
# ['Hiemstra', 'Rode']
# ['Hiemstra', 'Rode']
# +
# 457 / 1972
# ['Clifton', 'Teahan']
# ['Clifton', 'Teahan']
# +
# 458 / 1972
# ['Karamuftuoglu', 'Vechtomova']
# ['Karamuftuoglu', 'Vechtomova']
# +
# 459 / 1972
# ['Conrado']
# ['Büttcher', 'Clarke', 'Cormack']
# -
# 460 / 1972
# ['Craven', 'Settles']
# ['Craven', 'Settles']
# +
# 461 / 1972
# ['Fan', 'Fox', 'Wang', 'Xi']
# ['Fan', 'Fox', 'Wang', 'Xi']
# +
# 462 / 1972
# ['Huang', 'Huang', 'Wen', 'Zhong']
# ['Huang', 'Huang', 'Wen', 'Zhong']
# +
# 463 / 1972
# ['Voorhees']
# ['Voorhees']
# +
# 464 / 1972
# ['Craswell', 'Soboroff', 'Vries']
# ['Craswell', 'Soboroff', 'Vries']
# +
# 465 / 1972
# 466 / 1972
# ['Allan']
# ['Allan']
# +
# 467 / 1972
# ['Dang', 'Voorhees']
# ['Dang', 'Voorhees']
# +
# 468 / 1972
# ['Voorhees']
# ['Voorhees']
# +
# 469 / 1972
# 470 / 1972
# ['Clarke', 'Scholer', 'Soboroff']
# ['Clarke', 'Scholer', 'Soboroff']
# +
# 471 / 1972
# ['He', 'Hsu', 'Hung', 'Lee', 'Lin', 'Sung', 'Tsai', 'Wang', 'Wu']
# ['He', 'Hsu', 'Hung', 'Lee', 'Lin', 'Sung', 'Tsai', 'Wang', 'Wu']
# +
# 472 / 1972
# ['Ahmed', 'Baral', 'Gonzalez', 'Logsdon', 'Nakamura', 'Nikkila', 'Shah', 'Tari', 'Wendt', 'Yu', 'Zeigler']
# ['Ahmed', 'Baral', 'Gonzalez', 'Logsdon', 'Nakamura', 'Nikkila', 'Shah', 'Tari', 'Wendt', 'Yu', 'Zeigler']
# +
# 473 / 1972
# ['Chau', 'Filatova', 'Robles-Flores', 'Roussinov']
# ['Chau', 'Filatova', 'Robles-Flores', 'Roussinov']
# +
# 474 / 1972
# ['Chen', 'Guo', 'Ru', 'Xu']
# ['Chen', 'Guo', 'Ru', 'Xu']
# +
# 475 / 1972
# ['Chen', 'Guo', 'Hu', 'Xu', 'Yang']
# ['Chen', 'Guo', 'Hu', 'Xu', 'Yang']
# +
# 476 / 1972
# ['Breyer']
# ['Breyer']
# +
# 477 / 1972
# ['Guillén']
# ['Guillén']
# +
# 478 / 1972
# ['Callan', 'Ogilvie']
# ['Callan', 'Ogilvie']
# +
# 479 / 1972
# ['Bilotti', 'Frederking', 'Hannan', 'Hiyakumoto', 'Ko', 'Lin', 'Lita', 'Mitamura', 'Nyberg', 'Pedro', 'Schlaikjer']
# ['Bilotti', 'Frederking', 'Hannan', 'Hiyakumoto', 'Ko', 'Lin', 'Lita', 'Mitamura', 'Nyberg', 'Pedro', 'Schlaikjer']
# +
# 480 / 1972
# ['Kanungo', 'Si']
# ['Kanungo', 'Si']
# +
# 481 / 1972
# ['Bai', 'Ding', 'Wang']
# ['Bai', 'Ding', 'Wang']
# +
# 482 / 1972
# ['Cheng', 'Lang', 'Wang', 'Wang']
# ['Cheng', 'Lang', 'Wang', 'Wang']
# +
# 483 / 1972
# ['Lv', 'Zhao']
# ['Lv', 'Zhao']
# +
# 484 / 1972
# ['Lv', 'Sun', 'Zhang', 'Zhang']
# ['Lv', 'Sun', 'Zhang', 'Zhang']
# +
# 485 / 1972
# ['Chan', 'Han', 'Lam']
# ['Chan', 'Han', 'Lam']
# +
# 486 / 1972
# ['Litkowski']
# ['Litkowski']
# +
# 487 / 1972
# ['Assis', 'Chhabra', 'Siefkes', 'Yerazunis']
# ['Assis', 'Chhabra', 'Siefkes', 'Yerazunis']
# +
# 488 / 1972
# ['Hawking', 'Thomas', 'Wu']
# ['Hawking', 'Thomas', 'Wu']
# +
# 489 / 1972
# ['Abou-Assaleh', 'Cercone', 'Doyle', 'Keselj', 'Whidden']
# ['Abou-Assaleh', 'Cercone', 'Doyle', 'Keselj', 'Whidden']
# +
# 490 / 1972
# ['Keselj', 'Milios', 'Tuttle', 'Wang', 'Zhang']
# ['Keselj', 'Milios', 'Tuttle', 'Wang', 'Zhang']
# +
# 491 / 1972
# ['Li', 'Lin', 'Liu', 'Lu', 'Yang']
# ['Li', 'Lin', 'Liu', 'Lu', 'Yang']
# +
# 492 / 1972
# ['Zakharov']
# ['Zakharov']
# +
# 493 / 1972
# ['Ciany', 'Cutts', 'Mayfield', 'McNamee', 'Schone', 'Smith']
# ['Ciany', 'Cutts', 'Mayfield', 'McNamee', 'Schone', 'Smith']
# +
# 494 / 1972
# ['Allen', 'Song', 'Zhu']
# ['Allen', 'Song', 'Zhu']
# +
# 495 / 1972
# ['Blott', 'Camous', 'Gurrin', 'Jones', 'Smeaton']
# ['Blott', 'Camous', 'Gurrin', 'Jones', 'Smeaton']
# +
# 496 / 1972
# 497 / 1972
# ['Beigbeder', 'Mercier']
# ['Beigbeder', 'Mercier']
# +
# 498 / 1972
# ['Jelier', 'Kors', 'Kraaij', 'Mons', 'Mulligen', 'Schijvenaars', 'Schuemie', 'Weeber']
# ['Jelier', 'Kors', 'Kraaij', 'Mons', 'Mulligen', 'Schijvenaars', 'Schuemie', 'Weeber']
# +
# 499 / 1972
# ['Deng', 'Huang', 'Lin', 'Lou', 'Niu', 'Sun', 'Zheng']
# ['Deng', 'Huang', 'Lin', 'Lou', 'Niu', 'Sun', 'Zheng']
# +
# 500 / 1972
# ['Huang', 'Lin', 'Wu', 'Zhang', 'Zhou']
# ['Huang', 'Lin', 'Wu', 'Zhang', 'Zhou']
# +
# 501 / 1972
# ['Guan', 'Li', 'Xu', 'Zhao']
# ['Guan', 'Li', 'Xu', 'Zhao']
# +
# 502 / 1972
# ['Kwok', 'Leong', 'Luk', 'Wong', 'Wong', 'Wu']
# ['Kwok', 'Leong', 'Luk', 'Wong', 'Wong', 'Wu']
# +
# 503 / 1972
# ['Tomlinson']
# ['Tomlinson']
# +
# 504 / 1972
# ['Carmel', 'Darlow', 'Errera-Yaakov', 'Fine', 'Pelleg', 'Yom-Tov']
# ['Carmel', 'Darlow', 'Errera-Yaakov', 'Fine', 'Pelleg', 'Yom-Tov']
# +
# 505 / 1972
# ['Mukherjea', 'Punjani', 'Subramaniam']
# ['Mukherjea', 'Punjani', 'Subramaniam']
# +
# 506 / 1972
# ['Segal']
# ['Segal']
# +
# 507 / 1972
# ['Ando', 'Dredze', 'Zhang']
# ['Ando', 'Dredze', 'Zhang']
# +
# 508 / 1972
# 509 / 1972
# ['Frieder', 'Goharian', 'Urbain']
# ['Frieder', 'Goharian', 'Urbain']
# +
# 510 / 1972
# ['Akram', 'George', 'Loehrlein', 'McCaulay', 'Mei', 'Record', 'Yang', 'Yu', 'Zhang']
# ['Akram', 'George', 'Loehrlein', 'McCaulay', 'Mei', 'Record', 'Yang', 'Yu', 'Zhang']
# +
# 511 / 1972
# ['Ji', 'Su', 'Tan', 'Xiao', 'Yang', 'Yang', 'Yu', 'Zhang', 'Zhou']
# ['Ji', 'Su', 'Tan', 'Xiao', 'Yang', 'Yang', 'Yu', 'Zhang', 'Zhou']
# +
# 512 / 1972
# ['Aussenac-Gilles', 'Baziz', 'Boughanem']
# ['Aussenac-Gilles', 'Baziz', 'Boughanem']
# +
# 513 / 1972
# ['Mayfield', 'McNamee']
# ['Mayfield', 'McNamee']
# +
# 514 / 1972
# ['Bratko', 'Filipič']
# ['Bratko', 'Filipic']
# +
# 515 / 1972
# ['Bowden', 'Clark', 'Harabagiu', 'Hickl', 'Moldovan', 'Wang']
# ['Bowden', 'Clark', 'Harabagiu', 'Hickl', 'Moldovan', 'Wang']
# +
# 516 / 1972
# ['Geller']
# ['Geller']
# +
# 517 / 1972
# ['Hiemstra', 'Ramírez', 'Rode', 'Vries', 'Westerveld']
# ['Hiemstra', 'Ramírez', 'Rode', 'Vries', 'Westerveld']
# +
# 518 / 1972
# ['Aliod', 'Zaanen']
# ['Mollá', 'Zaanen']
# -
# 519 / 1972
# ['Meyer']
# ['Meyer']
# +
# 520 / 1972
# ['Hashimoto', 'Imai', 'Kudo', 'Takagi']
# ['Hashimoto', 'Imai', 'Kudo', 'Takagi']
# +
# 521 / 1972
# 522 / 1972
# ['Craswell', 'Robertson', 'Zaragoza']
# ['Craswell', 'Robertson', 'Zaragoza']
# +
# 523 / 1972
# ['Agichtein', 'Cucerzan']
# ['Agichtein', 'Cucerzan']
# +
# 524 / 1972
# ['Borchardt', 'Brownell', 'Felshin', 'Katz', 'Loreto', 'Louis-Rosenberg', 'Lu', 'Marton', 'Mora', 'Stiller', 'Uzuner', 'Wilcox']
# ['Borchardt', 'Brownell', 'Felshin', 'Katz', 'Loreto', 'Louis-Rosenberg', 'Lu', 'Marton', 'Mora', 'Stiller', 'Uzuner', 'Wilcox']
# +
# 525 / 1972
# 526 / 1972
# ['Aronson', 'Demner-Fushman', 'Humphrey', 'Lin', 'Liu', 'Ruch', 'Ruiz', 'Smith', 'Tanabe', 'Wilbur']
# ['Aronson', 'Demner-Fushman', 'Humphrey', 'Lin', 'Liu', 'Ruch', 'Ruiz', 'Smith', 'Tanabe', 'Wilbur']
# +
# 527 / 1972
# ['Chen', 'Hou', 'Lin']
# ['Chen', 'Hou', 'Lin']
# +
# 528 / 1972
# ['Chen', 'Hou', 'Lee']
# ['Chen', 'Hou', 'Lee']
# +
# 529 / 1972
# ['Chen', 'Hsu']
# ['Chen', 'Hsu']
# +
# 530 / 1972
# ['Chua', 'Cui', 'Jiang', 'Kan', 'Sun', 'Tan']
# ['Chua', 'Cui', 'Jiang', 'Kan', 'Sun', 'Tan']
# +
# 531 / 1972
# ['Cohen', 'Hersh', 'Yang']
# ['Cohen', 'Hersh', 'Yang']
# +
# 532 / 1972
# ['He', 'Peng', 'Yang', 'Yao']
# ['He', 'Peng', 'Yang', 'Yao']
# +
# 533 / 1972
# ['Bao', 'Chen', 'He', 'Yao', 'Yin']
# ['Bao', 'Chen', 'He', 'Yao', 'Yin']
# +
# 534 / 1972
# ['Li', 'Peng', 'Yan', 'Zhu']
# ['Li', 'Peng', 'Yan', 'Zhu']
# +
# 535 / 1972
# ['Terra']
# ['Terra']
# +
# 536 / 1972
# ['Ashoori', 'Cai', 'Roelleke', 'Wu']
# ['Ashoori', 'Cai', 'Roelleke', 'Wu']
# +
# 537 / 1972
# 538 / 1972
# ['Geva', 'King', 'Lu', 'Sahama', 'Woodley']
# ['Geva', 'King', 'Lu', 'Sahama', 'Woodley']
# +
# 539 / 1972
# ['Brady', 'Garg', 'Shatkay', 'Zheng']
# ['Brady', 'Garg', 'Shatkay', 'Zheng']
# +
# 540 / 1972
# ['Bernstein', 'Billerbeck', 'Garcia', 'Lester', 'Scholer', 'Webber', 'Zobel']
# ...
# +
# 1793 / 1972
# ['Cao', 'Chen', 'Gao', 'Ni', 'Qiao', 'Xie']
# ['Cao', 'Chen', 'Gao', 'Ni', 'Qiao', 'Xie']
# +
# 1794 / 1972
# ['Li', 'Li', 'Xu']
# ['Li', 'Li', 'Xu']
# +
# 1795 / 1972
# ['Dutkiewicz', 'Jedrzejek']
# ['Dutkiewicz', 'Jedrzejek']
# +
# 1796 / 1972
# ['Elsayed', 'Essam', 'Haouari']
# ['Elsayed', 'Essam', 'Haouari']
# +
# 1797 / 1972
# ['Sakai', 'Tao']
# ['Sakai', 'Tao']
# +
# 1798 / 1972
# ['Culpepper', 'Liu']
# ['Culpepper', 'Liu']
# +
# 1799 / 1972
# ['Boers', 'Kamphuis', 'Vries']
# ['Boers', 'Kamphuis', 'Vries']
# +
# 1800 / 1972
# ['Bonab', 'Clifton', 'Jones', 'Karlgren', 'Tanveer', 'Yu']
# ['Bonab', 'Clifton', 'Jones', 'Karlgren', 'Tanveer', 'Yu']
# +
# 1801 / 1972
# ['Clifton', 'Jones', 'Reddy', 'Rezapour']
# ['Clifton', 'Jones', 'Reddy', 'Rezapour']
# +
# 1802 / 1972
# ['Ak', 'Fayoumi', 'Köksal', 'Yeniterzi']
# ['Ak', 'Fayoumi', 'Köksal', 'Yeniterzi']
# +
# 1803 / 1972
# ['Dietz', 'Kashyapi']
# ['Dietz', 'Kashyapi']
# +
# 1804 / 1972
# ['Hanbury', 'Hofstätter']
# ['Hanbury', 'Hofstätter']
# +
# 1805 / 1972
# ['Andersson', 'El-Ebshihy', 'Hanbury', 'Ningtyas', 'Piroi']
# ['Andersson', 'El-Ebshihy', 'Hanbury', 'Ningtyas', 'Piroi']
# +
# 1806 / 1972
# ['Kamps', 'Kondylidis', 'Rau']
# ['Kamps', 'Kondylidis', 'Rau']
# +
# 1807 / 1972
# ['Lillis', 'Wang']
# ['Lillis', 'Wang']
# +
# 1808 / 1972
# ['Li', 'Liu', 'Song', 'Wang', 'Yu']
# ['Li', 'Liu', 'Song', 'Wang', 'Yu']
# +
# 1809 / 1972
# ['Fang', 'Lu']
# ['Fang', 'Lu']
# +
# 1810 / 1972
# ['Fan', 'Wang', 'Zhang', 'Zheng']
# ['Fan', 'Wang', 'Zhang', 'Zheng']
# +
# 1811 / 1972
# ['Oard', 'Sayed']
# ['Oard', 'Sayed']
# +
# 1812 / 1972
# ['Galuscáková', 'Nair', 'Oard']
# ['Galuscáková', 'Nair', 'Oard']
# +
# 1813 / 1972
# ['Madabushi', 'Reed']
# ['Madabushi', 'Reed']
# +
# 1814 / 1972
# ['Dalton', 'Owoicho']
# ['Dalton', 'Owoicho']
# +
# 1815 / 1972
# ['Macdonald', 'Ounis', 'Wang', 'Wang', 'Wu']
# ['Macdonald', 'Ounis', 'Wang', 'Wang', 'Wu']
# +
# 1816 / 1972
# ['Mcdonald', 'Ounis']
# ['McDonald', 'Ounis']
# +
# 1817 / 1972
# ['McCreadie', 'Pugantsov']
# ['Hepburn', 'McCreadie']
# -
# 1818 / 1972
# ['Macdonald', 'Ounis', 'Santos', 'Ueda']
# ['Macdonald', 'Ounis', 'Santos', 'Ueda']
# +
# 1819 / 1972
# ['Aliannejadi', 'Crestani', 'Sekulic']
# ['Aliannejadi', 'Crestani', 'Sekulic']
# +
# 1820 / 1972
# ['Aliannejadi', 'Crestani', 'Sekulic', 'Soleimani']
# ['Aliannejadi', 'Crestani', 'Sekulic', 'Soleimani']
# +
# 1821 / 1972
# ['Longpre', 'Tu', 'Vakulenko', 'Voskarides']
# ['Longpre', 'Tu', 'Vakulenko', 'Voskarides']
# +
# 1822 / 1972
# ['Gonçalves', 'Martins']
# ['Goncalves', 'Martins']
# +
# 1823 / 1972
# ['Cardoso', 'Martins']
# ['Cardoso', 'Martins']
# +
# 1824 / 1972
# ['Arabzadeh', 'Clarke']
# ['Arabzadeh', 'Clarke']
# +
# 1825 / 1972
# ['Bevendor', 'Bondarenko', 'Fröbe', 'Günther', 'Hagen', 'Stein', 'Völske']
# ['Bevendorff', 'Bondarenko', 'Fröbe', 'Günther', 'Hagen', 'Stein', 'Völske']
# +
# 1826 / 1972
# ['Niebergall', 'Zhao']
# ['Niebergall', 'Zhao']
# +
# 1827 / 1972
# ['Soboroff']
# ['Soboroff']
# +
# 1828 / 1972
# ['Callan', 'Dalton', 'Xiong']
# ['Callan', 'Dalton', 'Xiong']
# +
# 1829 / 1972
# ['Campos', 'Craswell', 'Lin', 'Mitra', 'Yilmaz']
# ['Campos', 'Craswell', 'Lin', 'Mitra', 'Yilmaz']
# +
# 1830 / 1972
# ['Biega', 'Diaz', 'Ekstrand', 'Kohlmeier']
# ['Ekstrand', 'Johnson', 'McDonald', 'Raj']
# -
# 1831 / 1972
# ['Clarke', 'Maistro', 'Rizvi', 'Smucker', 'Zuccon']
# ['Clarke', 'Maistro', 'Smucker']
# -
# 1832 / 1972
# ['Carterette', 'Clifton', 'Eskevich', 'Jones', 'Jones', 'Karlgren', 'Reddy', 'Tanaka']
# ['Carterette', 'Clifton', 'Eskevich', 'Jones', 'Jones', 'Karlgren', 'Reddy', 'Tanaka']
# +
# 1833 / 1972
# ['Huang', 'Jin', 'Tan', 'Yuan', 'Zhao']
# ['Huang', 'Jin', 'Tan', 'Yuan', 'Zhao']
# +
# 1834 / 1972
# ['Caucheteur', 'Gobeill', 'Mottaz', 'Mottin', 'Pasche', 'Ruch']
# ['Caucheteur', 'Gobeill', 'Mottaz', 'Mottin', 'Pasche', 'Ruch']
# +
# 1835 / 1972
# ['Kompatsiaris', 'Koufakis', 'Tsikrika', 'Vrochidis']
# ['Kompatsiaris', 'Koufakis', 'Tsikrika', 'Vrochidis']
# +
# 1836 / 1972
# ['Ding', 'Ju', 'Lin', 'Tsai', 'Tsao', 'Wang', 'Yeh']
# ['Ding', 'Ju', 'Lin', 'Tsai', 'Tsao', 'Wang', 'Yeh']
# +
# 1837 / 1972
# ['Vu', 'Wu']
# ['Vu', 'Wu']
# +
# 1838 / 1972
# ['Chen', 'He', 'Sun', 'Sun']
# ['Chen', 'He', 'Sun', 'Sun']
# +
# 1839 / 1972
# ['Corral', 'Fernández-Pichel', 'Gamallo', 'Losada', 'Pichel']
# ['Corral', 'Fernández-Pichel', 'Gamallo', 'Losada', 'Pichel']
# +
# 1840 / 1972
# ['Fedorova']
# ['Fedorova']
# +
# 1841 / 1972
# ['Callan', 'Gonçalves', 'Jedidi']
# ['Callan', 'Gonçalves', 'Jedidi']
# +
# 1842 / 1972
# ['Mele', 'Muntean', 'Nardini', 'Perego', 'Tonellotto']
# ['Mele', 'Muntean', 'Nardini', 'Perego', 'Tonellotto']
# +
# 1843 / 1972
# ['Karimi', 'Nguyen', 'Rybiński']
# ['Karimi', 'Nguyen', 'Rybinski']
# +
# 1844 / 1972
# ['Jaume-Santero', 'Naderi', 'Teodoro', 'Zhang']
# ['Jaume-Santero', 'Naderi', 'Teodoro', 'Zhang']
# +
# 1845 / 1972
# ['Ghafourian', 'Kusa']
# ['Ghafourian', 'Kusa']
# +
# 1846 / 1972
# ['Hemmje', 'Kevitt', 'Wagenpfeil']
# ['Hemmje', 'Kevitt', 'Wagenpfeil']
# +
# 1847 / 1972
# ['Ji', 'Tian', 'Tran', 'Ying']
# ['Ji', 'Tian', 'Tran', 'Ying']
# +
# 1848 / 1972
# ['Biester', 'Dandala', 'Joopudi']
# ['Biester', 'Dandala', 'Joopudi']
# +
# 1849 / 1972
# ['Bushkov', 'Chernyshevich', 'Goncharov', 'Khobnia', 'Makouski', 'Mitskevich', 'Podberezko']
# ['Bushkov', 'Chernyshevich', 'Goncharov', 'Khobnia', 'Makouski', 'Mitskevich', 'Podberezko']
# +
# 1850 / 1972
# ['Choudhary']
# ['Choudhary']
# +
# 1851 / 1972
# ['Faggioli', 'Marchesin', 'Nunzio']
# ['Faggioli', 'Marchesin', 'Nunzio']
# +
# 1852 / 1972
# ['Engelmann', 'Schaer']
# ['Engelmann', 'Schaer']
# +
# 1853 / 1972
# ['Kanoulas', 'Krasakis']
# ['Kanoulas', 'Krasakis']
# +
# 1854 / 1972
# ['Bénédict', 'Bénédict', 'Gupta', 'Heuss', 'Khandel', 'Li', 'Sarvi', 'Vardasbi']
# ['Bénédict', 'Gupta', 'Heuss', 'Khandel', 'Li', 'Sarvi', 'Vardasbi']
# -
# 1855 / 1972
# ['Frihat', 'Fuhr']
# ['Frihat', 'Fuhr']
# +
# 1856 / 1972
# ['Baldwin', 'Cavedon', 'Cohn', 'Lau', 'Mahendra', 'Otmakhova', 'Spina', 'Truong', 'Verspoor']
# ['Baldwin', 'Cavedon', 'Cohn', 'Lau', 'Mahendra', 'Otmakhova', 'Spina', 'Truong', 'Verspoor']
# +
# 1857 / 1972
# ['Boros', 'Rochelle']
# ['Boros', 'Coustaty', 'Doucet', 'Lejeune', 'Nguyen']
# -
# 1858 / 1972
# ['Cabrera-Diego']
# ['Boros', 'Cabrera-Diego', 'Doucet']
# -
# 1859 / 1972
# ['Anand', 'Leonhardt', 'Rudra']
# ['Anand', 'Leonhardt', 'Rudra']
# +
# 1860 / 1972
# ['Foley', 'Koster']
# ['Foley', 'Koster']
# +
# 1861 / 1972
# ['Astaouti', 'Nie', 'Soulier', 'Touzari']
# ['Astaouti', 'Gerald', 'Nie', 'Soulier', 'Touzari']
# -
# 1862 / 1972
# ['Buntain', 'Sharma']
# ['Buntain', 'Sharma']
# +
# 1863 / 1972
# ['Clinchant', 'Formal', 'Lassance', 'Piwowarski', 'Sors']
# ['Clinchant', 'Formal', 'Lassance', 'Piwowarski', 'Sors']
# +
# 1864 / 1972
# ['Chen', 'Huang', 'Pan', 'Shi']
# ['Chen', 'Huang', 'Pan', 'Shi']
# +
# 1865 / 1972
# ['Chen', 'Fang', 'Gao', 'Lai', 'Liu', 'Qiao', 'Wang', 'Xie', 'Xie', 'Ye']
# ['Chen', 'Gao', 'Liu', 'Qiao', 'Wang', 'Xie', 'Ye']
# -
# 1866 / 1972
# ['Cagliero', 'Garza', 'Quatra', 'Vaiani']
# ['Cagliero', 'Garza', 'Quatra', 'Vaiani']
# +
# 1867 / 1972
# ['Dutkiewicz', 'Jedrzejek']
# ['Dutkiewicz', 'Jedrzejek']
# +
# 1868 / 1972
# ['Elsayed', 'Essam']
# ['Elsayed', 'Essam']
# +
# 1869 / 1972
# ['Cherumanal', 'Croft', 'Scholer']
# ['Cherumanal', 'Croft', 'Scholer', 'Spina']
# -
# 1870 / 1972
# ['Gerritse', 'Hasibi', 'Joko', 'Vries']
# ['Gerritse', 'Hasibi', 'Joko', 'Vries']
# +
# 1871 / 1972
# ['Baumgardner', 'Cartwright', 'Coppola', 'Liu', 'Orlioglu', 'Small']
# ['Baumgardner', 'Cartwright', 'Coppola', 'Liu', 'Orlioglu', 'Small']
# +
# 1872 / 1972
# ['Fayoumi', 'Yeniterzi']
# ['Fayoumi', 'Yeniterzi']
# +
# 1873 / 1972
# ['Zheng']
# ['Zheng']
# +
# 1874 / 1972
# ['Fang', 'Fujita', 'Joho']
# ['Fang', 'Fujita', 'Joho']
# +
# 1875 / 1972
# ['Fujita', 'Jin', 'Joho']
# ['Fujita', 'Jin', 'Joho']
# +
# 1876 / 1972
# ['Fujita', 'Joho', 'Zhang']
# ['Fujita', 'Joho', 'Zhang']
# +
# 1877 / 1972
# ['Hanbury', 'Hofstätter', 'Sertkan']
# ['Hanbury', 'Hofstätter', 'Sertkan']
# +
# 1878 / 1972
# ['Kamps', 'Rau']
# ['Kamps', 'Rau']
# +
# 1879 / 1972
# ['Lillis', 'Wang']
# ['Lillis', 'Wang']
# +
# 1880 / 1972
# ['Balog', 'Book', 'Kostric', 'Linjordet', 'Setty']
# ['Balog', 'Book', 'Kostric', 'Linjordet', 'Setty']
# +
# 1881 / 1972
# ['Oard', 'Qian']
# ['Oard', 'Qian']
# +
# 1882 / 1972
# ['Koontz', 'Oronoz', 'Pérez']
# ['Koontz', 'Oronoz', 'Pérez']
# +
# 1883 / 1972
# ['Clifton', 'Tanaka', 'Tanveer']
# ['Clifton', 'Tanaka', 'Tanveer']
# +
# 1884 / 1972
# ['Espitia', 'Pasi', 'Peikos']
# ['Espitia', 'Pasi', 'Peikos']
# +
# 1885 / 1972
# ['Chen', 'Chen', 'Cleveland', 'Ding', 'Nguyen', 'Prasad', 'Zhao']
# ['Chen', 'Chen', 'Cleveland', 'Ding', 'Nguyen', 'Prasad', 'Zhao']
# +
# 1886 / 1972
# ['Jänich', 'MacAvaney', 'Macdonald', 'McCreadie', 'Mcdonald', 'Ounis', 'Pugantsov', 'Wang']
# ['Hepburn', 'McCreadie']
# -
# 1887 / 1972
# ['Paula', 'Rosso', 'Schlicht']
# ['Paula', 'Rosso', 'Schlicht']
# +
# 1888 / 1972
# ['Abualsaud', 'Chen', 'Ghajar', 'Minh', 'Phan', 'Smucker', 'Tahami', 'Zhang']
# ['Abualsaud', 'Chen', 'Ghajar', 'Minh', 'Smucker', 'Tahami', 'Zhang']
# -
# 1889 / 1972
# ['Deshmukh', 'Sethi']
# ['Deshmukh', 'Sethi']
# +
# 1890 / 1972
# ['Arabzadeh', 'Clarke', 'Yan']
# ['Arabzadeh', 'Clarke', 'Yan']
# +
# 1891 / 1972
# ['Bondarenko', 'Fröbe', 'Gohsen', 'Günther', 'Hagen', 'Kiesel', 'Potthast', 'Schwerter', 'Stein', 'Syed', 'Völske']
# ['Bondarenko', 'Fröbe', 'Gohsen', 'Günther', 'Hagen', 'Kiesel', 'Potthast', 'Schwerter', 'Stein', 'Syed', 'Völske']
# +
# 1892 / 1972
# ['Bexte', 'Friedrich', 'Galetzka', 'Idrissi-Yaghir', 'Schäfer']
# ['Bexte', 'Friedrich', 'Galetzka', 'Idrissi-Yaghir', 'Schäfer']
# +
# 1893 / 1972
# ['Huang', 'Huang']
# ['Huang', 'Huang']
# +
# 1894 / 1972
# ['Aliannejadi', 'Azzopardi', 'Dalton', 'Owoicho', 'Trippas', 'Vakulenko']
# ['Aliannejadi', 'Azzopardi', 'Dalton', 'Owoicho', 'Trippas', 'Vakulenko']
# +
# 1895 / 1972
# ['Campos', 'Craswell', 'Lin', 'Mitra', 'Soboroff', 'Voorhees', 'Yilmaz']
# ['Campos', 'Craswell', 'Lin', 'Mitra', 'Soboroff', 'Voorhees', 'Yilmaz']
# +
# 1896 / 1972
# ['Ekstrand', 'Johnson', 'Mcdonald', 'Raj']
# ['Ekstrand', 'Johnson', 'McDonald', 'Raj']
# +
# 1897 / 1972
# ['Lawrie', 'MacAvaney', 'Mayfield', 'McNamee', 'Oard', 'Soldaini', 'Yang']
# ['Lawrie', 'MacAvaney', 'Mayfield', 'McNamee', 'Oard', 'Soldaini', 'Yang']
# +
# 1898 / 1972
# ['Bedrick', 'Demner-Fushman', 'Hersh', 'Roberts', 'Voorhees']
# ['Bedrick', 'Demner-Fushman', 'Hersh', 'Roberts', 'Voorhees']
# +
# 1899 / 1972
# ['Guo', 'Long', 'Xie', 'Xu', 'Zhang', 'Zhang']
# ['Guo', 'Long', 'Xie', 'Xu', 'Zhang', 'Zhang']
# +
# 1900 / 1972
# ['Kompatsiaris', 'Koufakis', 'Tsikrika', 'Vrochidis']
# ['Kompatsiaris', 'Koufakis', 'Tsikrika', 'Vrochidis']
# +
# 1901 / 1972
# ['Chang', 'Ju', 'Lin', 'Tsai', 'Wang']
# ['Chang', 'Ju', 'Lin', 'Tsai', 'Wang']
# +
# 1902 / 1972
# ['Chang', 'Chen', 'Ju', 'Lin', 'Tsai', 'Wang']
# ['Chang', 'Chen', 'Ju', 'Lin', 'Tsai', 'Wang']
# +
# 1903 / 1972
# ['Chen', 'He', 'Luo', 'Peng', 'Sun', 'Sun']
# ['Chen', 'He', 'Luo', 'Peng', 'Sun', 'Sun']
# +
# 1904 / 1972
# ['Mele', 'Muntean', 'Nardini', 'Perego', 'Tonellotto']
# ['Mele', 'Muntean', 'Nardini', 'Perego', 'Tonellotto']
# +
# 1905 / 1972
# ['Karimi', 'Nguyen', 'Rybiński']
# ['Karimi', 'Nguyen', 'Rybinski']
# +
# 1906 / 1972
# ['Corral', 'Fernández-Pichel', 'Losada', 'Pichel']
# ['Corral', 'Fernández-Pichel', 'Losada', 'Pichel']
# +
# 1907 / 1972
# ['Wang', 'Ye', 'Zhang', 'Zhou']
# ['Wang', 'Ye', 'Zhang', 'Zhou']
# +
# 1908 / 1972
# ['Gales', 'Li', 'Liusie', 'Qian']
# ['Gales', 'Li', 'Liusie', 'Qian']
# +
# 1909 / 1972
# ['Conroy', 'Molino', 'Yang']
# ['Conroy', 'Molino', 'Yang']
# +
# 1910 / 1972
# ['Dusart', 'Hubert', 'Pinel-Sauvagnat']
# ['Dusart', 'Hubert', 'Pinel-Sauvagnat']
# +
# 1911 / 1972
# ['Abe']
# ['Abe']
# +
# 1912 / 1972
# ['Formal', 'Gerald', 'Hai', 'Nie', 'Piwowarski', 'Soulier']
# ['Formal', 'Gerald', 'Hai', 'Nie', 'Piwowarski', 'Soulier']
# +
# 1913 / 1972
# ['Clinchant', 'Lassance']
# ['Clinchant', 'Lassance']
# +
# 1914 / 1972
# ['Fidalgo', 'Lotufo', 'Nogueira', 'Pereira']
# ['Fidalgo', 'Lotufo', 'Nogueira', 'Pereira']
# +
# 1915 / 1972
# ['Jeronymo', 'Lotufo', 'Nogueira']
# ['Jeronymo', 'Lotufo', 'Nogueira']
# +
# 1916 / 1972
# ['Kamps', 'Rau']
# ['Kamps', 'Rau']
# +
# 1917 / 1972
# ['Alberede', 'Galuscáková', 'Mannion', 'Mulhem', 'Quénot', 'Sáez']
# ['Alberede', 'Galuscáková', 'Mannion', 'Mulhem', 'Quénot', 'Sáez']
# +
# 1918 / 1972
# ['Pasi', 'Peikos']
# ['Pasi', 'Peikos']
# +
# 1919 / 1972
# ['Smucker', 'Tahami', 'Zhang']
# ['Smucker', 'Tahami', 'Zhang']
# +
# 1920 / 1972
# ['Balog', 'Bernard', 'Kostric', 'Lajewska', 'Sekulic']
# ['Balog', 'Bernard', 'Kostric', 'Lajewska', 'Sekulic']
# +
# 1921 / 1972
# ['MacAvaney', 'Macdonald', 'Ounis', 'Wang']
# ['MacAvaney', 'Macdonald', 'Ounis', 'Wang']
# +
# 1922 / 1972
# ['Jänich', 'Mcdonald', 'Ounis']
# ['Jänich', 'McDonald', 'Ounis']
# +
# 1923 / 1972
# ['Kongyoung', 'Macdonald', 'Ounis']
# ['Kongyoung', 'Macdonald', 'Ounis']
# +
# 1924 / 1972
# ['Clarke', 'Huo', 'Yan']
# ['Clarke', 'Huo', 'Yan']
# +
# 1925 / 1972
# ['Bondarenko', 'Pugachev', 'Reimer']
# ['Artemova', 'Bondarenko', 'Braslavski', 'Fröbe', 'Gienapp', 'Hagen', 'Potthast', 'Pugachev', 'Reimer', 'Schlatt', 'Stein']
# -
# 1926 / 1972
# ['Nguyen', 'Rudra']
# ['Nguyen', 'Rudra']
# +
# 1927 / 1972
# ['Herrmannova', 'Jadhav', 'Lima-Walton', 'Nazir', 'Sindhwa']
# ['Herrmannova', 'Jadhav', 'Lima-Walton', 'Nazir', 'Sindhwa']
# +
# 1928 / 1972
# ['Alfonso-Hermelo', 'Jeronymo', 'Kamalloo', 'Lassance', 'Lin', 'Nogueira', 'Ogundepo', 'Rezagholizadeh', 'Thakur', 'Yang', 'Zhang']
# ['Alfonso-Hermelo', 'Jeronymo', 'Kamalloo', 'Lassance', 'Lin', 'Nogueira', 'Ogundepo', 'Rezagholizadeh', 'Thakur', 'Yang', 'Zhang']
# +
# 1929 / 1972
# ['Lawrie', 'Mayfield', 'Yang']
# ['Lawrie', 'Mayfield', 'Yang']
# +
# 1930 / 1972
# ['Alfonso-Hermelo', 'Kamalloo', 'Rezagholizadeh']
# ['Alfonso-Hermelo', 'Kamalloo', 'Rezagholizadeh']
# +
# 1931 / 1972
# ['Faggioli', 'Marchesin', 'Nunzio']
# ['Faggioli', 'Marchesin', 'Nunzio']
# +
# 1932 / 1972
# ['Faggioli', 'Ferro', 'Romanello']
# ['Faggioli', 'Ferro', 'Romanello']
# +
# 1933 / 1972
# ['Jo', 'Lee', 'Lee', 'Sin']
# ['Jo', 'Lee', 'Lee', 'Sin']
# +
# 1934 / 1972
# ['McNamee']
# ['McNamee']
# +
# 1935 / 1972
# ['Riedhammer', 'Seeberger']
# ['Riedhammer', 'Seeberger']
# +
# 1936 / 1972
# ['Bean', 'Dobson', 'Kraljevic', 'Searle', 'Wu']
# ['Bean', 'Dobson', 'Kraljevic', 'Searle', 'Wu']
# +
# 1937 / 1972
# ['Alaofi', 'Altalhi', 'Cherumanal', 'Naghizade', 'Scholer', 'Spina']
# ['Alaofi', 'Altalhi', 'Cherumanal', 'Naghizade', 'Scholer', 'Spina']
# +
# 1938 / 1972
# ['Chen', 'Fang']
# ['Chen', 'Fang']
# +
# 1939 / 1972
# ['Fang', 'Yang', 'Zhang']
# ['Fang', 'Yang', 'Zhang']
# +
# 1940 / 1972
# ['Nair', 'Oard']
# ['Nair', 'Oard']
# +
# 1941 / 1972
# ['Oard', 'Rankel', 'Rollings']
# ['Oard', 'Rankel', 'Rollings']
# +
# 1942 / 1972
# ['Huang', 'Huang']
# ['Huang', 'Huang']
# +
# 1943 / 1972
# ['Marx', 'SMART-AKSW']
# ['Coelho', 'Marx']
# -
# 1944 / 1972
# ['Jiang', 'Jin', 'Lin', 'Liu', 'Ma', 'Song', 'Zhang', 'Zhao']
# ['Jiang', 'Jin', 'Lin', 'Liu', 'Ma', 'Song', 'Zhang', 'Zhao']
# +
# 1945 / 1972
# ['Abualsaud', 'Lioma', 'Maistro', 'Smucker', 'Zuccon']
# ['Abualsaud', 'Lioma', 'Maistro', 'Smucker', 'Zuccon']
# +
# 1946 / 1972
# ['Jose', 'McMinn', 'Perez']
# ['Jose', 'McMinn', 'Perez']
# +
# 1947 / 1972
# ['Craswell', 'Hawking']
# ['Craswell', 'Hawking']
# +
# 1948 / 1972
# ['Bagdouri', 'Oard']
# ['Bagdouri', 'Oard']
# +
# 1949 / 1972
# ['Cheriton', 'Lin', 'Yang']
# ['Lin', 'Yang']
# -
# 1950 / 1972
# 1951 / 1972
# ['Clinchant', 'Lassance']
# ['Clinchant', 'Lassance']
# +
# 1952 / 1972
# []
# ['Lin', 'Wang', 'Yilmaz']
# -
# 1953 / 1972
# 1954 / 1972
# ['Biega', 'Diaz', 'Ekstrand', 'Kohlmeier']
# ['Biega', 'Diaz', 'Ekstrand', 'Kohlmeier']
# +
# 1955 / 1972
# ['Li', 'Xu', 'Yao']
# ['Gobeill', 'Mottaz', 'Mottin', 'Pasche', 'Rijen', 'Ruch']
# -
# 1956 / 1972
# ['Kersten', 'Klan', 'Kruspe', 'Stein', 'Wiegmann']
# ['Kersten', 'Klan', 'Kruspe', 'Stein', 'Wiegmann']
# +
# 1957 / 1972
# 1958 / 1972
# 1959 / 1972
# ['Doshi', 'Majumder']
# ['Doshi', 'Kewlani', 'Majumder', 'Mandalia', 'Modha', 'Shah', 'Shahshah']
# -
# 1960 / 1972
# ['Khloponin', 'Kosseim']
# ['Khloponin', 'Kosseim']
# +
# 1961 / 1972
# 1962 / 1972
# ['Fern´andez', 'G´omez', 'Llopis', 'Mart´ınez-Barco']
# ['Fernández', 'Gómez', 'Llopis', 'Martínez-Barco']
# -
# 1963 / 1972
# 1964 / 1972
# ['Canova', 'Carpenter', 'Danaher', 'Devine']
# ['Canova', 'Carpenter', 'Danaher', 'Devine', 'Lim']
# -
# 1965 / 1972
# ['Campos', 'Craswell', 'Mitra', 'Voorhees', 'Yilmaz']
# ['Campos', 'Craswell', 'Mitra', 'Voorhees', 'Yilmaz']
# +
# 1966 / 1972
# ['Bricon-Souf', 'Nguyen', 'Soulier', 'Tamine']
# ['Bricon-Souf', 'Nguyen', 'Soulier', 'Tamine']
# +
# 1967 / 1972
# ['Jung', 'Lease']
# ['Jung', 'Lease']
# +
# 1968 / 1972
# ['Dietz']
# ['Dietz', 'Foley']
# -
# 1969 / 1972
# ['Anh', 'Moffat', 'Webber']
# ['Anh', 'Moffat', 'Webber']
# +
# 1970 / 1972
# ['Biega', 'Diaz', 'Ekstrand', 'Feldman', 'Kohlmeier']
# ['Biega', 'Diaz', 'Ekstrand', 'Feldman', 'Kohlmeier']
# +
# 1971 / 1972
# ['Araújo', 'Magalhães', 'Mourão']
# ['Araújo', 'Magalhães', 'Mourão']
# +
# 1972 / 1972
# ['Castelli', 'Florian', 'Ott', 'Raghavan']
# ['Castelli', 'Florian', 'Ott', 'Raghavan']
# +
# 200

# %%
df_not_found = pd.read_parquet("../../../data/metadata_TREC_SemanticScholar_not_found.parquet")

# %%
# Read in already manually searched document IDS for Semantic Scholar

file_path = '../../../data/TREC_SemanticScholar_manually_seach_IDs.txt'

# Read the tab-separated file into a DataFrame
df_found = pd.read_csv(file_path, sep=',', header=None)

# Display the DataFrame
df_found
# Out:
#             0                                         1              2
# 0     trec_76   d19009c71873e08035a75e8ec55bda650bdc5f9             OK
# 1    trec_132  7e525f13fcd4e477e75d3a8b1a6ad136a8edf680             OK
# 2    trec_270  16172a45df487449b91b59706ed9d071e5af468c          draft
# 3    trec_293  bd608f980ca65d20be920d4fac16df4bd0a5ea10             OK
# 4    trec_329  8cfbfc2a90b18d154a12761da44204d55179ea45             OK
# 5    trec_362  4e4152d168b0ca49a0718629814de868793cc8a8             OK
# 6    trec_398  5fc936d6a3d9276c4ef9c9bae62dc3cad70786dd             OK
# 7    trec_435  9e0bd7808afb5cb28aeb811cbbe1a552d0f27ad8             OK
# 8    trec_454  a4f22fb9631dea6cf2496055c1a20bf3177cdab3             OK
# 9    trec_459  27853481007662b26f7707ad4a39ccb881ff48f9             OK
# 10   trec_518  316957b62931eab3b7b095ee7e11a559dcdaaea9             OK
# 11   trec_560  89d59cf86e07810d4d030080237aab3262c8a9ea             OK
# 12   trec_563  109881f3543f2fe68283b935d7e510945e0dfb4a             OK
# 13   trec_642  1a570b9ad58c91b57d5432d31911064c3041f4cb             OK
# 14   trec_645  6a625f7fdebf15fe1b3651441f50f2111784cb88             OK
# 15   trec_658  ad1318e05066517b5cf96ce9487bae253b94d292             OK
# 16   trec_663  541016fb1c81b632c03dcdfa1c84d954619aa6f4             OK
# 17   trec_667  a2fd1364cc9050ac09256b3f7abee03b8e49b606             OK
# 18   trec_680  a480ac1f9fcc8a3e35e20644c083c780941fd89f             OK
# 19   trec_720  7ad403a633f97aa78f7973f94af8551eddfb3e26             OK
# 20   trec_924  9eee1e5b0afe82808ab6d49d99438615ba2728cd             OK
# 21   trec_936  bc5a993371d100b6a0daa240fd9e0ec13608c766             OK
# 22   trec_961  b9f01183f7b6632c174bd56810fa1b9521402e8b             OK
# 23   trec_987  3842090ed1a3bc3681263c07aac40d78d4ada3ec             OK
# 24   trec_989  cd8467ed935c71b6f9e33afba8985a17e1a163ff             OK
# 25   trec_993  7fa42baa9c5e7e8efb0669219b17f5b32799f085  missingSource
# 26  trec_1019  a1b25c5f1f628d7baf8f9f4bee9237bfa843b262             OK
# 27  trec_1053  ae0365f06b812d9f565d58e3161cba4a5402845b             OK
# 28  trec_1072  5716ad1cbe40619d3733d5e3c4cc28dedaebc8bf             OK
# 29  trec_1096  a5fc141f1d42a8809c99f1c38af669fb5783fbb7  missingSource
# 30  trec_1106  d334ee08a2bc3247e1f3fa138e2e35eace34c842             OK
# 31  trec_1107  0c46fe38a86f58efe87c4533b68313cc68e42947             OK
# 32  trec_1113  769ba56ef6b4e82e6498aaf01a8eccd4ee6063fb             OK
# 33  trec_1116  4f1119f418489bfa1dab9bf280fb4f4a85489ef1             OK
# 34  trec_1123  0737a9b31b84e32db39c813ee9397b70a7e95a08             OK
# 35  trec_1130  2e9de90b6a53bf693f7d4efce61e8a14a00ba258             OK
# 36  trec_1142  f325d7ef8427d6ed83d98107a424d99ddd8b8e66             OK
# 37  trec_1172  b384faf411c959a4f05c843f40059864c48ab6c9             OK
# 38    trec_20  debf9b3fa2e8c2d05aed8e4551591b000c18d73a             OK
# 39   trec_279  991665892b9d234217a4313730824173ef409ee0  missingSource

# %%
# Narrow done the IDs to the once fitting the requirements 

df_found = df_found[df_found[2] == "OK"]

# %%
df_found.columns = ['ID', 'Semantic ID', 'Notes']

# %%
# Filter rows in when ID was already manually searched

df_not_found = df_not_found[~df_not_found["ID"].isin(df_found[0].tolist())]

# %%
 # Initialize an empty list to store ID, semantic_id, and note
ids = []

for i, j in df_not_found.iterrows():
   
    print(j["Title"])
    print(j["Authors"])

    # Take user input for the semantic ID (manual input)
    semantic_id = input()

    # Take user input for any additional note (manual input)
    note = input()

    # Append the current row's ID, the inputted semantic_id, and note to the ids list
    ids.append([j["ID"], semantic_id, note])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ids = []
# ----> 2 for i, j in df_not_found.iterrows():
#       4     print(j["Title"])
#       5     print(j["Authors"])
#
# NameError: name 'df_not_found' is not defined

# %%
df_manual = pd.DataFrame(liste_ids, columns=["ID","Semantic ID", "Notes"])
df_manual = df_manual[df_manual["Semantic ID"] != ""]

# Concatenate the manually entered data (df_manual) with the previously manually entered data data (df_found)
df_concat = pd.concat([df_manual, df_found])

# Define a list of notes that indicate papers requiring additional scraping
notes_to_scrape = ['','WrongLinkRestGood', 'NoSourceButLink', 'LinkArxivRestGood',  'GoodAberVieleJahreLinks', 'LinkArxivSonstGoost', 'TablesCorrectTitleWrong',  'AbstractCorrectLinkAndTitleWrong', 'OK']

# Filter rows where the "Notes" column contains entries in the 'notes_to_scrape' list
df_to_additionally_scrape = df_concat[df_concat["Notes"].isin(notes_to_scrape)]

# Filter rows where the "Notes" column does NOT contain entries in the 'notes_to_scrape' list
df_not_sufficient = df_concat[~df_concat["Notes"].isin(notes_to_scrape)]

# %%
params = {
        "query": j["Title"],
        "limit": 1,
        "fields": "corpusId,externalIds,citationCount,influentialCitationCount,authors,journal,title,citations.paperId"
    }
    counter += 1
    resp = requests.get(url, params=params, headers=headers).json()

# %%
df_to_additionally_scrape
# Out:
#            ID                               Semantic ID  \
# 12   trec_521  b05c34e18c5fd407c0f70360c1b175afb7749ccc
# 21   trec_652  b55686bc31771814626a684a00c93c17d3d19c5d
# 27   trec_770  704a49e2c70ef81dc0b768a6a3590a3e570e903c
# 32   trec_849  ccaa9caf84876897c8740d86b6cb681d32845db3
# 33   trec_860  a151b4d68bff5a052827c3d35ab82d769ecfcf6f
# ..        ...                                       ...
# 34  trec_1123  0737a9b31b84e32db39c813ee9397b70a7e95a08
# 35  trec_1130  2e9de90b6a53bf693f7d4efce61e8a14a00ba258
# 36  trec_1142  f325d7ef8427d6ed83d98107a424d99ddd8b8e66
# 37  trec_1172  b384faf411c959a4f05c843f40059864c48ab6c9
# 38    trec_20  debf9b3fa2e8c2d05aed8e4551591b000c18d73a
#
#                       Notes
# 12  TablesCorrectTitleWrong
# 21          NoSourceButLink
# 27
# 32
# 33
# ..                      ...
# 34                       OK
# 35                       OK
# 36                       OK
# 37                       OK
# 38                       OK
#
# [100 rows x 3 columns]

# %%
import time
import requests
data_trec = {}

params = {
        "limit": 1,
        "fields": "corpusId,externalIds,citationCount,influentialCitationCount,authors,journal,title,citations.paperId"
    }

for i,j in df_to_additionally_scrape.iterrows():
    
    # Construct the API URL using the "Semantic ID" from the current row
    url = f'https://api.semanticscholar.org/graph/v1/paper/{j["Semantic ID"]}'

    # Send a GET request to the Semantic Scholar API with the specified parameters and headers
    resp = requests.get(url, params=params, headers=headers).json()

    # Store the API response in the data_trec dictionary with the current row's "ID" as the key
    data_trec[j["ID"]] =  resp

    # Pause for 3.5 seconds to avoid overloading the API with too many requests in a short time
    time.sleep(3.5)

# %%
import json

with open('../../../data/SemanticScholar_TREC_found.json', 'r', encoding="utf-8") as file:
    Semantic_Trec = json.load(file)

# %%
# Initialize a new dictionary to store the unified data types
unified_semantic_trec = {}

for i in Semantic_Trec:
    if type(Semantic_Trec[i]) == list:
        unified_semantic_trec[i] = Semantic_Trec[i][0]
    elif isinstance(Semantic_Trec[i] , dict):
        unified_semantic_trec[i] = Semantic_Trec[i]

# %%
final_semantic_trec = data_trec | unified_semantic_trec

# %%
len(final_semantic_trec)
# Out:
# 1871

# %%
with open('../../../data/SemanticScholar_TREC.json', 'w', encoding='utf-8') as f:
    json.dump(final_semantic_trec, f, ensure_ascii=False, indent=4)

# %%
df_not_scraped_for_reasons = df_concat[~df_concat["Notes"].isin(notes_to_scrape)]

# %%
df_not_scraped_for_reasons
# Out:
#             ID                               Semantic ID  \
# 2     trec_270  16172a45df487449b91b59706ed9d071e5af468c
# 3     trec_279  991665892b9d234217a4313730824173ef409ee0
# 11    trec_508  bde127a84030270714180e0b4eff187a127a6106
# 35    trec_884  1485f07d7d9194d15f09ed222388700585f457f3
# 42    trec_993  7fa42baa9c5e7e8efb0669219b17f5b32799f085
# 45   trec_1026  1485f07d7d9194d15f09ed222388700585f457f3
# 75   trec_1309  3e8df0ab78ea7f40595dd6958196bc3d98889500
# 156  trec_1955  0ef581a8a1640f049d313790b0263b77939cb919
# 164  trec_1968  24d1b149a9f25288542785fd16e33ab7eb93563f
#
#                                    Notes
# 2                                  draft
# 3                          missingSource
# 11                         missingSource
# 35          WrongTitleCorrectAbstractETC
# 42                  MissingSourceAndLink
# 45             CorrectTitleWrongAbstract
# 75     TitleHalfCorrectWrongLinkNoSource
# 156  AbstractCorrectTitleWrongLinksWrong
# 164                    NoSourceWrongLink

# %%
df_not_scraped_for_reasons.to_parquet("../../../data/SemanticScholar_TREC_found_but_not_scraped.parquet")
